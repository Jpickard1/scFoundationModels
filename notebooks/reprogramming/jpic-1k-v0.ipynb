# %% [markdown]
# # 1k Fibroblasts Perturbed with All HumanTFs

# %% [markdown]
# # Set up

# %%
import numpy as np
import pandas as pd
import scanpy as sp
import anndata as ad # JP add this line
import os
import sys
import time

# %%
# Subset 1k Fibroblasts
# Load firboblast source cells
DATAPATH = "/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/unperturbed"
FILE = "fibroblast.h5ad"
adata = sp.read_h5ad(os.path.join(DATAPATH, FILE))

adata.var['ensemblid'] = adata.var['ensemblid'].str.split('.').str[0] # JP Add this line

# Change the layers to show the raw counts
adata.layers = {'raw_counts': adata.layers['raw_counts']}
adata.X = adata.layers['raw_counts'].copy()

# Select 1000 random cells
adata = adata[np.random.randint(0,adata.shape[0], 100), :]

# Show data to the user
adata.var.head()
# Out:
#              gene_symbol     feature_type        ensemblid  highly_variable  \
# DDX11L1          DDX11L1  Gene Expression  ENSG00000223972            False
# WASH7P            WASH7P  Gene Expression  ENSG00000227232            False
# MIR6859-1      MIR6859-1  Gene Expression  ENSG00000278267            False
# MIR1302-2HG  MIR1302-2HG  Gene Expression  ENSG00000243485            False
# MIR1302-2      MIR1302-2  Gene Expression  ENSG00000284332            False
#
#                     means  dispersions  dispersions_norm      mean       std
# DDX11L1      6.398244e-05     0.835044         -0.573947  0.000039  0.005574
# WASH7P       2.274395e-03     2.442280          0.533203  0.001080  0.031731
# MIR6859-1    6.175251e-05     1.295335         -0.256874  0.000033  0.005634
# MIR1302-2HG  1.372886e-04     2.656352          0.680668  0.000048  0.008041
# MIR1302-2    1.000000e-12          NaN          0.000000  0.000000  1.000000

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 100 × 58870
#     obs: 'organ_tissue', 'method', 'donor', 'anatomical_information', 'n_counts_UMIs', 'n_genes', 'cell_ontology_class', 'free_annotation', 'manually_annotated', 'compartment', 'gender'
#     var: 'gene_symbol', 'feature_type', 'ensemblid', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: '_scvi', '_training_mode', 'dendrogram_cell_type_tissue', 'dendrogram_computational_compartment_assignment', 'dendrogram_consensus_prediction', 'dendrogram_tissue_cell_type', 'donor_colors', 'donor_method_colors', 'hvg', 'method_colors', 'neighbors', 'organ_tissue_colors', 'sex_colors', 'tissue_colors', 'umap'
#     obsm: 'X_pca', 'X_scvi', 'X_scvi_umap', 'X_umap'
#     layers: 'raw_counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# # Perturbations

# %% [markdown]
# ## Load HumanTF

# %%
humanTfdf = pd.read_csv('data/HumanTFs_v_1.01.csv') # JP this line is changed
humanTfdf.head()
# Out:
#    Unnamed: 0       Ensembl ID HGNC symbol   DBD Is TF? TF assessment  \
# 0           0  ENSG00000137203      TFAP2A  AP-2    Yes   Known motif
# 1           1  ENSG00000008196      TFAP2B  AP-2    Yes   Known motif
# 2           2  ENSG00000087510      TFAP2C  AP-2    Yes   Known motif
# 3           3  ENSG00000008197      TFAP2D  AP-2    Yes   Known motif
# 4           4  ENSG00000116819      TFAP2E  AP-2    Yes   Known motif
#
#               Binding mode              Motif status  \
# 0  Monomer or homomultimer  High-throughput in vitro
# 1  Monomer or homomultimer  High-throughput in vitro
# 2  Monomer or homomultimer  High-throughput in vitro
# 3  Monomer or homomultimer       In vivo/Misc source
# 4  Monomer or homomultimer  High-throughput in vitro
#
#                                          Final Notes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Only known motifs are from Transfac or HocoMoc...
# 4                                                NaN
#
#                                       Final Comments  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3  Binds the same GCCTGAGGC sequence as the other...  ...
# 4                                                NaN  ...
#
#   CisBP considers it a TF?                               TFCat classification  \
# 0                      Yes  TF Gene_DNA-Binding: sequence-specific_DNA Bin...
# 1                      Yes  TF Gene_DNA-Binding: sequence-specific_DNA Bin...
# 2                      Yes                                                 No
# 3                      Yes                                                 No
# 4                      Yes  TF Gene_DNA-Binding: sequence-specific_DNA Bin...
#
#   Is a GO TF?                    Initial assessment       Curator 1  \
# 0         Yes                1a1, Direct HQ evidence    Sam Lambert
# 1         Yes                1a1, Direct HQ evidence  Matt Weirauch
# 2         Yes                1a1, Direct HQ evidence  Matt Weirauch
# 3         Yes  2a1, Lower confidence direct evidence    Arttu Jolma
# 4         Yes                1a1, Direct HQ evidence    Sam Lambert
#
#           Curator 2 TFclass considers it a TF?   \
# 0        Yimeng Yin                         Yes
# 1        Yimeng Yin                         Yes
# 2        Yimeng Yin                         Yes
# 3       Sam Lambert                         Yes
# 4  Laura Campitelli                         Yes
#
#                                          Go Evidence  \
# 0  $#ENSG00000137203#GO:0000981#sequence-specific...
# 1  $#ENSG00000008196#GO:0000981#sequence-specific...
# 2  $#ENSG00000087510#GO:0001077#RNA polymerase II...
# 3  $#ENSG00000008197#GO:0000981#sequence-specific...
# 4  $#ENSG00000116819#GO:0000981#sequence-specific...
#
#                            Pfam Domains (By ENSP ID) Is C2H2 ZF(KRAB)?
# 0  $#ENSP00000368928#ENSG00000137203#ENST00000379...             False
# 1  $#ENSP00000377265#ENSG00000008196#ENST00000393...             False
# 2  $#ENSP00000201031#ENSG00000087510#ENST00000201...             False
# 3  $#ENSP00000008391#ENSG00000008197#ENST00000008...             False
# 4  $#ENSP00000362332#ENSG00000116819#ENST00000373...             False
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Verify HumanTFs in Tabula Sapiens Data

# %%
# Check which human TFs are in the dataframe
tfIds = humanTfdf['Ensembl ID']

ct = 0
sub = 0
for i, tf in enumerate(tfIds):
    if humanTfdf['Is TF?'].iloc[i] != 'Yes':
        sub += 1
        continue
    if tf in list(adata.var['ensemblid']):
        ct += 1

print(ct)
print(ct/(len(tfIds) - sub))
# Out:
# 1637
# 0.9987797437461867

# %% [markdown]
# ## Perform Perturbations

# %%
adata.obs['TF'] = None
adata.obs['u']  = 0
adata.obs
# Out:
# /tmp/ipykernel_3472526/1648163555.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs['TF'] = None
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#                                                       organ_tissue     method  \
# AGATGCTTCATAAGGA_TSP2_Thymus_NA_10X_1_1                     Thymus        10X
# TGTAACGTCGGCTCTT_TSP14_SalivaryGland_Parotid_10...  Salivary_Gland        10X
# GTTTGGACATTCTTCA_TSP4_Uterus_Endometrium_10X_1_1            Uterus        10X
# CGGCAGTTCCCTTGTG_TSP2_Vasculature_Aorta_10X_1_1        Vasculature        10X
# CCTATCGAGGCGATAC_TSP2_Vasculature_Aorta_10X_2_1        Vasculature        10X
# ...                                                            ...        ...
# TTCCGTGCACGTACAT_TSP1_bladder_1                            Bladder        10X
# AACCAACTCTAGTGTG_TSP10_FAT_SCAT_10X_1_1                        Fat        10X
# CAACCAATCCACCTCA_TSP14_Vasculature_CoronaryArte...     Vasculature        10X
# CTGCCTAAGGTGCAGT_TSP2_Vasculature_Aorta_10X_1_2        Vasculature        10X
# TSP7_Salivary_parotid_SS2_B134159_B133912_Epith...  Salivary_Gland  smartseq2
#
#                                                     donor  \
# AGATGCTTCATAAGGA_TSP2_Thymus_NA_10X_1_1              TSP2
# TGTAACGTCGGCTCTT_TSP14_SalivaryGland_Parotid_10...  TSP14
# GTTTGGACATTCTTCA_TSP4_Uterus_Endometrium_10X_1_1     TSP4
# CGGCAGTTCCCTTGTG_TSP2_Vasculature_Aorta_10X_1_1      TSP2
# CCTATCGAGGCGATAC_TSP2_Vasculature_Aorta_10X_2_1      TSP2
# ...                                                   ...
# TTCCGTGCACGTACAT_TSP1_bladder_1                      TSP1
# AACCAACTCTAGTGTG_TSP10_FAT_SCAT_10X_1_1             TSP10
# CAACCAATCCACCTCA_TSP14_Vasculature_CoronaryArte...  TSP14
# CTGCCTAAGGTGCAGT_TSP2_Vasculature_Aorta_10X_1_2      TSP2
# TSP7_Salivary_parotid_SS2_B134159_B133912_Epith...   TSP7
#
#                                                    anatomical_information  \
# AGATGCTTCATAAGGA_TSP2_Thymus_NA_10X_1_1                               nan
# TGTAACGTCGGCTCTT_TSP14_SalivaryGland_Parotid_10...                Parotid
# GTTTGGACATTCTTCA_TSP4_Uterus_Endometrium_10X_1_1              Endometrium
# CGGCAGTTCCCTTGTG_TSP2_Vasculature_Aorta_10X_1_1                     Aorta
# CCTATCGAGGCGATAC_TSP2_Vasculature_Aorta_10X_2_1                     Aorta
# ...                                                                   ...
# TTCCGTGCACGTACAT_TSP1_bladder_1                                       nan
# AACCAACTCTAGTGTG_TSP10_FAT_SCAT_10X_1_1                              SCAT
# CAACCAATCCACCTCA_TSP14_Vasculature_CoronaryArte...       CoronaryArteries
# CTGCCTAAGGTGCAGT_TSP2_Vasculature_Aorta_10X_1_2                     Aorta
# TSP7_Salivary_parotid_SS2_B134159_B133912_Epith...                Parotid
#
#                                                     n_counts_UMIs  n_genes  \
# AGATGCTTCATAAGGA_TSP2_Thymus_NA_10X_1_1                   10048.0     3323
# TGTAACGTCGGCTCTT_TSP14_SalivaryGland_Parotid_10...         3208.0     1226
# GTTTGGACATTCTTCA_TSP4_Uterus_Endometrium_10X_1_1           6766.0     2644
# CGGCAGTTCCCTTGTG_TSP2_Vasculature_Aorta_10X_1_1            2905.0     1294
# CCTATCGAGGCGATAC_TSP2_Vasculature_Aorta_10X_2_1           16290.0     3890
# ...                                                           ...      ...
# TTCCGTGCACGTACAT_TSP1_bladder_1                           12448.0     2992
# AACCAACTCTAGTGTG_TSP10_FAT_SCAT_10X_1_1                   11502.0     3212
# CAACCAATCCACCTCA_TSP14_Vasculature_CoronaryArte...         9086.0     2109
# CTGCCTAAGGTGCAGT_TSP2_Vasculature_Aorta_10X_1_2           15170.0     3878
# TSP7_Salivary_parotid_SS2_B134159_B133912_Epith...      1723561.0     2956
#
#                                                    cell_ontology_class  \
# AGATGCTTCATAAGGA_TSP2_Thymus_NA_10X_1_1                     fibroblast
# TGTAACGTCGGCTCTT_TSP14_SalivaryGland_Parotid_10...          fibroblast
# GTTTGGACATTCTTCA_TSP4_Uterus_Endometrium_10X_1_1            fibroblast
# CGGCAGTTCCCTTGTG_TSP2_Vasculature_Aorta_10X_1_1             fibroblast
# CCTATCGAGGCGATAC_TSP2_Vasculature_Aorta_10X_2_1             fibroblast
# ...                                                                ...
# TTCCGTGCACGTACAT_TSP1_bladder_1                             fibroblast
# AACCAACTCTAGTGTG_TSP10_FAT_SCAT_10X_1_1             myofibroblast cell
# CAACCAATCCACCTCA_TSP14_Vasculature_CoronaryArte...          fibroblast
# CTGCCTAAGGTGCAGT_TSP2_Vasculature_Aorta_10X_1_2             fibroblast
# TSP7_Salivary_parotid_SS2_B134159_B133912_Epith...          fibroblast
#
#                                                                     free_annotation  \
# AGATGCTTCATAAGGA_TSP2_Thymus_NA_10X_1_1                                  fibroblast
# TGTAACGTCGGCTCTT_TSP14_SalivaryGland_Parotid_10...                       Fibroblast
# GTTTGGACATTCTTCA_TSP4_Uterus_Endometrium_10X_1_1    Endometrial stromal fibbroblast
# CGGCAGTTCCCTTGTG_TSP2_Vasculature_Aorta_10X_1_1                          fibroblast
# CCTATCGAGGCGATAC_TSP2_Vasculature_Aorta_10X_2_1                          fibroblast
# ...                                                                             ...
# TTCCGTGCACGTACAT_TSP1_bladder_1                                          fibroblast
# AACCAACTCTAGTGTG_TSP10_FAT_SCAT_10X_1_1                              Myofibroblasts
# CAACCAATCCACCTCA_TSP14_Vasculature_CoronaryArte...                       fibroblast
# CTGCCTAAGGTGCAGT_TSP2_Vasculature_Aorta_10X_1_2                          fibroblast
# TSP7_Salivary_parotid_SS2_B134159_B133912_Epith...                       Fibroblast
#
#                                                     manually_annotated  \
# AGATGCTTCATAAGGA_TSP2_Thymus_NA_10X_1_1                           True
# TGTAACGTCGGCTCTT_TSP14_SalivaryGland_Parotid_10...                True
# GTTTGGACATTCTTCA_TSP4_Uterus_Endometrium_10X_1_1                  True
# CGGCAGTTCCCTTGTG_TSP2_Vasculature_Aorta_10X_1_1                   True
# CCTATCGAGGCGATAC_TSP2_Vasculature_Aorta_10X_2_1                   True
# ...                                                                ...
# TTCCGTGCACGTACAT_TSP1_bladder_1                                   True
# AACCAACTCTAGTGTG_TSP10_FAT_SCAT_10X_1_1                           True
# CAACCAATCCACCTCA_TSP14_Vasculature_CoronaryArte...                True
# CTGCCTAAGGTGCAGT_TSP2_Vasculature_Aorta_10X_1_2                   True
# TSP7_Salivary_parotid_SS2_B134159_B133912_Epith...                True
#
#                                                    compartment  gender    TF  \
# AGATGCTTCATAAGGA_TSP2_Thymus_NA_10X_1_1                stromal  female  None
# TGTAACGTCGGCTCTT_TSP14_SalivaryGland_Parotid_10...     stromal    male  None
# GTTTGGACATTCTTCA_TSP4_Uterus_Endometrium_10X_1_1       stromal  female  None
# CGGCAGTTCCCTTGTG_TSP2_Vasculature_Aorta_10X_1_1        stromal  female  None
# CCTATCGAGGCGATAC_TSP2_Vasculature_Aorta_10X_2_1        stromal  female  None
# ...                                                        ...     ...   ...
# TTCCGTGCACGTACAT_TSP1_bladder_1                        stromal  female  None
# AACCAACTCTAGTGTG_TSP10_FAT_SCAT_10X_1_1                stromal    male  None
# CAACCAATCCACCTCA_TSP14_Vasculature_CoronaryArte...     stromal    male  None
# CTGCCTAAGGTGCAGT_TSP2_Vasculature_Aorta_10X_1_2        stromal  female  None
# TSP7_Salivary_parotid_SS2_B134159_B133912_Epith...     stromal  female  None
#
#                                                     u
# AGATGCTTCATAAGGA_TSP2_Thymus_NA_10X_1_1             0
# TGTAACGTCGGCTCTT_TSP14_SalivaryGland_Parotid_10...  0
# GTTTGGACATTCTTCA_TSP4_Uterus_Endometrium_10X_1_1    0
# CGGCAGTTCCCTTGTG_TSP2_Vasculature_Aorta_10X_1_1     0
# CCTATCGAGGCGATAC_TSP2_Vasculature_Aorta_10X_2_1     0
# ...                                                ..
# TTCCGTGCACGTACAT_TSP1_bladder_1                     0
# AACCAACTCTAGTGTG_TSP10_FAT_SCAT_10X_1_1             0
# CAACCAATCCACCTCA_TSP14_Vasculature_CoronaryArte...  0
# CTGCCTAAGGTGCAGT_TSP2_Vasculature_Aorta_10X_1_2     0
# TSP7_Salivary_parotid_SS2_B134159_B133912_Epith...  0
#
# [1000 rows x 13 columns]

# %%
0 % 10
# Out:
# 0

# %%
# Create a copy of the AnnData object
adataFull = adata.copy()

# Define the perturbation values
U = [-1, -0.75, -0.5, -0.25, 0.25, 0.5, 0.75, 1, 1.25, 1.5]

# Calculate the maximum gene expression for each cell
maximumGeneExpression = np.max(adata.X, axis=1).toarray()[:, np.newaxis]

# Loop through the transcription factors in the dataframe
ctr = 0
for tfi, tf in enumerate(humanTfdf['Ensembl ID']):
    # Skip if it is not marked as a TF or if the TF is not found in the adata variable names
    if humanTfdf['Is TF?'].iloc[tfi] != 'Yes':
        continue
    if tf not in list(adata.var['ensemblid']):
        continue

    # Get the transcription factor index and expression
    tfIdx = list(adata.var['ensemblid']).index(tf)
    tfExpression = adata.X[:, tfIdx].copy()  # Copy the expression to avoid overwriting

    start_time = time.time()
    
    # Perturb the transcription factor expression for each value of U
    for u in U:
        # Make a fresh copy of the AnnData object for each perturbation
        adata_perturbed = adata.copy()

        # Apply the perturbation
        if u < 0:
            perturbedExpression = tfExpression - (u * tfExpression)
        else:
            perturbedExpression = u * maximumGeneExpression

        # Update the expression of the TF with the perturbed values
        adata_perturbed.X[:, tfIdx] = perturbedExpression
        adata_perturbed.obs['TF']   = tf
        adata_perturbed.obs['u']    = u
        
        # Concatenate the perturbed AnnData object to adataFull
        adataFull = adataFull.concatenate(adata_perturbed)
    
    print("time=" + str(time.time() - start_time))
    print(f"{ctr=}")
    ctr += 1


    if tfi % 5 == 0:
        # Save the full dataset with all perturbations
        adataFull.write("/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/all-tfs/jpic-Sep-26-2024.h5ad")

# Save the full dataset with all perturbations
adataFull.write("/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/all-tfs/jpic-Sep-26-2024.h5ad")
# Out:
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# time=1.6425261497497559
# ctr=0
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# time=2.4025962352752686
# ctr=1
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# time=3.150596857070923
# ctr=2
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# time=4.319546222686768
# ctr=3
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# time=5.694421768188477
# ctr=4
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# time=6.385369777679443
# ctr=5
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# time=7.613742351531982
# ctr=6
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# time=8.685608863830566
# ctr=7
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# time=10.004846572875977
# ctr=8
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# time=10.945104122161865
# ctr=9
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# time=12.066322326660156
# ctr=10
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# /tmp/ipykernel_3472526/3696715999.py:42: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adataFull = adataFull.concatenate(adata_perturbed)

# %%
adataFull.obs['batch']

# %%
adataFull = adata.copy()
U = [-1, -0.75, -0.5, -0.25, 0.25, 0.5, 0.75, 1, 1.25, 1.5]
for tfi, tf in enumerate(humanTfdf['Ensembl ID']):
    # skip the TF if either (1) it isnot a transcription factor or (2) it is not found in the dataframe
    if humanTfdf['Is TF?'].iloc[i] != 'Yes':
        continue
    if tf not in list(adata.var['ensemblid']):
        continue

    # Get the transcription factor location and expression
    tfIdx = list(adata.var['ensemblid']).index(tf)
    tfExpression = adata.X[:, tfIdx]
    for u in U:

        # Do perturbation of gene expression
        if u < 0:
            perturbedExpression = tfExpression - (u * tfExpression)
        else:
            perturbedExpression = u * maximumGeneExpression
        adata.X[:, tfIdx] = perturbedExpression

        
        adataFull = adataFull concatenated with adata.X.copy()
# Out:
#   Cell In[56], line 11
#
#     ^
# SyntaxError: incomplete input

# %%
1000*10*1600
# Out:
# 16000000

# %%
adata.layers
# Out:
# Layers with keys: decontXcounts, raw_counts

# %%
tfIdx = list(adata.var['ensemblid']).index(tf)

# %%
adata.layers['raw_counts'][:, tfIdx]
# Out:
# <1000x1 sparse matrix of type '<class 'numpy.float32'>'
# 	with 847 stored elements in Compressed Sparse Row format>

# %%
tfExpression = adata.layers['raw_counts'][:, tfIdx]

# %%
tfExpression = adata.X[:, tfIdx]

# %%
tfExpression.toarray()
# Out:
# array([[2.000e+00],
#        [9.000e+00],
#        [2.000e+01],
#        [9.000e+00],
#        [2.000e+00],
#        [4.900e+01],
#        [1.000e+01],
#        [6.000e+01],
#        [9.000e+00],
#        [3.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [2.000e+00],
#        [1.200e+01],
#        [3.000e+00],
#        [3.000e+00],
#        [1.000e+01],
#        [2.000e+00],
#        [3.000e+00],
#        [1.300e+01],
#        [7.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [2.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [6.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [1.900e+01],
#        [7.000e+00],
#        [1.000e+00],
#        [3.000e+00],
#        [2.000e+00],
#        [1.000e+00],
#        [1.300e+01],
#        [2.000e+00],
#        [9.000e+00],
#        [2.000e+00],
#        [2.000e+00],
#        [2.400e+01],
#        [1.400e+01],
#        [7.000e+00],
#        [1.500e+01],
#        [5.000e+00],
#        [1.000e+00],
#        [1.110e+02],
#        [8.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [6.000e+00],
#        [4.000e+00],
#        [0.000e+00],
#        [4.000e+00],
#        [8.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [7.000e+00],
#        [4.000e+00],
#        [9.000e+00],
#        [4.000e+00],
#        [0.000e+00],
#        [1.200e+01],
#        [2.000e+00],
#        [1.200e+01],
#        [2.800e+01],
#        [8.000e+00],
#        [6.000e+00],
#        [3.000e+00],
#        [2.000e+00],
#        [4.000e+00],
#        [1.000e+01],
#        [2.000e+00],
#        [8.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [7.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [6.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [8.000e+00],
#        [0.000e+00],
#        [1.000e+01],
#        [1.000e+00],
#        [4.000e+00],
#        [6.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [8.000e+00],
#        [1.100e+01],
#        [1.000e+01],
#        [0.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [9.000e+00],
#        [2.000e+00],
#        [5.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [1.400e+01],
#        [3.000e+00],
#        [7.000e+00],
#        [3.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [8.000e+00],
#        [2.000e+01],
#        [6.000e+00],
#        [2.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [1.300e+01],
#        [1.900e+01],
#        [1.000e+00],
#        [3.300e+01],
#        [5.000e+00],
#        [1.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [6.000e+00],
#        [7.000e+00],
#        [2.000e+00],
#        [5.000e+00],
#        [3.000e+00],
#        [8.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [1.600e+01],
#        [1.000e+00],
#        [1.100e+01],
#        [0.000e+00],
#        [0.000e+00],
#        [4.000e+00],
#        [6.000e+00],
#        [6.000e+00],
#        [3.000e+00],
#        [1.000e+01],
#        [1.000e+00],
#        [1.000e+00],
#        [7.000e+00],
#        [7.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [4.000e+00],
#        [3.000e+00],
#        [1.500e+01],
#        [3.000e+00],
#        [6.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [2.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [9.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [5.000e+00],
#        [4.000e+00],
#        [7.000e+00],
#        [0.000e+00],
#        [4.000e+00],
#        [2.000e+00],
#        [2.000e+00],
#        [8.000e+00],
#        [6.000e+00],
#        [2.670e+02],
#        [1.000e+00],
#        [0.000e+00],
#        [7.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [3.000e+00],
#        [9.000e+00],
#        [3.000e+00],
#        [5.000e+00],
#        [2.000e+00],
#        [1.000e+00],
#        [2.300e+01],
#        [5.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [4.000e+00],
#        [1.600e+01],
#        [1.600e+01],
#        [6.000e+00],
#        [1.000e+00],
#        [6.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [4.000e+00],
#        [8.000e+00],
#        [3.000e+00],
#        [7.000e+00],
#        [3.700e+01],
#        [2.100e+01],
#        [0.000e+00],
#        [1.000e+00],
#        [8.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [7.000e+00],
#        [4.000e+00],
#        [2.000e+00],
#        [3.000e+00],
#        [6.000e+00],
#        [4.000e+00],
#        [3.000e+00],
#        [2.200e+01],
#        [0.000e+00],
#        [1.000e+00],
#        [7.000e+00],
#        [0.000e+00],
#        [2.200e+01],
#        [5.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [4.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [7.000e+00],
#        [0.000e+00],
#        [8.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [7.000e+00],
#        [2.000e+00],
#        [3.000e+00],
#        [7.000e+00],
#        [5.000e+00],
#        [4.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [4.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [5.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [6.000e+00],
#        [2.077e+03],
#        [1.000e+00],
#        [7.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [4.000e+00],
#        [4.000e+00],
#        [6.000e+00],
#        [3.000e+00],
#        [3.000e+00],
#        [1.200e+01],
#        [2.000e+00],
#        [8.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [6.000e+00],
#        [1.000e+00],
#        [2.200e+01],
#        [1.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [2.400e+01],
#        [3.000e+00],
#        [5.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [3.000e+00],
#        [1.800e+01],
#        [3.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [7.000e+00],
#        [6.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [1.000e+01],
#        [3.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [3.000e+00],
#        [1.000e+01],
#        [1.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [2.000e+00],
#        [1.300e+01],
#        [2.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [1.000e+01],
#        [9.000e+00],
#        [1.000e+00],
#        [6.000e+00],
#        [1.000e+00],
#        [3.000e+00],
#        [8.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [9.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [4.000e+00],
#        [5.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [4.000e+00],
#        [5.000e+00],
#        [2.000e+00],
#        [5.000e+00],
#        [1.100e+01],
#        [1.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [1.000e+00],
#        [7.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [1.000e+01],
#        [2.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [9.000e+00],
#        [4.000e+00],
#        [1.000e+00],
#        [9.000e+00],
#        [5.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [8.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [2.000e+00],
#        [1.230e+02],
#        [0.000e+00],
#        [4.000e+00],
#        [2.000e+00],
#        [6.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [3.000e+00],
#        [1.600e+01],
#        [1.400e+01],
#        [5.000e+00],
#        [6.000e+00],
#        [1.100e+01],
#        [4.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [3.500e+01],
#        [0.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [1.500e+01],
#        [0.000e+00],
#        [5.000e+00],
#        [1.200e+01],
#        [5.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [2.400e+01],
#        [3.000e+00],
#        [0.000e+00],
#        [1.600e+01],
#        [1.100e+01],
#        [0.000e+00],
#        [7.000e+00],
#        [6.000e+00],
#        [4.000e+00],
#        [9.000e+00],
#        [3.000e+00],
#        [7.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [4.000e+00],
#        [3.000e+00],
#        [2.300e+01],
#        [1.100e+01],
#        [2.000e+00],
#        [5.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [3.000e+00],
#        [5.000e+00],
#        [5.000e+00],
#        [5.000e+00],
#        [7.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [3.000e+00],
#        [1.300e+01],
#        [3.000e+00],
#        [1.800e+01],
#        [1.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [6.000e+00],
#        [1.000e+00],
#        [3.000e+00],
#        [5.000e+00],
#        [1.400e+01],
#        [4.000e+00],
#        [1.000e+00],
#        [2.000e+01],
#        [2.000e+00],
#        [3.000e+00],
#        [2.000e+00],
#        [2.000e+00],
#        [3.000e+00],
#        [4.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [8.000e+00],
#        [2.360e+02],
#        [1.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [1.500e+01],
#        [1.000e+01],
#        [0.000e+00],
#        [7.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [1.400e+01],
#        [5.000e+00],
#        [5.000e+00],
#        [2.000e+00],
#        [2.500e+01],
#        [1.000e+00],
#        [6.000e+00],
#        [1.700e+01],
#        [6.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [4.000e+00],
#        [5.000e+01],
#        [0.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [3.000e+00],
#        [6.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [6.000e+00],
#        [1.100e+01],
#        [2.500e+01],
#        [0.000e+00],
#        [1.200e+01],
#        [3.000e+00],
#        [2.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [8.000e+00],
#        [0.000e+00],
#        [1.400e+01],
#        [1.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [3.000e+00],
#        [1.600e+01],
#        [5.000e+00],
#        [1.000e+01],
#        [6.000e+00],
#        [2.900e+01],
#        [0.000e+00],
#        [8.000e+00],
#        [4.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [4.000e+00],
#        [4.600e+01],
#        [0.000e+00],
#        [4.000e+00],
#        [1.700e+01],
#        [8.000e+00],
#        [4.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [7.000e+00],
#        [7.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [1.100e+01],
#        [1.200e+01],
#        [1.000e+00],
#        [5.000e+00],
#        [3.000e+00],
#        [3.900e+01],
#        [2.000e+00],
#        [1.000e+00],
#        [3.000e+00],
#        [2.000e+00],
#        [2.000e+00],
#        [6.000e+00],
#        [8.000e+00],
#        [1.500e+01],
#        [1.000e+00],
#        [6.000e+00],
#        [1.000e+00],
#        [7.000e+00],
#        [0.000e+00],
#        [1.100e+01],
#        [1.000e+00],
#        [1.600e+01],
#        [4.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [2.200e+01],
#        [5.000e+00],
#        [4.000e+00],
#        [0.000e+00],
#        [7.000e+00],
#        [8.000e+00],
#        [3.000e+00],
#        [3.000e+00],
#        [1.555e+03],
#        [1.000e+00],
#        [3.000e+00],
#        [5.000e+00],
#        [2.000e+00],
#        [8.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [1.000e+00],
#        [1.300e+01],
#        [1.000e+00],
#        [1.700e+01],
#        [4.000e+00],
#        [3.000e+00],
#        [1.800e+01],
#        [0.000e+00],
#        [1.000e+00],
#        [3.000e+00],
#        [9.000e+00],
#        [1.000e+00],
#        [7.000e+00],
#        [0.000e+00],
#        [1.300e+01],
#        [5.000e+00],
#        [5.000e+00],
#        [6.960e+02],
#        [5.000e+00],
#        [0.000e+00],
#        [4.000e+00],
#        [1.000e+00],
#        [3.000e+00],
#        [5.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [1.300e+01],
#        [0.000e+00],
#        [1.000e+00],
#        [7.000e+00],
#        [4.000e+00],
#        [2.000e+00],
#        [9.000e+00],
#        [3.000e+00],
#        [1.300e+01],
#        [5.000e+01],
#        [5.000e+00],
#        [4.000e+00],
#        [4.000e+00],
#        [2.100e+01],
#        [1.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [5.840e+02],
#        [3.000e+00],
#        [2.000e+00],
#        [4.000e+00],
#        [4.000e+00],
#        [3.000e+00],
#        [8.000e+00],
#        [1.400e+01],
#        [1.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [6.000e+00],
#        [6.000e+00],
#        [1.000e+00],
#        [1.000e+01],
#        [7.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [2.100e+01],
#        [5.000e+00],
#        [6.000e+00],
#        [6.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [5.000e+00],
#        [3.000e+00],
#        [1.000e+01],
#        [6.000e+00],
#        [7.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [8.700e+01],
#        [6.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [3.000e+00],
#        [4.000e+00],
#        [3.000e+00],
#        [1.100e+01],
#        [4.000e+00],
#        [3.000e+00],
#        [6.000e+00],
#        [2.000e+00],
#        [4.000e+00],
#        [5.000e+00],
#        [1.200e+01],
#        [1.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [9.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [1.100e+01],
#        [0.000e+00],
#        [1.400e+01],
#        [1.000e+00],
#        [2.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [4.000e+00],
#        [3.000e+00],
#        [3.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [7.800e+01],
#        [1.300e+01],
#        [1.000e+00],
#        [5.000e+00],
#        [5.000e+00],
#        [8.000e+00],
#        [1.200e+01],
#        [3.000e+00],
#        [1.800e+01],
#        [3.000e+00],
#        [2.000e+00],
#        [2.600e+01],
#        [3.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [6.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [6.000e+00],
#        [1.100e+01],
#        [2.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [5.000e+00],
#        [6.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [1.100e+01],
#        [1.300e+01],
#        [5.000e+00],
#        [5.000e+00],
#        [2.000e+00],
#        [2.200e+01],
#        [0.000e+00],
#        [5.000e+00],
#        [1.000e+01],
#        [0.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [3.000e+00],
#        [4.600e+01],
#        [5.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [1.300e+01],
#        [5.000e+00],
#        [2.000e+00],
#        [9.000e+00],
#        [7.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [5.000e+00],
#        [0.000e+00],
#        [8.000e+00],
#        [7.000e+00],
#        [1.500e+01],
#        [3.000e+01],
#        [1.600e+01],
#        [3.000e+00],
#        [7.000e+00],
#        [8.000e+00],
#        [1.100e+01],
#        [1.000e+00],
#        [2.000e+00],
#        [7.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [0.000e+00],
#        [5.000e+00],
#        [5.000e+00],
#        [0.000e+00],
#        [1.040e+02],
#        [1.000e+00],
#        [4.000e+00],
#        [2.000e+00],
#        [4.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [1.300e+01],
#        [0.000e+00],
#        [0.000e+00],
#        [6.000e+00],
#        [3.000e+00],
#        [3.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [9.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [4.000e+00],
#        [7.000e+00],
#        [1.200e+01],
#        [5.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [2.000e+00],
#        [4.000e+00],
#        [3.000e+00],
#        [2.000e+00],
#        [4.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [7.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [2.000e+00],
#        [3.210e+03],
#        [0.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [5.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [6.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [7.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [6.700e+01],
#        [6.000e+00],
#        [9.000e+00],
#        [9.000e+00],
#        [0.000e+00],
#        [4.000e+00],
#        [2.000e+00],
#        [3.000e+00],
#        [1.400e+01],
#        [0.000e+00],
#        [6.000e+00],
#        [2.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [7.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [1.000e+00],
#        [1.300e+01],
#        [1.800e+01],
#        [4.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [3.000e+00],
#        [8.000e+00],
#        [3.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [8.000e+00],
#        [7.000e+00],
#        [1.000e+00],
#        [6.000e+00],
#        [2.000e+00],
#        [5.000e+00],
#        [1.400e+01],
#        [1.000e+00],
#        [7.000e+00],
#        [4.600e+01],
#        [9.000e+00],
#        [0.000e+00],
#        [6.000e+00],
#        [1.000e+01],
#        [0.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [4.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [9.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [4.000e+00],
#        [1.000e+00],
#        [1.700e+01],
#        [7.000e+00],
#        [1.000e+00],
#        [1.000e+00],
#        [2.000e+00],
#        [2.000e+00],
#        [1.400e+01],
#        [0.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [5.000e+00],
#        [5.000e+00],
#        [2.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [0.000e+00],
#        [8.000e+00],
#        [8.000e+00],
#        [6.000e+00],
#        [0.000e+00],
#        [3.000e+00],
#        [0.000e+00],
#        [6.000e+00],
#        [2.000e+00],
#        [1.000e+01],
#        [3.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [6.000e+00],
#        [1.300e+01],
#        [3.000e+00],
#        [3.000e+00],
#        [6.000e+00],
#        [5.000e+00],
#        [2.960e+02],
#        [6.000e+00],
#        [0.000e+00],
#        [6.000e+00],
#        [1.000e+00],
#        [5.000e+00],
#        [3.000e+00],
#        [2.000e+00],
#        [5.000e+00],
#        [0.000e+00],
#        [1.000e+01],
#        [4.000e+00],
#        [7.000e+00],
#        [1.000e+00],
#        [4.000e+00],
#        [5.000e+00],
#        [1.000e+00],
#        [3.000e+00],
#        [3.000e+00],
#        [1.000e+00],
#        [0.000e+00],
#        [1.000e+01],
#        [3.000e+00],
#        [4.000e+00],
#        [4.000e+00],
#        [1.100e+01],
#        [2.000e+00],
#        [2.000e+00],
#        [0.000e+00],
#        [3.000e+00]], dtype=float32)

# %% [markdown]
# # Embeddings
