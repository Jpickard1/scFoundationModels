# %% [markdown]
# # Reprogramming Recepies
#
# Auth: [Joshua Pickard](jpic@umich.edu)
#
# Date: August 26, 2024

# %% [markdown]
# # Day 8
#
# Generatting the perturbation files

# %% [markdown]
# ## Set up

# %%
import numpy as np
import anndata as ad
import pandas as pd
import scanpy as sp
import os

def iterate_perturb_counts(adata, tf_list, scalar_list):
    """
    Applies perturbations to the expression data of specified transcription factors across multiple scalars 
    and stores the resulting AnnData objects in a dictionary.

    This function performs the following steps:
    1. Iterates over a list of scalar values.
    2. For each scalar, creates a copy of the AnnData object to preserve the original data.
    3. Applies the `perturb_counts` function to scale the expression data of genes listed in `tf_list` by
       the maximum gene expression of each cell and the current scalar.
    4. Stores the perturbed AnnData object in a dictionary with the scalar as the key.

    Parameters:
    tf_list (list): A list of gene symbols (transcription factors) to be perturbed.
    scalar_list (list): A list of scalar values for scaling the gene expression.
    adata (AnnData): The AnnData object containing gene expression data (cells x genes).

    Returns:
    dict: A dictionary where keys are scalar values and values are the corresponding perturbed AnnData objects.
    """
    
    adata_dict = {}
    
    for scalar in scalar_list:
        # Create a copy of the AnnData object for each scalar value
        adata_temp = adata.copy()
        
        # Apply perturb_counts to the copied AnnData object
        perturbed_adata = perturb_counts(adata_temp, tf_list, scalar)
        
        # Store the perturbed AnnData object in the dictionary with scalar as the key
        adata_dict[scalar] = perturbed_adata
    
    return adata_dict

def perturb_counts(adata, tf_list, scalar): 
    """
    Applies a perturbation to the expression data of specific genes in an AnnData object.

    This function performs the following steps:
    1. Computes the maximum gene expression level for each cell.
    2. Applies a scaling operation to the expression levels of genes listed in `tf_list`.
       - Each entry of these genes in the matrix is multiplied by the maximum expression level 
         of its respective cell and a specified scalar value.
    3. Updates the AnnData object with new columns:
       - 'scaled': A boolean column indicating whether each gene is in the `tf_list`.
       - 'scaled_by': Contains the scaling factor used for each gene (the product of the maximum 
         expression level of each cell and the scalar), or `1` if the gene was not in `tf_list`.
    
    Parameters:
    tf_list (list): A list of gene symbols to be perturbed.
    scalar (float): The scalar value used to scale the expression levels.
    adata (AnnData): The AnnData object containing gene expression data.

    Returns:
    AnnData: The updated AnnData object with applied perturbations and new columns.
    """

    # Create a boolean mask for genes in tf_list
    gene_mask = adata.var['gene_symbol'].isin(tf_list)
    
    # Save the original state of the parameter objects, in case some tfs do not translate (failsafe)
    original_X = adata.X.copy()
    original_gene_mask = gene_mask.copy()
    
    # Compute maximum expression level of each cell
    max_exp = np.max(adata.X, axis=1)

    """This is new today. v """
    # Raise an error if any of the gene names in tf_list do not match column names (we will manually update these in adata):
    missing_genes = [gene for gene in tf_list if gene not in adata.var['gene_symbol'].values]
    
    if missing_genes:
        # Restore original parameter objects
        adata.X = original_X
        gene_mask = original_gene_mask
        raise ValueError(f"Genes {missing_genes} not found in anndata object")

    else:    
        
        # Apply the scaling operation to the specified genes
        adata.X[:, gene_mask] = max_exp * scalar
        
        # Add/Update 'scaled' column in var
        adata.var['scaled'] = gene_mask
        
        # Add/Update 'scaled_by' column in var
        adata.var['scaled_by'] = scalar  # Default value for genes not in tf_list

        # Add/Update 'scaled_by' column in var
        adata.obs['U'] = scalar  # Default value for genes not in tf_list
    # adata.var = 
    return adata

def validateTFs(TFs, adata):
    adata_gene_list = adata.var['gene_symbol'].values.tolist()
    for TF in TFs:
        if TF not in adata_gene_list:
            return False
    return True

# %% [markdown]
# ## Load Data

# %%
# Load reprogramming recipes
df = pd.read_csv('data/recipe_table_9_6_2024.csv')
df.head()

# Load firboblast source cells
DATAPATH = "/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/unperturbed"
FILE = "fibroblast.h5ad"
adata = sp.read_h5ad(os.path.join(DATAPATH, FILE))
adata_gene_list = adata.var['gene_symbol'].values.tolist()

# %% [markdown]
# ## Make Files

# %%
output_directory = "/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed"
scalars = [0.5, 0.75, 1.001]
for i in range(len(df['TFs'])):
    val = df['TFs'].iloc[i]
    TFs = val.split()
    if validateTFs(TFs, adata):

        # Join the TFs list into a string for the filename
        TFs_str = "_".join(TFs)
        
        # Generate the file path for saving
        file_name = f"{TFs_str}.h5ad"
        output_path = os.path.join(output_directory, file_name)

        # Check if the file already exists
        if os.path.exists(output_path):
            print(output_path + " already exist: continue!")
            continue
        
        print(TFs)
        adataDict = iterate_perturb_counts(adata.copy(), TFs, scalars)

        # Concatenate all AnnData objects along the observations axis
        concatenated_adata = ad.concat(list(adataDict.values()), axis=0)

        # This is the line was added today to fix the bug
        concatenated_adata.var = adata.var.copy()

        # Save reprogramming metadata into the concatenated_adata.obs table
        concatenated_adata.obs['Source_cells'] = df['Source cells'].iloc[i]
        concatenated_adata.obs['Target_cells'] = df['Target cells'].iloc[i]
        concatenated_adata.obs['Treatment'] = df['Treatment'].iloc[i]
        concatenated_adata.obs['Species'] = df['Species'].iloc[i]
        concatenated_adata.obs['Cell_Transplantation'] = df['Cell Transplantation'].iloc[i]
        concatenated_adata.obs['Published_Year'] = df['Published Year'].iloc[i]
        concatenated_adata.obs['PMID'] = df['PMID'].iloc[i]
        
        # Save the concatenated AnnData object to the file
        concatenated_adata.write_h5ad(output_path)
        print("    file created")

print('All recipes complete!')
# Out:
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/ASCL1_POU3F2_MYT1L_LMX1A_FOXA2.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/SOX2.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/NEUROG2_SOX11_ISL1_LHX3.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/SOX2_HMGA2.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/ASCL1_PAX6.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/SOX2_PAX6.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/PTF1A.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/SOX2_ASCL1_NEUROG2.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/ASCL1_SOX2.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/FOXM1_SOX2_MYC_SALL4_STAT6.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/AR_SOX2_SMAD3_MYC_JUN_WT1_TAL1_SPI1_RUNX1.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/POU3F2_SOX2_BACH1_AR_PBX1_NANOG.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/MSI1_NEUROG2_MBD2.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/GATA4_MEF2C_TBX5_MESP1_MYOCD.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/GATA4_MEF2C_TBX5_ESRRG_MESP1_ZFPM2_MYOCD.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/ATF5_PROX1_FOXA2_FOXA3_HNF4A.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/PDX1_PAX4_MAFA.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/NFE2_MAFG_MAFK.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/SPI1_IRF8_BATF3.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/MYC_KLF4_SOX9.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/MYOD1_MYCL.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/PRDM16_CEBPB.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/CRX_RAX_NEUROD1.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/MITF_SOX10_PAX3.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/SOX18.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/CRX_RAX_OTX2_NEUROD1.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/NFKB1_LEF1.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/EMX2_HNF1B_HNF4A_PAX8.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/MYOCD.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/ETV2.h5ad already exist: continue!
# /nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/PPARG.h5ad already exist: continue!
# ['HNF4A', 'FOXA3', 'GATA6', 'CDX2']
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#     file created
# ['MYOCD', 'GATA6', 'MEF2C']
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#     file created
# ['SNAI2', 'EYA1', 'SIX1']
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#     file created
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       3 for i in range(len(df['TFs'])):
#       4     val = df['TFs'].iloc[i]
# ----> 5     TFs = val.split()
#       6     if validateTFs(TFs, adata):
#       7
#       8         # Join the TFs list into a string for the filename
#       9         TFs_str = "_".join(TFs)
#
# AttributeError: 'float' object has no attribute 'split'

# %%
df['TFs']
# Out:
# 0                                     ASCL1 LXMLA NR4A2
# 1                           POU3F2 ASCL1 MYT1L NEUROD11
# 2                        ASCL1 POU3F2 MYT1L LMX1A FOXA2
# 3                                                  SOX2
# 4                    ASCL1 NEUROG2 SOX2 NR4A2 PITX3 P53
# 5                               NEUROG2 SOX11 ISL1 LHX3
# 6                                            SOX2 HMGA2
# 7                                            ASCL1 PAX6
# 8                           POU3F2 ASCL1 MYT1L NEUROD11
# 9     ASCL1 ISL1 NEUROD11 POU3F2 MNX1 LHX3 MYT1L NEU...
# 10                                  SOX2 GATA3 NEUROD11
# 11                                            SOX2 PAX6
# 12                                                PTF1A
# 13        SOX2; SOX2 PAX6; SOX2 LMX1A; SOX2 LMX1A FOXA2
# 14                                   SOX2 ASCL1 NEUROG2
# 15                                           ASCL1 SOX2
# 16                           FOXM1 SOX2 MYC SALL4 STAT6
# 17            AR SOX2 SMAD3 MYC JUN WT1 TAL1 SPI1 RUNX1
# 18                      POU3F2 SOX2 BACH1 AR PBX1 NANOG
# 19     ASCL1  PHOX2B  AP-2A  GATA3  HAND2  NR4A2 PHOX2A
# 20                                    MSI1 NEUROG2 MBD2
# 21                         GATA4 MEF2C TBX5 MESP1 MYOCD
# 22             GATA4 MEF2C TBX5 ESRRG MESP1 ZFPM2 MYOCD
# 23     HNF1A HNF4A ONECUT1 ATF5 PROX1 CEBPA; MYC + TP53
# 24            FOXA3 HNF1A  HNF4A + SV40 Large T Antigen
# 25    HNF1A FOXA1 FOXA3; HNF1A FOXA1 HNF4A; HNF1A FO...
# 26                         ATF5 PROX1 FOXA2 FOXA3 HNF4A
# 27                               OCT4 FOXA2 HNF1A GATA3
# 28                                       PDX1 PAX4 MAFA
# 29                                       NFE2 MAFG MAFK
# 30                                      SPI1 IRF8 BATF3
# 31                                        MYC KLF4 SOX9
# 32    POU5F1 OCT6; POU3F4 MYCL; POU3F4 MYC; POU3F4 MYCN
# 33                            RUNX2  OCT4  OSTERIX MYCL
# 34                                   OCT4  OSTERIX MYCL
# 35                                           MYOD1 MYCL
# 36                                         PRDM16 CEBPB
# 37                                     CRX  RAX NEUROD1
# 38                                     MITF  SOX10 PAX3
# 39                                                SOX18
# 40                               CRX  RAX  OTX2 NEUROD1
# 41                                           NFKB1 LEF1
# 42                                                 OCT4
# 43                              EMX2  HNF1B  HNF4A PAX8
# 44                                                MYOCD
# 45                                                 ETV2
# 46                                                PPARG
# 47                             HNF4A  FOXA3  GATA6 CDX2
# 48                                   MYOCD  GATA6 MEF2C
# 49                                     SNAI2  EYA1 SIX1
# 50                                                  NaN
# 51                                                  NaN
# 52                                                  NaN
# 53                                                  NaN
# Name: TFs, dtype: object

# %% [markdown]
# ## Debug

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 38151 × 58870
#     obs: 'organ_tissue', 'method', 'donor', 'anatomical_information', 'n_counts_UMIs', 'n_genes', 'cell_ontology_class', 'free_annotation', 'manually_annotated', 'compartment', 'gender'
#     var: 'gene_symbol', 'feature_type', 'ensemblid', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: '_scvi', '_training_mode', 'dendrogram_cell_type_tissue', 'dendrogram_computational_compartment_assignment', 'dendrogram_consensus_prediction', 'dendrogram_tissue_cell_type', 'donor_colors', 'donor_method_colors', 'hvg', 'method_colors', 'neighbors', 'organ_tissue_colors', 'sex_colors', 'tissue_colors', 'umap'
#     obsm: 'X_pca', 'X_scvi', 'X_scvi_umap', 'X_umap'
#     layers: 'decontXcounts', 'raw_counts'
#     obsp: 'connectivities', 'distances'

# %%
adata.var
# Out:
#              gene_symbol     feature_type          ensemblid  highly_variable  \
# DDX11L1          DDX11L1  Gene Expression  ENSG00000223972.5            False
# WASH7P            WASH7P  Gene Expression  ENSG00000227232.5            False
# MIR6859-1      MIR6859-1  Gene Expression  ENSG00000278267.1            False
# MIR1302-2HG  MIR1302-2HG  Gene Expression  ENSG00000243485.5            False
# MIR1302-2      MIR1302-2  Gene Expression  ENSG00000284332.1            False
# ...                  ...              ...                ...              ...
# MT-ND6            MT-ND6  Gene Expression  ENSG00000198695.2            False
# MT-TE              MT-TE  Gene Expression  ENSG00000210194.1            False
# MT-CYB            MT-CYB  Gene Expression  ENSG00000198727.2            False
# MT-TT              MT-TT  Gene Expression  ENSG00000210195.2            False
# MT-TP              MT-TP  Gene Expression  ENSG00000210196.2             True
#
#                     means  dispersions  dispersions_norm      mean       std
# DDX11L1      6.398244e-05     0.835044         -0.573947  0.000039  0.005574
# WASH7P       2.274395e-03     2.442280          0.533203  0.001080  0.031731
# MIR6859-1    6.175251e-05     1.295335         -0.256874  0.000033  0.005634
# MIR1302-2HG  1.372886e-04     2.656352          0.680668  0.000048  0.008041
# MIR1302-2    1.000000e-12          NaN          0.000000  0.000000  1.000000
# ...                   ...          ...               ...       ...       ...
# MT-ND6       9.634841e-01     2.466404          0.154140  0.590065  0.741395
# MT-TE        1.600667e-01     1.603787         -0.044396  0.083929  0.301820
# MT-CYB       4.367693e+00     4.765751         -0.499747  3.874830  1.104192
# MT-TT        6.573967e-02     0.624316         -0.719108  0.040580  0.186848
# MT-TP        4.385102e-01     2.705558          1.115482  0.204806  0.501265
#
# [58870 rows x 9 columns]

# %%
padata = perturb_counts(adata, ['DDX11L1'], 1)
# Out:
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)

# %%
concatenated_adata = ad.concat([adata, padata], axis=0)
concatenated_adata.var = adata.var.copy()
concatenated_adata.var
# Out:
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#              gene_symbol     feature_type          ensemblid  highly_variable  \
# DDX11L1          DDX11L1  Gene Expression  ENSG00000223972.5            False
# WASH7P            WASH7P  Gene Expression  ENSG00000227232.5            False
# MIR6859-1      MIR6859-1  Gene Expression  ENSG00000278267.1            False
# MIR1302-2HG  MIR1302-2HG  Gene Expression  ENSG00000243485.5            False
# MIR1302-2      MIR1302-2  Gene Expression  ENSG00000284332.1            False
# ...                  ...              ...                ...              ...
# MT-ND6            MT-ND6  Gene Expression  ENSG00000198695.2            False
# MT-TE              MT-TE  Gene Expression  ENSG00000210194.1            False
# MT-CYB            MT-CYB  Gene Expression  ENSG00000198727.2            False
# MT-TT              MT-TT  Gene Expression  ENSG00000210195.2            False
# MT-TP              MT-TP  Gene Expression  ENSG00000210196.2             True
#
#                     means  dispersions  dispersions_norm      mean       std  \
# DDX11L1      6.398244e-05     0.835044         -0.573947  0.000039  0.005574
# WASH7P       2.274395e-03     2.442280          0.533203  0.001080  0.031731
# MIR6859-1    6.175251e-05     1.295335         -0.256874  0.000033  0.005634
# MIR1302-2HG  1.372886e-04     2.656352          0.680668  0.000048  0.008041
# MIR1302-2    1.000000e-12          NaN          0.000000  0.000000  1.000000
# ...                   ...          ...               ...       ...       ...
# MT-ND6       9.634841e-01     2.466404          0.154140  0.590065  0.741395
# MT-TE        1.600667e-01     1.603787         -0.044396  0.083929  0.301820
# MT-CYB       4.367693e+00     4.765751         -0.499747  3.874830  1.104192
# MT-TT        6.573967e-02     0.624316         -0.719108  0.040580  0.186848
# MT-TP        4.385102e-01     2.705558          1.115482  0.204806  0.501265
#
#              scaled  scaled_by
# DDX11L1        True          1
# WASH7P        False          1
# MIR6859-1     False          1
# MIR1302-2HG   False          1
# MIR1302-2     False          1
# ...             ...        ...
# MT-ND6        False          1
# MT-TE         False          1
# MT-CYB        False          1
# MT-TT         False          1
# MT-TP         False          1
#
# [58870 rows x 11 columns]

# %%
adata.var
# Out:
#              gene_symbol     feature_type          ensemblid  highly_variable  \
# DDX11L1          DDX11L1  Gene Expression  ENSG00000223972.5            False
# WASH7P            WASH7P  Gene Expression  ENSG00000227232.5            False
# MIR6859-1      MIR6859-1  Gene Expression  ENSG00000278267.1            False
# MIR1302-2HG  MIR1302-2HG  Gene Expression  ENSG00000243485.5            False
# MIR1302-2      MIR1302-2  Gene Expression  ENSG00000284332.1            False
# ...                  ...              ...                ...              ...
# MT-ND6            MT-ND6  Gene Expression  ENSG00000198695.2            False
# MT-TE              MT-TE  Gene Expression  ENSG00000210194.1            False
# MT-CYB            MT-CYB  Gene Expression  ENSG00000198727.2            False
# MT-TT              MT-TT  Gene Expression  ENSG00000210195.2            False
# MT-TP              MT-TP  Gene Expression  ENSG00000210196.2             True
#
#                     means  dispersions  dispersions_norm      mean       std  \
# DDX11L1      6.398244e-05     0.835044         -0.573947  0.000039  0.005574
# WASH7P       2.274395e-03     2.442280          0.533203  0.001080  0.031731
# MIR6859-1    6.175251e-05     1.295335         -0.256874  0.000033  0.005634
# MIR1302-2HG  1.372886e-04     2.656352          0.680668  0.000048  0.008041
# MIR1302-2    1.000000e-12          NaN          0.000000  0.000000  1.000000
# ...                   ...          ...               ...       ...       ...
# MT-ND6       9.634841e-01     2.466404          0.154140  0.590065  0.741395
# MT-TE        1.600667e-01     1.603787         -0.044396  0.083929  0.301820
# MT-CYB       4.367693e+00     4.765751         -0.499747  3.874830  1.104192
# MT-TT        6.573967e-02     0.624316         -0.719108  0.040580  0.186848
# MT-TP        4.385102e-01     2.705558          1.115482  0.204806  0.501265
#
#              scaled  scaled_by
# DDX11L1        True          1
# WASH7P        False          1
# MIR6859-1     False          1
# MIR1302-2HG   False          1
# MIR1302-2     False          1
# ...             ...        ...
# MT-ND6        False          1
# MT-TE         False          1
# MT-CYB        False          1
# MT-TT         False          1
# MT-TP         False          1
#
# [58870 rows x 11 columns]

# %%
concatenated_adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [DDX11L1, WASH7P, MIR6859-1, MIR1302-2HG, MIR1302-2, FAM138A, OR4G4P, OR4G11P, OR4F5, AL627309.1, AL627309.3, CICP27, AL627309.6, AL627309.7, AL627309.2, AL627309.5, RNU6-1100P, AL627309.4, FO538757.1, WASH9P, MIR6859-2, AP006222.1, RPL23AP24, AL732372.1, AL732372.2, WBP1LP7, OR4F29, CICP7, AL732372.3, RF00026, AL669831.3, AC114498.1, MTND1P23, MTND2P28, MTCO1P12, AC114498.2, MTCO2P12, MTATP8P1, MTATP6P1, MTCO3P12, WBP1LP6, OR4F16, CICP3, AL669831.1, RNU6-1199P, AL669831.2, AL669831.5, AL669831.7, AL669831.4, FAM87B, LINC01128, LINC00115, FAM41C, TUBB8P11, AL669831.6, AL645608.6, AL645608.2, AL645608.4, LINC02593, SAMD11, NOC2L, KLHL17, PLEKHN1, PERM1, AL645608.7, HES4, ISG15, AL645608.3, AL645608.1, AGRN, AL645608.5, AL390719.1, AL645608.8, RNF223, C1orf159, AL390719.3, LINC01342, MIR200B, MIR200A, MIR429, AL390719.2, TTLL10-AS1, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, C1QTNF12, AL162741.1, UBE2J2, LINC01786, SCNN1D, ACAP3, MIR6726, PUSL1, INTS11, MIR6727, AL139287.1, CPTP, TAS1R3, ...]
#
# [58870 rows x 0 columns]

# %%
padata.var
# Out:
#              gene_symbol     feature_type          ensemblid  highly_variable  \
# DDX11L1          DDX11L1  Gene Expression  ENSG00000223972.5            False
# WASH7P            WASH7P  Gene Expression  ENSG00000227232.5            False
# MIR6859-1      MIR6859-1  Gene Expression  ENSG00000278267.1            False
# MIR1302-2HG  MIR1302-2HG  Gene Expression  ENSG00000243485.5            False
# MIR1302-2      MIR1302-2  Gene Expression  ENSG00000284332.1            False
# ...                  ...              ...                ...              ...
# MT-ND6            MT-ND6  Gene Expression  ENSG00000198695.2            False
# MT-TE              MT-TE  Gene Expression  ENSG00000210194.1            False
# MT-CYB            MT-CYB  Gene Expression  ENSG00000198727.2            False
# MT-TT              MT-TT  Gene Expression  ENSG00000210195.2            False
# MT-TP              MT-TP  Gene Expression  ENSG00000210196.2             True
#
#                     means  dispersions  dispersions_norm      mean       std  \
# DDX11L1      6.398244e-05     0.835044         -0.573947  0.000039  0.005574
# WASH7P       2.274395e-03     2.442280          0.533203  0.001080  0.031731
# MIR6859-1    6.175251e-05     1.295335         -0.256874  0.000033  0.005634
# MIR1302-2HG  1.372886e-04     2.656352          0.680668  0.000048  0.008041
# MIR1302-2    1.000000e-12          NaN          0.000000  0.000000  1.000000
# ...                   ...          ...               ...       ...       ...
# MT-ND6       9.634841e-01     2.466404          0.154140  0.590065  0.741395
# MT-TE        1.600667e-01     1.603787         -0.044396  0.083929  0.301820
# MT-CYB       4.367693e+00     4.765751         -0.499747  3.874830  1.104192
# MT-TT        6.573967e-02     0.624316         -0.719108  0.040580  0.186848
# MT-TP        4.385102e-01     2.705558          1.115482  0.204806  0.501265
#
#              scaled  scaled_by
# DDX11L1        True          1
# WASH7P        False          1
# MIR6859-1     False          1
# MIR1302-2HG   False          1
# MIR1302-2     False          1
# ...             ...        ...
# MT-ND6        False          1
# MT-TE         False          1
# MT-CYB        False          1
# MT-TT         False          1
# MT-TP         False          1
#
# [58870 rows x 11 columns]

# %% [markdown]
# # Day 7
#
# Nat says the Reproramming recipes should work

# %% [markdown]
# ## Set up

# %%
import numpy as np
import anndata as ad
import pandas as pd
import scanpy as sp
import os

# %%
def iterate_perturb_counts(adata, tf_list, scalar_list):
    """
    Applies perturbations to the expression data of specified transcription factors across multiple scalars 
    and stores the resulting AnnData objects in a dictionary.

    This function performs the following steps:
    1. Iterates over a list of scalar values.
    2. For each scalar, creates a copy of the AnnData object to preserve the original data.
    3. Applies the `perturb_counts` function to scale the expression data of genes listed in `tf_list` by
       the maximum gene expression of each cell and the current scalar.
    4. Stores the perturbed AnnData object in a dictionary with the scalar as the key.

    Parameters:
    tf_list (list): A list of gene symbols (transcription factors) to be perturbed.
    scalar_list (list): A list of scalar values for scaling the gene expression.
    adata (AnnData): The AnnData object containing gene expression data (cells x genes).

    Returns:
    dict: A dictionary where keys are scalar values and values are the corresponding perturbed AnnData objects.
    """
    
    adata_dict = {}
    
    for scalar in scalar_list:
        # Create a copy of the AnnData object for each scalar value
        adata_temp = adata.copy()
        
        # Apply perturb_counts to the copied AnnData object
        perturbed_adata = perturb_counts(adata_temp, tf_list, scalar)
        
        # Store the perturbed AnnData object in the dictionary with scalar as the key
        adata_dict[scalar] = perturbed_adata
    
    return adata_dict

def perturb_counts(adata, tf_list, scalar): 
    """
    Applies a perturbation to the expression data of specific genes in an AnnData object.

    This function performs the following steps:
    1. Computes the maximum gene expression level for each cell.
    2. Applies a scaling operation to the expression levels of genes listed in `tf_list`.
       - Each entry of these genes in the matrix is multiplied by the maximum expression level 
         of its respective cell and a specified scalar value.
    3. Updates the AnnData object with new columns:
       - 'scaled': A boolean column indicating whether each gene is in the `tf_list`.
       - 'scaled_by': Contains the scaling factor used for each gene (the product of the maximum 
         expression level of each cell and the scalar), or `1` if the gene was not in `tf_list`.
    
    Parameters:
    tf_list (list): A list of gene symbols to be perturbed.
    scalar (float): The scalar value used to scale the expression levels.
    adata (AnnData): The AnnData object containing gene expression data.

    Returns:
    AnnData: The updated AnnData object with applied perturbations and new columns.
    """

    # Create a boolean mask for genes in tf_list
    gene_mask = adata.var['gene_symbol'].isin(tf_list)
    
    # Save the original state of the parameter objects, in case some tfs do not translate (failsafe)
    original_X = adata.X.copy()
    original_gene_mask = gene_mask.copy()
    
    # Compute maximum expression level of each cell
    max_exp = np.max(adata.X, axis=1)

    """This is new today. v """
    # Raise an error if any of the gene names in tf_list do not match column names (we will manually update these in adata):
    missing_genes = [gene for gene in tf_list if gene not in adata.var['gene_symbol'].values]
    
    if missing_genes:
        # Restore original parameter objects
        adata.X = original_X
        gene_mask = original_gene_mask
        raise ValueError(f"Genes {missing_genes} not found in anndata object")

    else:    
        
        # Apply the scaling operation to the specified genes
        adata.X[:, gene_mask] = max_exp * scalar
        
        # Add/Update 'scaled' column in var
        adata.var['scaled'] = gene_mask
        
        # Add/Update 'scaled_by' column in var
        adata.var['scaled_by'] = scalar  # Default value for genes not in tf_list

        # Add/Update 'scaled_by' column in var
        adata.obs['U'] = scalar  # Default value for genes not in tf_list
    # adata.var = 
    return adata

def validateTFs(TFs, adata):
    adata_gene_list = adata.var['gene_symbol'].values.tolist()
    for TF in TFs:
        if TF not in adata_gene_list:
            return False
    return True

# %% [markdown]
# ## Validate Recipes

# %%
DATAPATH = "/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/jpic/"
FILE = "fibroblast.h5ad"
adata = sp.read_h5ad(os.path.join(DATAPATH, FILE))
adata_gene_list = adata.var['gene_symbol'].values.tolist()

# %%
df = pd.read_csv('data/recipe_table_9_6_2024.csv')
df.head()
# Out:
#                                         Source cells  Source  \
# 0   Embryonic Fibroblasts and Adult Skin Fibroblasts     NaN
# 1  Fetal Fibroblasts and Postnatal Foreskin Fibro...     NaN
# 2    Embryonic Fibroblasts and Postnatal Fibroblasts     NaN
# 3  Embryonic Fibroblasts and Fetal Foreskin Fibro...     NaN
# 4                          Fibroblasts (IMR90 Cells)     NaN
#
#            Target cells  Target  \
# 0      Dopamine Neurons     NaN
# 1        Neuronal Cells     NaN
# 2        Neuronal Cells     NaN
# 3     Neural Stem Cells     NaN
# 4  Dopaminergic Neurons     NaN
#
#                                            Treatment  \
# 0                            ASCL1, LXMLA, and NURR1
# 1                    BRN2, ASCL1, MYT1L, and NEUROD1
# 2               ASCL1, BRN2, MYT1L, LMX1A, and FOXA2
# 3                                               SOX2
# 4  MASH1, NGN2, SOX2, NURR1, and PITX3 + A Domina...
#
#                                   TFs Species Cell Transplantation  \
# 0                   ASCL1 LXMLA NR4A2    Both                  Yes
# 1         POU3F2 ASCL1 MYT1L NEUROD11   Human                  NaN
# 2      ASCL1 POU3F2 MYT1L LMX1A FOXA2   Human                  NaN
# 3                                SOX2    Both                  Yes
# 4  ASCL1 NEUROG2 SOX2 NR4A2 PITX3 P53   Human                  Yes
#
#    Published Year          PMID  Unnamed: 10 Notes
# 0          2011.0    2172534_27          NaN   NaN
# 1          2011.0   21617644_28          NaN   NaN
# 2          2011.0   21646515_29          NaN   NaN
# 3          2012.0   22683203_31          NaN   NaN
# 4          2014.0  25129808_214          NaN   NaN

# %%
true_count = 0

for i in range(df.shape[0]):
    try:
        TFs = df['TFs'].iloc[i].split()
        result = validateTFs(TFs, adata)
        # print(result)
        if result == True:
            true_count += 1
    except:
        continue

print(f'Number of times True was printed: {true_count}')
print(f'Number of times True rate: {true_count/df.shape[0]}')
# Out:
# Number of times True was printed: 34
# Number of times True rate: 0.6296296296296297

# %% [markdown]
# ## Make the perturbation files

# %%
adata.var
# Out:
#              gene_symbol     feature_type          ensemblid  highly_variable  \
# DDX11L1          DDX11L1  Gene Expression  ENSG00000223972.5            False
# WASH7P            WASH7P  Gene Expression  ENSG00000227232.5            False
# MIR6859-1      MIR6859-1  Gene Expression  ENSG00000278267.1            False
# MIR1302-2HG  MIR1302-2HG  Gene Expression  ENSG00000243485.5            False
# MIR1302-2      MIR1302-2  Gene Expression  ENSG00000284332.1            False
# ...                  ...              ...                ...              ...
# MT-ND6            MT-ND6  Gene Expression  ENSG00000198695.2            False
# MT-TE              MT-TE  Gene Expression  ENSG00000210194.1            False
# MT-CYB            MT-CYB  Gene Expression  ENSG00000198727.2            False
# MT-TT              MT-TT  Gene Expression  ENSG00000210195.2            False
# MT-TP              MT-TP  Gene Expression  ENSG00000210196.2             True
#
#                     means  dispersions  dispersions_norm      mean       std
# DDX11L1      6.398244e-05     0.835044         -0.573947  0.000039  0.005574
# WASH7P       2.274395e-03     2.442280          0.533203  0.001080  0.031731
# MIR6859-1    6.175251e-05     1.295335         -0.256874  0.000033  0.005634
# MIR1302-2HG  1.372886e-04     2.656352          0.680668  0.000048  0.008041
# MIR1302-2    1.000000e-12          NaN          0.000000  0.000000  1.000000
# ...                   ...          ...               ...       ...       ...
# MT-ND6       9.634841e-01     2.466404          0.154140  0.590065  0.741395
# MT-TE        1.600667e-01     1.603787         -0.044396  0.083929  0.301820
# MT-CYB       4.367693e+00     4.765751         -0.499747  3.874830  1.104192
# MT-TT        6.573967e-02     0.624316         -0.719108  0.040580  0.186848
# MT-TP        4.385102e-01     2.705558          1.115482  0.204806  0.501265
#
# [58870 rows x 9 columns]

# %%
output_directory = "/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed"
scalars = [0.5, 0.75, 1.001]
for i in range(len(df['TFs'])):
    val = df['TFs'].iloc[i]
    TFs = val.split()
    if validateTFs(TFs, adata):
        print(TFs)
        adataDict = iterate_perturb_counts(adata.copy(), TFs, scalars)

        # Concatenate all AnnData objects along the observations axis
        concatenated_adata = ad.concat(list(adataDict.values()), axis=0)

        # Save reprogramming metadata into the concatenated_adata.obs table
        concatenated_adata.obs['Source_cells'] = df['Source cells'].iloc[i]
        concatenated_adata.obs['Target_cells'] = df['Target cells'].iloc[i]
        concatenated_adata.obs['Treatment'] = df['Treatment'].iloc[i]
        concatenated_adata.obs['Species'] = df['Species'].iloc[i]
        concatenated_adata.obs['Cell_Transplantation'] = df['Cell Transplantation'].iloc[i]
        concatenated_adata.obs['Published_Year'] = df['Published Year'].iloc[i]
        concatenated_adata.obs['PMID'] = df['PMID'].iloc[i]
        
        # Join the TFs list into a string for the filename
        TFs_str = "_".join(TFs)
        
        # Generate the file path for saving
        file_name = f"{TFs_str}.h5ad"
        output_path = os.path.join(output_directory, file_name)
        
        # Save the concatenated AnnData object to the file
        concatenated_adata.write_h5ad(output_path)
        break
# Out:
# ['ASCL1', 'POU3F2', 'MYT1L', 'LMX1A', 'FOXA2']
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/anndata/_io/h5ad.py:104, in write_h5ad(filepath, adata, as_dense, dataset_kwargs, **kwargs)
#     103     write_elem(f, "raw", adata.raw, dataset_kwargs=dataset_kwargs)
# --> 104 write_elem(f, "obs", adata.obs, dataset_kwargs=dataset_kwargs)
#     105 write_elem(f, "var", adata.var, dataset_kwargs=dataset_kwargs)
#
# File ~/.local/lib/python3.11/site-packages/anndata/_io/specs/registry.py:359, in write_elem(store, k, elem, dataset_kwargs)
#     342 """
#     343 Write an element to a storage group using anndata encoding.
#     344
#    (...)
#     357     E.g. for zarr this would be `chunks`, `compressor`.
#     358 """
# --> 359 Writer(_REGISTRY).write_elem(store, k, elem, dataset_kwargs=dataset_kwargs)
#
# File ~/.local/lib/python3.11/site-packages/anndata/_io/utils.py:243, in report_write_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     242 try:
# --> 243     return func(*args, **kwargs)
#     244 except Exception as e:
#
# File ~/.local/lib/python3.11/site-packages/anndata/_io/specs/registry.py:309, in Writer.write_elem(self, store, k, elem, dataset_kwargs, modifiers)
#     308 if self.callback is None:
# --> 309     return write_func(store, k, elem, dataset_kwargs=dataset_kwargs)
#     310 return self.callback(
#     311     write_func,
#     312     store,
#    (...)
#     316     iospec=self.registry.get_spec(elem),
#     317 )
#
# File ~/.local/lib/python3.11/site-packages/anndata/_io/specs/registry.py:57, in write_spec.<locals>.decorator.<locals>.wrapper(g, k, *args, **kwargs)
#      55 @wraps(func)
#      56 def wrapper(g: GroupStorageType, k: str, *args, **kwargs):
# ---> 57     result = func(g, k, *args, **kwargs)
#      58     g[k].attrs.setdefault("encoding-type", spec.encoding_type)
#
# File ~/.local/lib/python3.11/site-packages/anndata/_io/specs/methods.py:704, in write_dataframe(f, key, df, _writer, dataset_kwargs)
#     701 # ._values is "the best" array representation. It's the true array backing the
#     702 # object, where `.values` is always a np.ndarray and .array is always a pandas
#     703 # array.
# --> 704 _writer.write_elem(
#     705     group, index_name, df.index._values, dataset_kwargs=dataset_kwargs
#     706 )
#     707 for colname, series in df.items():
#     708     # TODO: this should write the "true" representation of the series (i.e. the underlying array or ndarray depending)
#
# File ~/.local/lib/python3.11/site-packages/anndata/_io/utils.py:243, in report_write_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     242 try:
# --> 243     return func(*args, **kwargs)
#     244 except Exception as e:
#
# File ~/.local/lib/python3.11/site-packages/anndata/_io/specs/registry.py:309, in Writer.write_elem(self, store, k, elem, dataset_kwargs, modifiers)
#     308 if self.callback is None:
# --> 309     return write_func(store, k, elem, dataset_kwargs=dataset_kwargs)
#     310 return self.callback(
#     311     write_func,
#     312     store,
#    (...)
#     316     iospec=self.registry.get_spec(elem),
#     317 )
#
# File ~/.local/lib/python3.11/site-packages/anndata/_io/specs/registry.py:57, in write_spec.<locals>.decorator.<locals>.wrapper(g, k, *args, **kwargs)
#      55 @wraps(func)
#      56 def wrapper(g: GroupStorageType, k: str, *args, **kwargs):
# ---> 57     result = func(g, k, *args, **kwargs)
#      58     g[k].attrs.setdefault("encoding-type", spec.encoding_type)
#
# File ~/.local/lib/python3.11/site-packages/anndata/_io/specs/methods.py:414, in write_vlen_string_array(f, k, elem, _writer, dataset_kwargs)
#     413 str_dtype = h5py.special_dtype(vlen=str)
# --> 414 f.create_dataset(k, data=elem.astype(str_dtype), dtype=str_dtype, **dataset_kwargs)
#
# File /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages/h5py/_hl/group.py:183, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     181         group = self.require_group(parent_path)
# --> 183 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     184 dset = dataset.Dataset(dsid)
#
# File /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages/h5py/_hl/dataset.py:166, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0)
#     165 if (data is not None) and (not isinstance(data, Empty)):
# --> 166     dset_id.write(h5s.ALL, h5s.ALL, data)
#     168 return dset_id
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5d.pyx:283, in h5py.h5d.DatasetID.write()
#
# File h5py/_proxy.pyx:146, in h5py._proxy.dset_rw()
#
# OSError: [Errno 5] Can't write data (file write failed: time = Fri Sep  6 16:27:04 2024
# , filename = '/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/ASCL1_POU3F2_MYT1L_LMX1A_FOXA2.h5ad', file descriptor = 54, errno = 5, error message = 'Input/output error', buf = 0x1063e960, total write size = 272, bytes this sub-write = 272, bytes actually written = 18446744073709551615, offset = 0)
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 30
#      27 output_path = os.path.join(output_directory, file_name)
#      29 # Save the concatenated AnnData object to the file
# ---> 30 concatenated_adata.write_h5ad(output_path)
#      31 break
#
# File ~/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1929, in AnnData.write_h5ad(self, filename, compression, compression_opts, as_dense)
#    1926 if filename is None:
#    1927     filename = self.filename
# -> 1929 write_h5ad(
#    1930     Path(filename),
#    1931     self,
#    1932     compression=compression,
#    1933     compression_opts=compression_opts,
#    1934     as_dense=as_dense,
#    1935 )
#    1937 if self.isbacked:
#    1938     self.file.filename = filename
#
# File ~/.local/lib/python3.11/site-packages/anndata/_io/h5ad.py:77, in write_h5ad(filepath, adata, as_dense, dataset_kwargs, **kwargs)
#      74 if adata.isbacked:  # close so that we can reopen below
#      75     adata.file.close()
# ---> 77 with h5py.File(filepath, mode) as f:
#      78     # TODO: Use spec writing system for this
#      79     # Currently can't use write_dispatched here because this function is also called to do an
#      80     # inplace update of a backed object, which would delete "/"
#      81     f = f["/"]
#      82     f.attrs.setdefault("encoding-type", "anndata")
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages/h5py/_hl/files.py:604, in File.__exit__(self, *args)
#     601 @with_phil
#     602 def __exit__(self, *args):
#     603     if self.id:
# --> 604         self.close()
#
# File /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages/h5py/_hl/files.py:586, in File.close(self)
#     580 if self.id.valid:
#     581     # We have to explicitly murder all open objects related to the file
#     582
#     583     # Close file-resident objects first, then the files.
#     584     # Otherwise we get errors in MPI mode.
#     585     self.id._close_open_objects(h5f.OBJ_LOCAL | ~h5f.OBJ_FILE)
# --> 586     self.id._close_open_objects(h5f.OBJ_LOCAL | h5f.OBJ_FILE)
#     588     self.id.close()
#     589     _objects.nonlocal_close()
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:360, in h5py.h5f.FileID._close_open_objects()
#
# OSError: [Errno 5] Unable to extend file properly, errno = 9, error message = 'bad file descriptor' (file write failed: time = Fri Sep  6 16:27:05 2024
# , filename = '/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed/ASCL1_POU3F2_MYT1L_LMX1A_FOXA2.h5ad', file descriptor = 54, errno = 5, error message = 'Input/output error', buf = 0x1063e960, total write size = 272, bytes this sub-write = 272, bytes actually written = 18446744073709551615, offset = 0)

# %%
concatenated_adata.obs
# Out:
#                                                    organ_tissue     method  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                    Liver        10X
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                    Liver        10X
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                    Liver        10X
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                    Liver        10X
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                    Liver        10X
# ...                                                         ...        ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Vasculature  smartseq2
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Vasculature  smartseq2
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Vasculature  smartseq2
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  Vasculature  smartseq2
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  Vasculature  smartseq2
#
#                                                    donor  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1              TSP6
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1              TSP6
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1              TSP6
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1              TSP6
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1              TSP6
# ...                                                  ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  TSP2
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  TSP2
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  TSP2
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  TSP2
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  TSP2
#
#                                                    anatomical_information  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                                nan
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                                nan
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                                nan
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                                nan
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                                nan
# ...                                                                   ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                    nan
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                    nan
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                    nan
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...                  aorta
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...                  aorta
#
#                                                     n_counts_UMIs  n_genes  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                    10423.0     2986
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                    11223.0     3248
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                    14695.0     4469
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                     8977.0     2875
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                    12109.0     3239
# ...                                                           ...      ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...       308152.0     2090
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...       387043.0     2132
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...       412608.0     3140
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...       341884.0     4379
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...       141115.0     5842
#
#                                                    cell_ontology_class  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                      fibroblast
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                      fibroblast
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                      fibroblast
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                      fibroblast
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                      fibroblast
# ...                                                                ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...          fibroblast
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...          fibroblast
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...          fibroblast
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...          fibroblast
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...          fibroblast
#
#                                                         free_annotation  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# ...                                                                 ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...           fibroblast
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...           fibroblast
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...           fibroblast
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...           fibroblast
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...           fibroblast
#
#                                                     manually_annotated  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                            True
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                            True
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                            True
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                            True
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                            True
# ...                                                                ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                True
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                True
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                True
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...                True
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...                True
#
#                                                    compartment  gender      U  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                 stromal    male  0.500
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                 stromal    male  0.500
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                 stromal    male  0.500
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                 stromal    male  0.500
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                 stromal    male  0.500
# ...                                                        ...     ...    ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...     stromal  female  1.001
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...     stromal  female  1.001
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...     stromal  female  1.001
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...     stromal  female  1.001
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...     stromal  female  1.001
#
#                                                                                        Source_cells  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1              Embryonic Fibroblasts and Postnatal Fibroblasts
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1              Embryonic Fibroblasts and Postnatal Fibroblasts
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1              Embryonic Fibroblasts and Postnatal Fibroblasts
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1              Embryonic Fibroblasts and Postnatal Fibroblasts
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1              Embryonic Fibroblasts and Postnatal Fibroblasts
# ...                                                                                             ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Embryonic Fibroblasts and Postnatal Fibroblasts
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Embryonic Fibroblasts and Postnatal Fibroblasts
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Embryonic Fibroblasts and Postnatal Fibroblasts
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  Embryonic Fibroblasts and Postnatal Fibroblasts
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  Embryonic Fibroblasts and Postnatal Fibroblasts
#
#                                                       Target_cells  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1              Neuronal Cells
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1              Neuronal Cells
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1              Neuronal Cells
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1              Neuronal Cells
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1              Neuronal Cells
# ...                                                            ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Neuronal Cells
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Neuronal Cells
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Neuronal Cells
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  Neuronal Cells
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  Neuronal Cells
#
#                                                                                Treatment  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1              ASCL1, BRN2, MYT1L, LMX1A, and FOXA2
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1              ASCL1, BRN2, MYT1L, LMX1A, and FOXA2
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1              ASCL1, BRN2, MYT1L, LMX1A, and FOXA2
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1              ASCL1, BRN2, MYT1L, LMX1A, and FOXA2
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1              ASCL1, BRN2, MYT1L, LMX1A, and FOXA2
# ...                                                                                  ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  ASCL1, BRN2, MYT1L, LMX1A, and FOXA2
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  ASCL1, BRN2, MYT1L, LMX1A, and FOXA2
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  ASCL1, BRN2, MYT1L, LMX1A, and FOXA2
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  ASCL1, BRN2, MYT1L, LMX1A, and FOXA2
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  ASCL1, BRN2, MYT1L, LMX1A, and FOXA2
#
#                                                    Species  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1               Human
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1               Human
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1               Human
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1               Human
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1               Human
# ...                                                    ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...   Human
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...   Human
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...   Human
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...   Human
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...   Human
#
#                                                     Cell_Transplantation  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                               NaN
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                               NaN
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                               NaN
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                               NaN
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                               NaN
# ...                                                                  ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                   NaN
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                   NaN
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                   NaN
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...                   NaN
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...                   NaN
#
#                                                     Published_Year  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                      2011.0
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                      2011.0
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                      2011.0
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                      2011.0
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                      2011.0
# ...                                                            ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...          2011.0
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...          2011.0
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...          2011.0
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...          2011.0
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...          2011.0
#
#                                                            PMID
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1              21646515_29
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1              21646515_29
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1              21646515_29
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1              21646515_29
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1              21646515_29
# ...                                                         ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  21646515_29
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  21646515_29
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  21646515_29
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  21646515_29
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  21646515_29
#
# [114453 rows x 19 columns]

# %%
adata.var
# Out:
#              gene_symbol     feature_type          ensemblid  highly_variable  \
# DDX11L1          DDX11L1  Gene Expression  ENSG00000223972.5            False
# WASH7P            WASH7P  Gene Expression  ENSG00000227232.5            False
# MIR6859-1      MIR6859-1  Gene Expression  ENSG00000278267.1            False
# MIR1302-2HG  MIR1302-2HG  Gene Expression  ENSG00000243485.5            False
# MIR1302-2      MIR1302-2  Gene Expression  ENSG00000284332.1            False
# ...                  ...              ...                ...              ...
# MT-ND6            MT-ND6  Gene Expression  ENSG00000198695.2            False
# MT-TE              MT-TE  Gene Expression  ENSG00000210194.1            False
# MT-CYB            MT-CYB  Gene Expression  ENSG00000198727.2            False
# MT-TT              MT-TT  Gene Expression  ENSG00000210195.2            False
# MT-TP              MT-TP  Gene Expression  ENSG00000210196.2             True
#
#                     means  dispersions  dispersions_norm      mean       std
# DDX11L1      6.398244e-05     0.835044         -0.573947  0.000039  0.005574
# WASH7P       2.274395e-03     2.442280          0.533203  0.001080  0.031731
# MIR6859-1    6.175251e-05     1.295335         -0.256874  0.000033  0.005634
# MIR1302-2HG  1.372886e-04     2.656352          0.680668  0.000048  0.008041
# MIR1302-2    1.000000e-12          NaN          0.000000  0.000000  1.000000
# ...                   ...          ...               ...       ...       ...
# MT-ND6       9.634841e-01     2.466404          0.154140  0.590065  0.741395
# MT-TE        1.600667e-01     1.603787         -0.044396  0.083929  0.301820
# MT-CYB       4.367693e+00     4.765751         -0.499747  3.874830  1.104192
# MT-TT        6.573967e-02     0.624316         -0.719108  0.040580  0.186848
# MT-TP        4.385102e-01     2.705558          1.115482  0.204806  0.501265
#
# [58870 rows x 9 columns]

# %%
concatenated_adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [DDX11L1, WASH7P, MIR6859-1, MIR1302-2HG, MIR1302-2, FAM138A, OR4G4P, OR4G11P, OR4F5, AL627309.1, AL627309.3, CICP27, AL627309.6, AL627309.7, AL627309.2, AL627309.5, RNU6-1100P, AL627309.4, FO538757.1, WASH9P, MIR6859-2, AP006222.1, RPL23AP24, AL732372.1, AL732372.2, WBP1LP7, OR4F29, CICP7, AL732372.3, RF00026, AL669831.3, AC114498.1, MTND1P23, MTND2P28, MTCO1P12, AC114498.2, MTCO2P12, MTATP8P1, MTATP6P1, MTCO3P12, WBP1LP6, OR4F16, CICP3, AL669831.1, RNU6-1199P, AL669831.2, AL669831.5, AL669831.7, AL669831.4, FAM87B, LINC01128, LINC00115, FAM41C, TUBB8P11, AL669831.6, AL645608.6, AL645608.2, AL645608.4, LINC02593, SAMD11, NOC2L, KLHL17, PLEKHN1, PERM1, AL645608.7, HES4, ISG15, AL645608.3, AL645608.1, AGRN, AL645608.5, AL390719.1, AL645608.8, RNF223, C1orf159, AL390719.3, LINC01342, MIR200B, MIR200A, MIR429, AL390719.2, TTLL10-AS1, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, C1QTNF12, AL162741.1, UBE2J2, LINC01786, SCNN1D, ACAP3, MIR6726, PUSL1, INTS11, MIR6727, AL139287.1, CPTP, TAS1R3, ...]
#
# [58870 rows x 0 columns]

# %% [markdown]
# # Day 6
#
# Make perturbations for all TFs in the [Human Transcription Factors Database](https://humantfs.ccbr.utoronto.ca/download.php)

# %% [markdown]
# ## Set up

# %%
import numpy as np
import anndata as ad
import pandas as pd
import scanpy as sp
import os

# %%
def iterate_perturb_counts(adata, tf_list, scalar_list):
    """
    Applies perturbations to the expression data of specified transcription factors across multiple scalars 
    and stores the resulting AnnData objects in a dictionary.

    This function performs the following steps:
    1. Iterates over a list of scalar values.
    2. For each scalar, creates a copy of the AnnData object to preserve the original data.
    3. Applies the `perturb_counts` function to scale the expression data of genes listed in `tf_list` by
       the maximum gene expression of each cell and the current scalar.
    4. Stores the perturbed AnnData object in a dictionary with the scalar as the key.

    Parameters:
    tf_list (list): A list of gene symbols (transcription factors) to be perturbed.
    scalar_list (list): A list of scalar values for scaling the gene expression.
    adata (AnnData): The AnnData object containing gene expression data (cells x genes).

    Returns:
    dict: A dictionary where keys are scalar values and values are the corresponding perturbed AnnData objects.
    """
    
    adata_dict = {}
    
    for scalar in scalar_list:
        # Create a copy of the AnnData object for each scalar value
        adata_temp = adata.copy()
        
        # Apply perturb_counts to the copied AnnData object
        perturbed_adata = perturb_counts(adata_temp, tf_list, scalar)
        
        # Store the perturbed AnnData object in the dictionary with scalar as the key
        adata_dict[scalar] = perturbed_adata
    
    return adata_dict

def perturb_counts(adata, tf_list, scalar): 
    """
    Applies a perturbation to the expression data of specific genes in an AnnData object.

    This function performs the following steps:
    1. Computes the maximum gene expression level for each cell.
    2. Applies a scaling operation to the expression levels of genes listed in `tf_list`.
       - Each entry of these genes in the matrix is multiplied by the maximum expression level 
         of its respective cell and a specified scalar value.
    3. Updates the AnnData object with new columns:
       - 'scaled': A boolean column indicating whether each gene is in the `tf_list`.
       - 'scaled_by': Contains the scaling factor used for each gene (the product of the maximum 
         expression level of each cell and the scalar), or `1` if the gene was not in `tf_list`.
    
    Parameters:
    tf_list (list): A list of gene symbols to be perturbed.
    scalar (float): The scalar value used to scale the expression levels.
    adata (AnnData): The AnnData object containing gene expression data.

    Returns:
    AnnData: The updated AnnData object with applied perturbations and new columns.
    """

    # Create a boolean mask for genes in tf_list
    gene_mask = adata.var['gene_symbol'].isin(tf_list)
    
    # Save the original state of the parameter objects, in case some tfs do not translate (failsafe)
    original_X = adata.X.copy()
    original_gene_mask = gene_mask.copy()
    
    # Compute maximum expression level of each cell
    max_exp = np.max(adata.X, axis=1)

    """This is new today. v """
    # Raise an error if any of the gene names in tf_list do not match column names (we will manually update these in adata):
    missing_genes = [gene for gene in tf_list if gene not in adata.var['gene_symbol'].values]
    
    if missing_genes:
        # Restore original parameter objects
        adata.X = original_X
        gene_mask = original_gene_mask
        raise ValueError(f"Genes {missing_genes} not found in anndata object")

    else:    
        
        # Apply the scaling operation to the specified genes
        adata.X[:, gene_mask] = max_exp * scalar
        
        # Add/Update 'scaled' column in var
        adata.var['scaled'] = gene_mask
        
        # Add/Update 'scaled_by' column in var
        adata.var['scaled_by'] = scalar  # Default value for genes not in tf_list

        # Add/Update 'scaled_by' column in var
        adata.obs['U'] = scalar  # Default value for genes not in tf_list
    
    return adata

def validateTFs(TFs, adata):
    adata_gene_list = adata.var['gene_symbol'].values.tolist()
    for TF in TFs:
        if TF not in adata_gene_list:
            return False
    return True

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('data/HumanTFs_v_1.01.csv')

DATAPATH = "/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/jpic/"
FILE = "fibroblast.h5ad"
adata = sp.read_h5ad(os.path.join(DATAPATH, FILE))
adata_gene_list = adata.var['gene_symbol'].values.tolist()

# %%
df = df[df['Is TF?'] == 'Yes']
all_tfs = list(df['HGNC symbol'].values)

# %% [markdown]
# ## Make Perturbation Files

# %%
output_directory = "/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed"
scalars = [0.5, 0.75, 1.001]
for tf in all_tfs:
    TFs = [tf]
    if validateTFs(TFs, adata):
        # Join the TFs list into a string for the filename
        TFs_str = "_".join(TFs)
       
        # Generate the file path for saving
        file_name = f"{TFs_str}.h5ad"
        output_path = os.path.join(output_directory, file_name)

        # prevents writing duplicate files
        if os.path.exists(output_path):
            continue

        # display some information
        print(TFs)

        adataDict = iterate_perturb_counts(adata, TFs, scalars)

        # Concatenate all AnnData objects along the observations axis
        concatenated_adata = ad.concat(list(adataDict.values()), axis=0)

        # Save reprogramming metadata into the concatenated_adata.obs table
        concatenated_adata.obs['HumanTFs'] = True
       
        # Save the concatenated AnnData object to the file
        concatenated_adata.write_h5ad(output_path)
# Out:
# ['ARID3C']
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ['ARID5A']
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ['ARID5B']
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ['KDM5B']
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ['ARID2']

# %%
concatenated_adata.obs
# Out:
#                                                    organ_tissue     method  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                    Liver        10X
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                    Liver        10X
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                    Liver        10X
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                    Liver        10X
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                    Liver        10X
# ...                                                         ...        ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Vasculature  smartseq2
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Vasculature  smartseq2
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Vasculature  smartseq2
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  Vasculature  smartseq2
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  Vasculature  smartseq2
#
#                                                    donor  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1              TSP6
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1              TSP6
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1              TSP6
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1              TSP6
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1              TSP6
# ...                                                  ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  TSP2
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  TSP2
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  TSP2
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  TSP2
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  TSP2
#
#                                                    anatomical_information  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                                nan
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                                nan
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                                nan
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                                nan
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                                nan
# ...                                                                   ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                    nan
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                    nan
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                    nan
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...                  aorta
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...                  aorta
#
#                                                     n_counts_UMIs  n_genes  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                    10423.0     2986
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                    11223.0     3248
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                    14695.0     4469
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                     8977.0     2875
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                    12109.0     3239
# ...                                                           ...      ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...       308152.0     2090
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...       387043.0     2132
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...       412608.0     3140
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...       341884.0     4379
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...       141115.0     5842
#
#                                                    cell_ontology_class  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                      fibroblast
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                      fibroblast
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                      fibroblast
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                      fibroblast
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                      fibroblast
# ...                                                                ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...          fibroblast
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...          fibroblast
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...          fibroblast
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...          fibroblast
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...          fibroblast
#
#                                                         free_annotation  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# ...                                                                 ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...           fibroblast
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...           fibroblast
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...           fibroblast
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...           fibroblast
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...           fibroblast
#
#                                                     manually_annotated  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                            True
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                            True
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                            True
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                            True
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                            True
# ...                                                                ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                True
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                True
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                True
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...                True
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...                True
#
#                                                    compartment  gender
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                 stromal    male
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                 stromal    male
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                 stromal    male
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                 stromal    male
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                 stromal    male
# ...                                                        ...     ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...     stromal  female
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...     stromal  female
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...     stromal  female
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...     stromal  female
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...     stromal  female
#
# [114453 rows x 11 columns]

# %% [markdown]
# # Day 5
#
# Helping Nat make some changes

# %%
output_directory = "/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed"
scalars = [0.5, 0.75, 1.001]
for i in range(len(df['TFs'])):
    val = df['TFs'].iloc[i]
    val = val.replace(',',' ')
    val = val.replace(';',' ')
    val = val.replace(':',' ')
    TFs = val.split(' ')
    if not validateTFs(TFs, adata):
        print(TFs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 output_directory = "/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed"
#       2 scalars = [0.5, 0.75, 1.001]
# ----> 3 for i in range(len(df['TFs'])):
#       4     val = df['TFs'].iloc[i]
#       5     val = val.replace(',',' ')
#
# NameError: name 'df' is not defined

# %%
output_directory = "/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed"
scalars = [0.5, 0.75, 1.001]
for i in range(len(df['TFs'])):
    val = df['TFs'].iloc[i]
    val = val.replace(',',' ')
    val = val.replace(';',' ')
    val = val.replace(':',' ')
    TFs = val.split(' ')
    if validateTFs(TFs, adata):
        # Join the TFs list into a string for the filename
        TFs_str = "_".join(TFs)

        # Generate the file path for saving
        file_name = f"{TFs_str}.h5ad"
        output_path = os.path.join(output_directory, file_name)

        # prevents writing duplicate files
        if os.path.exists(output_filepath):
            continue

        # display some information
        print(TFs)

        adataDict = iterate_perturb_counts(adata, TFs, scalars)

        # Concatenate all AnnData objects along the observations axis
        concatenated_adata = ad.concat(list(adataDict.values()), axis=0)

        # Save reprogramming metadata into the concatenated_adata.obs table
        concatenated_adata.obs['Source_cells'] = df['Source cells'].iloc[i]
        concatenated_adata.obs['Target_cells'] = df['Target cells'].iloc[i]
        concatenated_adata.obs['Treatment'] = df['Treatment'].iloc[i]
        concatenated_adata.obs['Species'] = df['Species'].iloc[i]
        concatenated_adata.obs['Cell_Transplantation'] = df['Cell Transplantation'].iloc[i]
        concatenated_adata.obs['Published_Year'] = df['Published Year'].iloc[i]
        concatenated_adata.obs['PMID'] = df['PMID'].iloc[i]
        
        # Save the concatenated AnnData object to the file
        concatenated_adata.write_h5ad(output_path)

# %% [markdown]
# # Day 4
#
# **Focus:** check out Nats code (debug a bit) and create a few perturbations
# - changes made to NO's code:
#     1. iterate_perturb_counts: changes the order of the arguments to `adata, tf_list, scalar_list`
#     2. perturb_counts: changes the order of the arguments to `adata, tf_list, scalar_list`
#     3. perturb_counts: there was an issue with the use of `[: np.newaxis]` with respect to `max_exp`, which is a `coo_matrix` (special type of sparse matrix). Code was modified to address an issue being thrown here.
# - new function:
#     1. validateTFs(TFs, adata): this checks if all the transcription factors are present in the adata
# - pertrubation driver (`Perform Perturbations and Create new files`):
#     1. loads Fibroblast data from Tabula Sapiens
#     2. loads `.csv` file of known reprogrmaming protocols
#     3. for each set of TFs that are validated by `validateTFs`:
#         1. use `iterate_perturb_counts` to generate perturbations with scalars `[0.5, 0.75, 1]`
#         2. concatenate the dataframes to make a single dataframe
#         3. save metadata from reprogramming protocol (i.e. PMID, source/targets, etc.)
#         4. save the new anndata as a `.h5ad` file

# %% [markdown]
# ## Nat's Code with some modifications

# %%
import numpy as np
import anndata as ad
import pandas as pd
import scanpy as sp
import os

# %%
def iterate_perturb_counts(adata, tf_list, scalar_list):
    """
    Applies perturbations to the expression data of specified transcription factors across multiple scalars 
    and stores the resulting AnnData objects in a dictionary.

    This function performs the following steps:
    1. Iterates over a list of scalar values.
    2. For each scalar, creates a copy of the AnnData object to preserve the original data.
    3. Applies the `perturb_counts` function to scale the expression data of genes listed in `tf_list` by
       the maximum gene expression of each cell and the current scalar.
    4. Stores the perturbed AnnData object in a dictionary with the scalar as the key.

    Parameters:
    tf_list (list): A list of gene symbols (transcription factors) to be perturbed.
    scalar_list (list): A list of scalar values for scaling the gene expression.
    adata (AnnData): The AnnData object containing gene expression data (cells x genes).

    Returns:
    dict: A dictionary where keys are scalar values and values are the corresponding perturbed AnnData objects.
    """
    
    adata_dict = {}
    
    for scalar in scalar_list:
        # Create a copy of the AnnData object for each scalar value
        adata_temp = adata.copy()
        
        # Apply perturb_counts to the copied AnnData object
        perturbed_adata = perturb_counts(adata_temp, tf_list, scalar)
        
        # Store the perturbed AnnData object in the dictionary with scalar as the key
        adata_dict[scalar] = perturbed_adata
    
    return adata_dict

def perturb_counts(adata, tf_list, scalar): 
    """
    Applies a perturbation to the expression data of specific genes in an AnnData object.

    This function performs the following steps:
    1. Computes the maximum gene expression level for each cell.
    2. Applies a scaling operation to the expression levels of genes listed in `tf_list`.
       - Each entry of these genes in the matrix is multiplied by the maximum expression level 
         of its respective cell and a specified scalar value.
    3. Updates the AnnData object with new columns:
       - 'scaled': A boolean column indicating whether each gene is in the `tf_list`.
       - 'scaled_by': Contains the scaling factor used for each gene (the product of the maximum 
         expression level of each cell and the scalar), or `1` if the gene was not in `tf_list`.
    
    Parameters:
    tf_list (list): A list of gene symbols to be perturbed.
    scalar (float): The scalar value used to scale the expression levels.
    adata (AnnData): The AnnData object containing gene expression data.

    Returns:
    AnnData: The updated AnnData object with applied perturbations and new columns.
    """

    # Create a boolean mask for genes in tf_list
    gene_mask = adata.var['gene_symbol'].isin(tf_list)
    
    # Save the original state of the parameter objects, in case some tfs do not translate (failsafe)
    original_X = adata.X.copy()
    original_gene_mask = gene_mask.copy()
    
    # Compute maximum expression level of each cell
    max_exp = np.max(adata.X, axis=1)

    """This is new today. v """
    # Raise an error if any of the gene names in tf_list do not match column names (we will manually update these in adata):
    missing_genes = [gene for gene in tf_list if gene not in adata.var['gene_symbol'].values]
    
    if missing_genes:
        # Restore original parameter objects
        adata.X = original_X
        gene_mask = original_gene_mask
        raise ValueError(f"Genes {missing_genes} not found in anndata object")

    else:    
        
        # Apply the scaling operation to the specified genes
        adata.X[:, gene_mask] = max_exp * scalar
        
        # Add/Update 'scaled' column in var
        adata.var['scaled'] = gene_mask
        
        # Add/Update 'scaled_by' column in var
        adata.var['scaled_by'] = scalar  # Default value for genes not in tf_list
    
    return adata

# %% [markdown]
# ## New code to validate lists of TFs

# %%
def validateTFs(TFs, adata):
    adata_gene_list = adata.var['gene_symbol'].values.tolist()
    for TF in TFs:
        if TF not in adata_gene_list:
            return False
    return True

# %% [markdown]
# ## Load data and perturbations

# %%
df = pd.read_csv('data/first_5_recepies_8_29_2024.csv')

DATAPATH = "/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/jpic/"
FILE = "fibroblast.h5ad"
adata = sp.read_h5ad(os.path.join(DATAPATH, FILE))
adata_gene_list = adata.var['gene_symbol'].values.tolist()

# %%
adata.var
# Out:
#              gene_symbol     feature_type          ensemblid  highly_variable  \
# DDX11L1          DDX11L1  Gene Expression  ENSG00000223972.5            False
# WASH7P            WASH7P  Gene Expression  ENSG00000227232.5            False
# MIR6859-1      MIR6859-1  Gene Expression  ENSG00000278267.1            False
# MIR1302-2HG  MIR1302-2HG  Gene Expression  ENSG00000243485.5            False
# MIR1302-2      MIR1302-2  Gene Expression  ENSG00000284332.1            False
# ...                  ...              ...                ...              ...
# MT-ND6            MT-ND6  Gene Expression  ENSG00000198695.2            False
# MT-TE              MT-TE  Gene Expression  ENSG00000210194.1            False
# MT-CYB            MT-CYB  Gene Expression  ENSG00000198727.2            False
# MT-TT              MT-TT  Gene Expression  ENSG00000210195.2            False
# MT-TP              MT-TP  Gene Expression  ENSG00000210196.2             True
#
#                     means  dispersions  dispersions_norm      mean       std
# DDX11L1      6.398244e-05     0.835044         -0.573947  0.000039  0.005574
# WASH7P       2.274395e-03     2.442280          0.533203  0.001080  0.031731
# MIR6859-1    6.175251e-05     1.295335         -0.256874  0.000033  0.005634
# MIR1302-2HG  1.372886e-04     2.656352          0.680668  0.000048  0.008041
# MIR1302-2    1.000000e-12          NaN          0.000000  0.000000  1.000000
# ...                   ...          ...               ...       ...       ...
# MT-ND6       9.634841e-01     2.466404          0.154140  0.590065  0.741395
# MT-TE        1.600667e-01     1.603787         -0.044396  0.083929  0.301820
# MT-CYB       4.367693e+00     4.765751         -0.499747  3.874830  1.104192
# MT-TT        6.573967e-02     0.624316         -0.719108  0.040580  0.186848
# MT-TP        4.385102e-01     2.705558          1.115482  0.204806  0.501265
#
# [58870 rows x 9 columns]

# %% [markdown]
# ## Perform Perturbations and Create new files

# %%
len(df['TFs'])
# Out:
# 50

# %%
output_directory = "/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot/perturbed"
scalars = [0.5, 0.75, 1.001]
for i in range(len(df['TFs'])):
    val = df['TFs'].iloc[i]
    val = val.replace(',',' ')
    val = val.replace(';',' ')
    val = val.replace(':',' ')
    TFs = val.split(' ')
    if validateTFs(TFs, adata):
        print(TFs)
        adataDict = iterate_perturb_counts(adata, TFs, scalars)

        # Concatenate all AnnData objects along the observations axis
        concatenated_adata = ad.concat(list(adataDict.values()), axis=0)

        # Save reprogramming metadata into the concatenated_adata.obs table
        concatenated_adata.obs['Source_cells'] = df['Source cells'].iloc[i]
        concatenated_adata.obs['Target_cells'] = df['Target cells'].iloc[i]
        concatenated_adata.obs['Treatment'] = df['Treatment'].iloc[i]
        concatenated_adata.obs['Species'] = df['Species'].iloc[i]
        concatenated_adata.obs['Cell_Transplantation'] = df['Cell Transplantation'].iloc[i]
        concatenated_adata.obs['Published_Year'] = df['Published Year'].iloc[i]
        concatenated_adata.obs['PMID'] = df['PMID'].iloc[i]
        
        # Join the TFs list into a string for the filename
        TFs_str = "_".join(TFs)
        
        # Generate the file path for saving
        file_name = f"{TFs_str}.h5ad"
        output_path = os.path.join(output_directory, file_name)
        
        # Save the concatenated AnnData object to the file
        concatenated_adata.write_h5ad(output_path)
# Out:
# ['SOX2']
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ['SOX2', 'HMGA2']
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ['ASCL1', 'PAX6']
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ['SOX2', 'GATA3', 'NEUROD1']
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ['SOX2', 'PAX6']
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ['SOX18']

# %% [markdown]
# ## Scratch

# %%
adata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 adata
#
# NameError: name 'adata' is not defined

# %%
file = "fibroblast.h5ad"
file[:-5]
# Out:
# 'fibroblast'

# %%
concatenated_adata.obs
# Out:
#                                                    organ_tissue     method  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                    Liver        10X
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                    Liver        10X
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                    Liver        10X
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                    Liver        10X
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                    Liver        10X
# ...                                                         ...        ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Vasculature  smartseq2
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Vasculature  smartseq2
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Vasculature  smartseq2
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  Vasculature  smartseq2
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  Vasculature  smartseq2
#
#                                                    donor  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1              TSP6
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1              TSP6
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1              TSP6
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1              TSP6
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1              TSP6
# ...                                                  ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  TSP2
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  TSP2
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  TSP2
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  TSP2
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  TSP2
#
#                                                    anatomical_information  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                                nan
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                                nan
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                                nan
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                                nan
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                                nan
# ...                                                                   ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                    nan
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                    nan
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                    nan
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...                  aorta
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...                  aorta
#
#                                                     n_counts_UMIs  n_genes  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                    10423.0     2986
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                    11223.0     3248
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                    14695.0     4469
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                     8977.0     2875
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                    12109.0     3239
# ...                                                           ...      ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...       308152.0     2090
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...       387043.0     2132
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...       412608.0     3140
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...       341884.0     4379
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...       141115.0     5842
#
#                                                    cell_ontology_class  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                      fibroblast
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                      fibroblast
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                      fibroblast
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                      fibroblast
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                      fibroblast
# ...                                                                ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...          fibroblast
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...          fibroblast
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...          fibroblast
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...          fibroblast
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...          fibroblast
#
#                                                         free_annotation  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1              Stellate/Fibroblast
# ...                                                                 ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...           fibroblast
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...           fibroblast
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...           fibroblast
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...           fibroblast
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...           fibroblast
#
#                                                     manually_annotated  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                            True
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                            True
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                            True
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                            True
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                            True
# ...                                                                ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                True
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                True
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...                True
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...                True
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...                True
#
#                                                    compartment  gender  \
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1                 stromal    male
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1                 stromal    male
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1                 stromal    male
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1                 stromal    male
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1                 stromal    male
# ...                                                        ...     ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...     stromal  female
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...     stromal  female
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...     stromal  female
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...     stromal  female
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...     stromal  female
#
#                                                                                         Source_cells
# AACAAAGTCCGGCTTT_TSP6_Liver_NA_10X_1_1              Embryonic Fibroblasts and Adult Skin Fibroblasts
# AATGACCAGTCTTCGA_TSP6_Liver_NA_10X_1_1              Embryonic Fibroblasts and Adult Skin Fibroblasts
# ACCACAATCCGAGAAG_TSP6_Liver_NA_10X_1_1              Embryonic Fibroblasts and Adult Skin Fibroblasts
# ACTTCGCCAACTTCTT_TSP6_Liver_NA_10X_1_1              Embryonic Fibroblasts and Adult Skin Fibroblasts
# AGAAGTATCAGGGATG_TSP6_Liver_NA_10X_1_1              Embryonic Fibroblasts and Adult Skin Fibroblasts
# ...                                                                                              ...
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Embryonic Fibroblasts and Adult Skin Fibroblasts
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Embryonic Fibroblasts and Adult Skin Fibroblasts
# TSP2_Vasculature_aorta_SS2_B114585_B133324_Stro...  Embryonic Fibroblasts and Adult Skin Fibroblasts
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  Embryonic Fibroblasts and Adult Skin Fibroblasts
# TSP2_Vasculature_aorta_SS2_B113343_B133091_Immu...  Embryonic Fibroblasts and Adult Skin Fibroblasts
#
# [114453 rows x 12 columns]

# %%
concatenated_adata.obs['Source_cells'] = df['Source cells'].iloc[0]

# %%
concatenated_adata.obs['Source_cells'] = df['Source cells'].iloc[i]
concatenated_adata.obs['Target_cells'] = df['Target cells'].iloc[i]
concatenated_adata.obs['Treatment'] = df['Treatment'].iloc[i]
concatenated_adata.obs['Species'] = df['Species'].iloc[i]
concatenated_adata.obs['Cell_Transplantation'] = df['Cell Transplantation'].iloc[i]
concatenated_adata.obs['Published_Year'] = df['Published Year'].iloc[i]
concatenated_adata.obs['PMID'] = df['PMID'].iloc[i]

# %%
TFs_str = "_".join(TFs)
TFs_str
# Out:
# 'SOX2_HMGA2'

# %%
import anndata as ad
# Concatenate all AnnData objects along the observations axis
concatenated_adata = ad.concat(list(adataDict.values()), axis=0)
# Out:
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jpic/.local/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
len(list(concatenated_adata.obs.index))
# Out:
# 114453

# %%
len(list(set(list(concatenated_adata.obs.index))))
# Out:
# 38151

# %%
adata.X[:, 0] = max_exp
# Out:
# /home/jpic/.local/lib/python3.11/site-packages/scipy/sparse/_index.py:134: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)

# %%
df = pd.read_csv('data/first_5_recepies_8_29_2024.csv')
words = []
for val in df['TFs']:
    val = val.replace(',',' ')
    val = val.replace(';',' ')
    val = val.replace(':',' ')
    words += val.split(' ')
words = list(set(words))

for word in words:
#     print(word in adata_gene_list)
    if word not in adata_gene_list:
        print(word)
# Out:
# +
# Ptf1a
# NEUROD
# 2)
# c-MYC
# (ETS
# or
# OCT4
# OCT9
# BRN2
# L-MYC
# NURR1
# SV40
# OSTERIX
# P53
# PU.1
# Knockdown
# Large
# Variant
# LXH3
# Antigen
# HNF6
# Any
# and
# OCT3/4
# ER71/ETV2
# of
# AP-2A
# LEF-1
# Three
# NGN2
# NF-κB
# N-MYC
# HB9
# OCT6
# LXMLA
# PPARG2
# MASH1
# the
# Two
# Factors
# T

# %% [markdown]
# # Day 3

# %%
import numpy as np
import pandas as pd
import scanpy as sp
import os

# %% [markdown]
# # Day 2

# %%
import numpy as np
import pandas as pd
import scanpy as sp
import os

# %% [markdown]
# ## Build Embeddings of Target Data

# %% [markdown]
# ### Neurons

# %%
import numpy as np
import pandas as pd
import scanpy as sp
import os

# location to data
DATAPATH = "/nfs/turbo/umms-indikar/shared/projects/public_data/cellXgene"
FILE = "neurons.h5ad"

# load data
adata = sp.read_h5ad(os.path.join(DATAPATH, FILE))

# filter to only neuron data
neurons_adata = adata[adata.obs['cell_type'] == 'neuron']

# this data needs to be embedded with all the models

# %% [markdown]
# ## Build Embedding Driver

# %%
def main(job_number, parameter_file):
    """
    Main function for performing in silico reprogramming experiments. It selects the correct model, source, target, 
    transcription factors (TFs), and other parameters based on the job number in a SLURM array job. Then, it processes 
    the data and saves the results.
    
    Args:
        job_number (int): The SLURM job array index to determine which parameters to use.
        parameter_file (str): Path to the CSV file containing model parameters.
    
    Returns:
        int: Return code (0 for success).
    """

    OUTPUTPATH = "/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot"
    
    # Load parameters from CSV
    df_embedding_parameters = pd.read_csv(parameter_file)
    TFs    = df_embedding_parameters['TFs'].values[job_number]
    model  = df_embedding_parameters['model'].values[job_number]
    source = df_embedding_parameters['source'].values[job_number]
    target = df_embedding_parameters['target'].values[job_number]
    PMID   = df_embedding_parameters['PMID'].values[job_number]
    year   = df_embedding_parameters['year'].values[job_number]
    organ  = df_embedding_parameters['organ'].values[job_number]

    print(f"Starting job {job_number} with model {model}, TFs {TFs}, source {source}, target {target}, PMID {PMID}, year {year}")

    # Load the source data (Fibroblasts)
    source_adata = load_fibroblasts()
    print("Source data loaded")

    # TODO: Load the target data
    targets_adata = load_targets()
    print("Target data loaded")

    # Perturb the source data
    perturbed_adata = perturbation_model(source_adata, TFs)
    print("Data perturbed")

    # Combine source, perturbed, and target data
    combined_adata = combine_adata([source_adata, perturbed_adata, targets_adata])

    # Add a new 'reprogrammed type' column to indicate the source, target, and reprogrammed cells
    combined_adata.obs['reprogrammed type'] = ['source'] * source_adata.shape[0] + \
                                              ['reprogrammed'] * perturbed_adata.shape[0] + \
                                              ['target'] * targets_adata.shape[0]
    print("Combined data and added 'reprogrammed type' column")

    # Add columns to the 'obs' field of combined_adata for metadata tracking
    combined_adata.obs['model'] = model
    combined_adata.obs['TFs'] = ','.join(TFs)
    combined_adata.obs['PMID'] = PMID
    combined_adata.obs['year'] = year
    combined_adata.obs['organ'] = organ
    print("Added metadata columns to combined data")

    # Generate embeddings using the specified model
    if model == 'geneformer':
        adata_embedded = embed_geneformer(combined_adata)
    elif model == 'tGPT':
        adata_embedded = embed_tGPT(combined_adata)
    elif model == 'scGTP':
        adata_embedded = embed_scGTP([combined_adata])
    else:
        raise ValueError(f"Unknown model: {model}")

    print(f"Embeddings generated using model: {model}")

    # Save the results to a file named according to the job number
    result_filepath = os.path.join(OUTPUTPATH, f"results_job_{job_number}.h5ad")
    adata_embedded.write(result_filepath)
    print(f"Results saved to {result_filepath}")

    return 0

# %% [markdown]
# # Day 1

# %%
import numpy as np
import pandas as pd
import scanpy as sp
import os

# %% [markdown]
# ## Perturbation Model Discussion
#
# E.V. = expression values
#
# Possible algorithm:
# ```
# 1. find highest E.V.  for a single cell
# 2. find expression value of TFs being modified
# 3. have a value k for the number of different concentrations we want to test
# 4. choose k different amounts to increase the TFs from there measured E.V. to the 150% maximum E.V.
#    - make an arbitray choice and code it up
# ```
#
# **A reasonable person could write this 10s of different ways**

# %% [markdown]
# ## Visualize Input Data

# %%
DATAPATH = "/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/"
FILE = "TS_epithelial.h5ad"

adata = sp.read_h5ad(os.path.join(DATAPATH, FILE))

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 104148 × 58870
#     obs: 'organ_tissue', 'method', 'donor', 'anatomical_information', 'n_counts_UMIs', 'n_genes', 'cell_ontology_class', 'free_annotation', 'manually_annotated', 'compartment', 'gender'
#     var: 'gene_symbol', 'feature_type', 'ensemblid', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: '_scvi', '_training_mode', 'dendrogram_cell_type_tissue', 'dendrogram_computational_compartment_assignment', 'dendrogram_consensus_prediction', 'dendrogram_tissue_cell_type', 'donor_colors', 'donor_method_colors', 'hvg', 'method_colors', 'neighbors', 'organ_tissue_colors', 'sex_colors', 'tissue_colors', 'umap'
#     obsm: 'X_pca', 'X_scvi', 'X_scvi_umap', 'X_umap'
#     layers: 'decontXcounts', 'raw_counts'
#     obsp: 'connectivities', 'distances'

# %%
adata.var
# Out:
#              gene_symbol     feature_type          ensemblid  highly_variable  \
# DDX11L1          DDX11L1  Gene Expression  ENSG00000223972.5            False
# WASH7P            WASH7P  Gene Expression  ENSG00000227232.5            False
# MIR6859-1      MIR6859-1  Gene Expression  ENSG00000278267.1            False
# MIR1302-2HG  MIR1302-2HG  Gene Expression  ENSG00000243485.5            False
# MIR1302-2      MIR1302-2  Gene Expression  ENSG00000284332.1            False
# ...                  ...              ...                ...              ...
# MT-ND6            MT-ND6  Gene Expression  ENSG00000198695.2            False
# MT-TE              MT-TE  Gene Expression  ENSG00000210194.1            False
# MT-CYB            MT-CYB  Gene Expression  ENSG00000198727.2            False
# MT-TT              MT-TT  Gene Expression  ENSG00000210195.2            False
# MT-TP              MT-TP  Gene Expression  ENSG00000210196.2             True
#
#                     means  dispersions  dispersions_norm      mean       std
# DDX11L1      6.398244e-05     0.835044         -0.573947  0.000039  0.005574
# WASH7P       2.274395e-03     2.442280          0.533203  0.001080  0.031731
# MIR6859-1    6.175251e-05     1.295335         -0.256874  0.000033  0.005634
# MIR1302-2HG  1.372886e-04     2.656352          0.680668  0.000048  0.008041
# MIR1302-2    1.000000e-12          NaN          0.000000  0.000000  1.000000
# ...                   ...          ...               ...       ...       ...
# MT-ND6       9.634841e-01     2.466404          0.154140  0.590065  0.741395
# MT-TE        1.600667e-01     1.603787         -0.044396  0.083929  0.301820
# MT-CYB       4.367693e+00     4.765751         -0.499747  3.874830  1.104192
# MT-TT        6.573967e-02     0.624316         -0.719108  0.040580  0.186848
# MT-TP        4.385102e-01     2.705558          1.115482  0.204806  0.501265
#
# [58870 rows x 9 columns]

# %%
adata.X.max(axis=1) # what is the value of the highest expressed gene for each cell?
# Out:
# <104148x1 sparse matrix of type '<class 'numpy.float32'>'
# 	with 104148 stored elements in COOrdinate format>

# %%
TF = 'DDX11L1'
index = np.where(adata.var['gene_symbol'] == TF)[0]
index
# Out:
# array([0])

# %%
adata.var['gene_symbol']
# Out:
# DDX11L1            DDX11L1
# WASH7P              WASH7P
# MIR6859-1        MIR6859-1
# MIR1302-2HG    MIR1302-2HG
# MIR1302-2        MIR1302-2
#                   ...
# MT-ND6              MT-ND6
# MT-TE                MT-TE
# MT-CYB              MT-CYB
# MT-TT                MT-TT
# MT-TP                MT-TP
# Name: gene_symbol, Length: 58870, dtype: object

# %%
adata.obs
# Out:
#                                                 organ_tissue method donor  \
# AACAGGGCATGTGCTA_TSP6_Liver_NA_10X_1_1                 Liver    10X  TSP6
# AATGAAGTCTAAGGAA_TSP6_Liver_NA_10X_1_1                 Liver    10X  TSP6
# ACAGAAAAGCTGTCCG_TSP6_Liver_NA_10X_1_1                 Liver    10X  TSP6
# ACGATGTTCGACTCCT_TSP6_Liver_NA_10X_1_1                 Liver    10X  TSP6
# ACGTTCCAGAACCCGA_TSP6_Liver_NA_10X_1_1                 Liver    10X  TSP6
# ...                                                      ...    ...   ...
# TGACAGTAGATGGCGT_TSP2_Vasculature_Aorta_10X_1_2  Vasculature    10X  TSP2
# TGTTGGATCGACATCA_TSP2_Vasculature_Aorta_10X_1_2  Vasculature    10X  TSP2
# TTGGATGGTGGCTACC_TSP2_Vasculature_Aorta_10X_1_2  Vasculature    10X  TSP2
# CTTGATTTCTTGCAAG_TSP2_Vasculature_Aorta_10X_2_2  Vasculature    10X  TSP2
# TCGACGGCATGGAATA_TSP2_Vasculature_Aorta_10X_2_2  Vasculature    10X  TSP2
#
#                                                 anatomical_information  \
# AACAGGGCATGTGCTA_TSP6_Liver_NA_10X_1_1                             nan
# AATGAAGTCTAAGGAA_TSP6_Liver_NA_10X_1_1                             nan
# ACAGAAAAGCTGTCCG_TSP6_Liver_NA_10X_1_1                             nan
# ACGATGTTCGACTCCT_TSP6_Liver_NA_10X_1_1                             nan
# ACGTTCCAGAACCCGA_TSP6_Liver_NA_10X_1_1                             nan
# ...                                                                ...
# TGACAGTAGATGGCGT_TSP2_Vasculature_Aorta_10X_1_2                  Aorta
# TGTTGGATCGACATCA_TSP2_Vasculature_Aorta_10X_1_2                  Aorta
# TTGGATGGTGGCTACC_TSP2_Vasculature_Aorta_10X_1_2                  Aorta
# CTTGATTTCTTGCAAG_TSP2_Vasculature_Aorta_10X_2_2                  Aorta
# TCGACGGCATGGAATA_TSP2_Vasculature_Aorta_10X_2_2                  Aorta
#
#                                                  n_counts_UMIs  n_genes  \
# AACAGGGCATGTGCTA_TSP6_Liver_NA_10X_1_1                 14151.0     3404
# AATGAAGTCTAAGGAA_TSP6_Liver_NA_10X_1_1                 10303.0     2863
# ACAGAAAAGCTGTCCG_TSP6_Liver_NA_10X_1_1                  9391.0     2738
# ACGATGTTCGACTCCT_TSP6_Liver_NA_10X_1_1                  4634.0     1634
# ACGTTCCAGAACCCGA_TSP6_Liver_NA_10X_1_1                 33370.0     6590
# ...                                                        ...      ...
# TGACAGTAGATGGCGT_TSP2_Vasculature_Aorta_10X_1_2        10354.0     2456
# TGTTGGATCGACATCA_TSP2_Vasculature_Aorta_10X_1_2        15677.0     3234
# TTGGATGGTGGCTACC_TSP2_Vasculature_Aorta_10X_1_2        18638.0     3368
# CTTGATTTCTTGCAAG_TSP2_Vasculature_Aorta_10X_2_2        36555.0     5102
# TCGACGGCATGGAATA_TSP2_Vasculature_Aorta_10X_2_2         6943.0     1799
#
#                                                         cell_ontology_class  \
# AACAGGGCATGTGCTA_TSP6_Liver_NA_10X_1_1                           hepatocyte
# AATGAAGTCTAAGGAA_TSP6_Liver_NA_10X_1_1                           hepatocyte
# ACAGAAAAGCTGTCCG_TSP6_Liver_NA_10X_1_1                           hepatocyte
# ACGATGTTCGACTCCT_TSP6_Liver_NA_10X_1_1                           hepatocyte
# ACGTTCCAGAACCCGA_TSP6_Liver_NA_10X_1_1           intrahepatic cholangiocyte
# ...                                                                     ...
# TGACAGTAGATGGCGT_TSP2_Vasculature_Aorta_10X_1_2             epithelial cell
# TGTTGGATCGACATCA_TSP2_Vasculature_Aorta_10X_1_2             epithelial cell
# TTGGATGGTGGCTACC_TSP2_Vasculature_Aorta_10X_1_2             epithelial cell
# CTTGATTTCTTGCAAG_TSP2_Vasculature_Aorta_10X_2_2             epithelial cell
# TCGACGGCATGGAATA_TSP2_Vasculature_Aorta_10X_2_2             epithelial cell
#
#                                                  free_annotation  \
# AACAGGGCATGTGCTA_TSP6_Liver_NA_10X_1_1                Hepatocyte
# AATGAAGTCTAAGGAA_TSP6_Liver_NA_10X_1_1                Hepatocyte
# ACAGAAAAGCTGTCCG_TSP6_Liver_NA_10X_1_1                Hepatocyte
# ACGATGTTCGACTCCT_TSP6_Liver_NA_10X_1_1                Hepatocyte
# ACGTTCCAGAACCCGA_TSP6_Liver_NA_10X_1_1                      BECS
# ...                                                          ...
# TGACAGTAGATGGCGT_TSP2_Vasculature_Aorta_10X_1_2  epithelial cell
# TGTTGGATCGACATCA_TSP2_Vasculature_Aorta_10X_1_2  epithelial cell
# TTGGATGGTGGCTACC_TSP2_Vasculature_Aorta_10X_1_2  epithelial cell
# CTTGATTTCTTGCAAG_TSP2_Vasculature_Aorta_10X_2_2  epithelial cell
# TCGACGGCATGGAATA_TSP2_Vasculature_Aorta_10X_2_2  epithelial cell
#
#                                                  manually_annotated  \
# AACAGGGCATGTGCTA_TSP6_Liver_NA_10X_1_1                         True
# AATGAAGTCTAAGGAA_TSP6_Liver_NA_10X_1_1                         True
# ACAGAAAAGCTGTCCG_TSP6_Liver_NA_10X_1_1                         True
# ACGATGTTCGACTCCT_TSP6_Liver_NA_10X_1_1                         True
# ACGTTCCAGAACCCGA_TSP6_Liver_NA_10X_1_1                         True
# ...                                                             ...
# TGACAGTAGATGGCGT_TSP2_Vasculature_Aorta_10X_1_2                True
# TGTTGGATCGACATCA_TSP2_Vasculature_Aorta_10X_1_2                True
# TTGGATGGTGGCTACC_TSP2_Vasculature_Aorta_10X_1_2                True
# CTTGATTTCTTGCAAG_TSP2_Vasculature_Aorta_10X_2_2                True
# TCGACGGCATGGAATA_TSP2_Vasculature_Aorta_10X_2_2                True
#
#                                                 compartment  gender
# AACAGGGCATGTGCTA_TSP6_Liver_NA_10X_1_1           epithelial    male
# AATGAAGTCTAAGGAA_TSP6_Liver_NA_10X_1_1           epithelial    male
# ACAGAAAAGCTGTCCG_TSP6_Liver_NA_10X_1_1           epithelial    male
# ACGATGTTCGACTCCT_TSP6_Liver_NA_10X_1_1           epithelial    male
# ACGTTCCAGAACCCGA_TSP6_Liver_NA_10X_1_1           epithelial    male
# ...                                                     ...     ...
# TGACAGTAGATGGCGT_TSP2_Vasculature_Aorta_10X_1_2  epithelial  female
# TGTTGGATCGACATCA_TSP2_Vasculature_Aorta_10X_1_2  epithelial  female
# TTGGATGGTGGCTACC_TSP2_Vasculature_Aorta_10X_1_2  epithelial  female
# CTTGATTTCTTGCAAG_TSP2_Vasculature_Aorta_10X_2_2  epithelial  female
# TCGACGGCATGGAATA_TSP2_Vasculature_Aorta_10X_2_2  epithelial  female
#
# [104148 rows x 11 columns]

# %%
list(adata.obs['cell_ontology_class'].unique())
# Out:
# ['hepatocyte',
#  'intrahepatic cholangiocyte',
#  'tracheal goblet cell',
#  'ciliated cell',
#  'ionocyte',
#  'secretory cell',
#  'basal cell',
#  'mucus secreting cell',
#  'serous cell of epithelium of trachea',
#  'acinar cell of salivary gland',
#  'duct epithelial cell',
#  'myoepithelial cell',
#  'epithelial cell',
#  'keratinocyte',
#  'luminal epithelial cell of mammary gland',
#  'epithelial cell of uterus',
#  'ciliated epithelial cell',
#  'conjunctival epithelial cell',
#  'eye photoreceptor cell',
#  'limbal stem cell',
#  'epithelial cell of lacrimal sac',
#  'corneal keratocyte',
#  'retinal pigment epithelial cell',
#  'corneal epithelial cell',
#  'ocular surface cell',
#  'ciliary body',
#  'pancreatic acinar cell',
#  'pancreatic ductal cell',
#  'pancreatic beta cell',
#  'basal cell of prostate epithelium',
#  'hillock-club cell of prostate epithelium',
#  'luminal cell of prostate epithelium',
#  'salivary gland cell',
#  'medullary thymic epithelial cell',
#  'bladder urothelial cell',
#  'enterocyte of epithelium of large intestine',
#  'large intestine goblet cell',
#  'paneth cell of epithelium of large intestine',
#  'transit amplifying cell of large intestine',
#  'intestinal crypt stem cell of large intestine',
#  'intestinal enteroendocrine cell',
#  'intestinal tuft cell',
#  'type ii pneumocyte',
#  'respiratory mucous cell',
#  'club cell of prostate epithelium',
#  'hillock cell of prostate epithelium',
#  'enterocyte of epithelium of small intestine',
#  'transit amplifying cell of small intestine',
#  'small intestine goblet cell',
#  'paneth cell of epithelium of small intestine',
#  'intestinal crypt stem cell of small intestine',
#  'kidney epithelial cell',
#  'immature enterocyte',
#  'intestinal crypt stem cell',
#  'mature enterocyte',
#  'goblet cell',
#  'lung ciliated cell',
#  'respiratory goblet cell',
#  'serous cell of epithelium of bronchus',
#  'type i pneumocyte',
#  'club cell',
#  'pulmonary ionocyte',
#  'pancreatic pp cell',
#  'pancreatic alpha cell',
#  'pancreatic delta cell',
#  'duodenum glandular cell',
#  'mesothelial cell']

# %% [markdown]
# ## Build driver

# %%
import pandas as pd

def load_fibroblasts():
    """
    Loads the single-cell RNA sequencing data for fibroblast cells.

    The function loads a specified .h5ad file containing cellular data, filters the data
    to only include fibroblasts, and returns the AnnData object.

    Returns:
        AnnData: The AnnData object containing data for fibroblast cells only.
    """

    # Path to the data
    DATAPATH = "/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/jpic/"
    FILE = "fibroblast.h5ad"
    
    # Load the data
    adata = sc.read_h5ad(os.path.join(DATAPATH, FILE))
    
    return fibroblasts

import os
import pandas as pd
import scanpy as sc

def main(job_number, parameter_file):
    """
    Main function for performing in silico reprogramming experiments. It selects the correct model, source, target, 
    transcription factors (TFs), and other parameters based on the job number in a SLURM array job. Then, it processes 
    the data and saves the results.
    
    Args:
        job_number (int): The SLURM job array index to determine which parameters to use.
        parameter_file (str): Path to the CSV file containing model parameters.
    
    Returns:
        int: Return code (0 for success).
    """

    OUTPUTPATH = "/nfs/turbo/umms-indikar/shared/projects/DARPA_AI/in-silico-reprogramming/one-shot"
    
    # Load parameters from CSV
    df_embedding_parameters = pd.read_csv(parameter_file)
    TFs    = df_embedding_parameters['TFs'].values[job_number]
    model  = df_embedding_parameters['model'].values[job_number]
    source = df_embedding_parameters['source'].values[job_number]
    target = df_embedding_parameters['target'].values[job_number]
    PMID   = df_embedding_parameters['PMID'].values[job_number]
    year   = df_embedding_parameters['year'].values[job_number]
    organ  = df_embedding_parameters['organ'].values[job_number]

    print(f"Starting job {job_number} with model {model}, TFs {TFs}, source {source}, target {target}, PMID {PMID}, year {year}")

    # Load the source data (Fibroblasts)
    source_adata = load_fibroblasts()
    print("Source data loaded")

    # TODO: Load the target data
    targets_adata = load_targets()
    print("Target data loaded")

    # Perturb the source data
    perturbed_adata = perturbation_model(source_adata, TFs)
    print("Data perturbed")

    # Combine source, perturbed, and target data
    combined_adata = combine_adata([source_adata, perturbed_adata, targets_adata])

    # Add a new 'reprogrammed type' column to indicate the source, target, and reprogrammed cells
    combined_adata.obs['reprogrammed type'] = ['source'] * source_adata.shape[0] + \
                                              ['reprogrammed'] * perturbed_adata.shape[0] + \
                                              ['target'] * targets_adata.shape[0]
    print("Combined data and added 'reprogrammed type' column")

    # Add columns to the 'obs' field of combined_adata for metadata tracking
    combined_adata.obs['model'] = model
    combined_adata.obs['TFs'] = ','.join(TFs)
    combined_adata.obs['PMID'] = PMID
    combined_adata.obs['year'] = year
    combined_adata.obs['organ'] = organ
    print("Added metadata columns to combined data")

    # Generate embeddings using the specified model
    if model == 'geneformer':
        adata_embedded = embed_geneformer(combined_adata)
    elif model == 'tGPT':
        adata_embedded = embed_tGPT(combined_adata)
    elif model == 'scGTP':
        adata_embedded = embed_scGTP([combined_adata])
    else:
        raise ValueError(f"Unknown model: {model}")

    print(f"Embeddings generated using model: {model}")

    # Save the results to a file named according to the job number
    result_filepath = os.path.join(OUTPUTPATH, f"results_job_{job_number}.h5ad")
    adata_embedded.write(result_filepath)
    print(f"Results saved to {result_filepath}")

    return 0

# %% [markdown]
# ## Build parameter dataframe

# %%
embedding_parameters = {
    'source': [],
    'target': [],
    'TFs'   : [],
    'model' : []
}
models = ['geneformer', 'tGPT', 'scGTP']

df = pd.read_csv('data/first_5_recepies_8_29_2024.csv')

for i in range(5):
    TFs = df['TFs'].values[i].split()
    source = df['Source'].values[i]
    target = df['Target'].values[i]
    for model in models:
        embedding_parameters['TFs'].append(TFs)
        embedding_parameters['source'].append(source)
        embedding_parameters['target'].append(source)
        embedding_parameters['model'].append(model)

df_embedding_parameters = pd.DataFrame(embedding_parameters)

df_embedding_parameters
# Out:
#     source  target                                     TFs       model
# 0      NaN     NaN                   [ASCL1, LXMLA, NURR1]  geneformer
# 1      NaN     NaN                   [ASCL1, LXMLA, NURR1]        tGPT
# 2      NaN     NaN                   [ASCL1, LXMLA, NURR1]       scGTP
# 3      NaN     NaN           [BRN2, ASCL1, MYT1L, NEUROD1]  geneformer
# 4      NaN     NaN           [BRN2, ASCL1, MYT1L, NEUROD1]        tGPT
# 5      NaN     NaN           [BRN2, ASCL1, MYT1L, NEUROD1]       scGTP
# 6      NaN     NaN      [ASCL1, BRN2, MYT1L, LMX1A, FOXA2]  geneformer
# 7      NaN     NaN      [ASCL1, BRN2, MYT1L, LMX1A, FOXA2]        tGPT
# 8      NaN     NaN      [ASCL1, BRN2, MYT1L, LMX1A, FOXA2]       scGTP
# 9      NaN     NaN                                  [SOX2]  geneformer
# 10     NaN     NaN                                  [SOX2]        tGPT
# 11     NaN     NaN                                  [SOX2]       scGTP
# 12     NaN     NaN  [MASH1, NGN2, SOX2, NURR1, PITX3, P53]  geneformer
# 13     NaN     NaN  [MASH1, NGN2, SOX2, NURR1, PITX3, P53]        tGPT
# 14     NaN     NaN  [MASH1, NGN2, SOX2, NURR1, PITX3, P53]       scGTP

# %%
df
# Out:
#                                          Source cells  Source  \
# 0    Embryonic Fibroblasts and Adult Skin Fibroblasts     NaN
# 1   Fetal Fibroblasts and Postnatal Foreskin Fibro...     NaN
# 2     Embryonic Fibroblasts and Postnatal Fibroblasts     NaN
# 3   Embryonic Fibroblasts and Fetal Foreskin Fibro...     NaN
# 4                           Fibroblasts (IMR90 Cells)     NaN
# 5                              Adult Skin Fibroblasts     NaN
# 6                          Umbilical Cord Blood Cells     NaN
# 7          Fibroblast-Like Cells from Retinal Tissues     NaN
# 8        Pluripotent Stem Cell-Derived Cardiomyocytes     NaN
# 9                                         Fibroblasts     NaN
# 10                                        Fibroblasts     NaN
# 11                                 Dermal Fibroblasts     NaN
# 12  Embryonic Fibroblasts and Newborn Foreskin Fib...     NaN
# 13                                  Adult Fibroblasts     NaN
# 14              Umbilical Cord Mesenchymal Stem Cells     NaN
# 15                                          Pericytes     NaN
# 16                          Cord Blood CD133(+) Cells     NaN
# 17                           Peripheral CD34(+) Cells     NaN
# 18                        Urine Epithelial-Like Cells     NaN
# 19                Astrocytes and Foreskin Fibroblasts     NaN
# 20  Bone Marrow-Derived Cells, Fibroblasts, and Ke...     NaN
# 21                                Cardiac Fibroblasts     NaN
# 22           Embryonic Stem Cells-Derived Fibroblasts     NaN
# 23                              Embryonic Fibroblasts     NaN
# 24  Fetal and Adult Fibroblasts and Adipose Tissue...     NaN
# 25                   Fibroblasts (BJ and MRC-5 Cells)     NaN
# 26                             Fetal Lung Fibroblasts     NaN
# 27                                        Fibroblasts     NaN
# 28                                        Liver Cells     NaN
# 29  Fibroblasts (3T3 Cells) and Adult Dermal Fibro...     NaN
# 30                                        Fibroblasts     NaN
# 31                      Neonatal Foreskin Fibroblasts     NaN
# 32                                 Dermal Fibroblasts     NaN
# 33                                        Fibroblasts     NaN
# 34  Gingival Fibroblasts and Adult Dermal Fibroblasts     NaN
# 35                                 Dermal Fibroblasts     NaN
# 36  Embryonic Fibroblasts and Newborn Foreskin Fib...     NaN
# 37                                 Iris-Derived Cells     NaN
# 38  Embryonic Fibroblasts and Adult Tail-Tip Derma...     NaN
# 39               Adipose Tissue-Derived Stromal Cells     NaN
# 40                                 Dermal Fibroblasts     NaN
# 41                                        Fibroblasts     NaN
# 42                         Amniotic Fluid Stemm Cells     NaN
# 43  Embryonic Fibroblasts, Adult Tail-Tip Dermal F...     NaN
# 44                       Endothelial Progenitor Cells     NaN
# 45                       Postnatal Dermal Fibroblasts     NaN
# 46                                 Dermal Fibroblasts     NaN
# 47  Embryonic Fibroblasts and Umbilical Vein Endot...     NaN
# 48  Embryonic Fibroblasts and Adult Dermal Fibrobl...     NaN
# 49      Renal Proximal Tubular Epithelial (HK2) Cells     NaN
#
#                           Target cells  Target  \
# 0                     Dopamine Neurons     NaN
# 1                       Neuronal Cells     NaN
# 2                       Neuronal Cells     NaN
# 3                    Neural Stem Cells     NaN
# 4                 Dopaminergic Neurons     NaN
# 5                        Motor Neurons     NaN
# 6                    Neural Stem Cells     NaN
# 7                       Neuronal Cells     NaN
# 8                       Neuronal Cells     NaN
# 9                        Motor Neurons     NaN
# 10                          Neurocytes     NaN
# 11              Neural Precursor Cells     NaN
# 12                   Neural Stem Cells     NaN
# 13              Neural Precursor Cells     NaN
# 14                      Neuronal Cells     NaN
# 15                      Neuronal Cells     NaN
# 16                      Neuronal Cells     NaN
# 17                   Neural Stem Cells     NaN
# 18                   Neural Stem Cells     NaN
# 19               Noradrenergic Neurons     NaN
# 20              Neural Precursor Cells     NaN
# 21                      Cardiomyocytes     NaN
# 22                      Cardiomyocytes     NaN
# 23                         Hepatocytes     NaN
# 24                         Hepatocytes     NaN
# 25                         Hepatocytes     NaN
# 26                         Hepatocytes     NaN
# 27                         Hepatocytes     NaN
# 28                             β Cells     NaN
# 29                       Megakaryocyte     NaN
# 30  Antigen-Presenting Dendritic Cells     NaN
# 31                  Chondrogenic Cells     NaN
# 32                         Osteoblasts     NaN
# 33                         Osteoblasts     NaN
# 34                         Osteoblasts     NaN
# 35                           Myoblasts     NaN
# 36                     Brown Fat Cells     NaN
# 37                 Photoreceptor Cells     NaN
# 38                         Melanocytes     NaN
# 39                   Endothelial Cells     NaN
# 40                 Photoreceptor Cells     NaN
# 41                   Sweat Gland Cells     NaN
# 42              Pluripotent Stem Cells     NaN
# 43      Renal Tubular Epithelial Cells     NaN
# 44                 Smooth Muscle Cells     NaN
# 45                   Endothelial Cells     NaN
# 46                          Adipocytes     NaN
# 47          Intestine Progenitor Cells     NaN
# 48                 Smooth Muscle Cells     NaN
# 49            Nephron Progenitor Cells     NaN
#
#                                             Treatment  \
# 0                             ASCL1, LXMLA, and NURR1
# 1                     BRN2, ASCL1, MYT1L, and NEUROD1
# 2                ASCL1, BRN2, MYT1L, LMX1A, and FOXA2
# 3                                                SOX2
# 4   MASH1, NGN2, SOX2, NURR1, and PITX3 + A Domina...
# 5                      NEUROG2, SOX11, ISL1, and LXH3
# 6                                      SOX2 and HMGA2
# 7                                      ASCL1 and PAX6
# 8                     BRN2, ASCL1, MYT1L, and NEUROD1
# 9   ASCL1, ISL1, NEUROD1, BRN2, HB9, LHX3, MYT1L, ...
# 10                           SOX2, GATA3, and NEUROD1
# 11                                      SOX2 and PAX6
# 12                                              Ptf1a
# 13  SOX2; SOX2 and PAX6; SOX2 and LMX1A; SOX2, LMX...
# 14                           SOX2, ASCL1, and NEUROG2
# 15                                     ASCL1 and SOX2
# 16                 FOXM1, SOX2, MYC, SALL4, and STAT6
# 17  AR, SOX2, SMAD3, MYC, JUN, WT1, TAL1, SPI1, an...
# 18           POU3F2, SOX2, BACH1, AR, PBX1, and NANOG
# 19  ASCL1, PHOX2B, AP-2A, GATA3, HAND2, NURR1, and...
# 20                               MSI1, NGN2, and MBD2
# 21                   GATA4, MEF2C, TBX5, MESP1, MYOCD
# 22     GATA4, MEF2C, TBX5, ESRRG, MESP1, ZFPM2, MYOCD
# 23  HNF1A, HNF4A, HNF6, ATF5, PROX1, CEBPA, and MY...
# 24     FOXA3, HNF1A, and HNF4A + SV40 Large T Antigen
# 25  HNF1A, and Any Two of the Three Factors: FOXA1...
# 26               ATF5, PROX1, FOXA2, FOXA3, and HNF4A
# 27                      OCT4, FOXA2, HNF1A, and GATA3
# 28                               PDX1, PAX4, and MAFA
# 29                               NFE2, MAFG, and MAFK
# 30                              PU.1, IRF8, and BATF3
# 31                              c-MYC, KLF4, and SOX9
# 32   OCT3/4 and OCT6 or OCT9 + L-MYC, c-MYC, or N-MYC
# 33                    RUNX2, OCT4, OSTERIX, and L-MYC
# 34                           OCT4, OSTERIX, and L-MYC
# 35                                     MYOD1 and MYCL
# 36                                   PRDM16 and CEBPB
# 37                               CRX, RAX, and NEUROD
# 38                              MITF, SOX10, and PAX3
# 39                                              SOX18
# 40                         CRX, RAX, OTX2, and NEUROD
# 41                                    NF-κB and LEF-1
# 42                                               OCT4
# 43                       EMX2, HNF1B, HNF4A, and PAX8
# 44                                              MYOCD
# 45                          ER71/ETV2 (ETS Variant 2)
# 46                                             PPARG2
# 47                      HNF4A, FOXA3, GATA6, and CDX2
# 48                            MYOCD, GATA6, and MEF2C
# 49                              SNAI2, EYA1, and SIX1
#
#                                                   TFs Species  \
# 0                                   ASCL1 LXMLA NURR1    Both
# 1                            BRN2 ASCL1 MYT1L NEUROD1   Human
# 2                        ASCL1 BRN2 MYT1L LMX1A FOXA2   Human
# 3                                                SOX2    Both
# 4                     MASH1 NGN2 SOX2 NURR1 PITX3 P53   Human
# 5                             NEUROG2 SOX11 ISL1 LXH3   Human
# 6                                          SOX2 HMGA2   Human
# 7                                          ASCL1 PAX6   Human
# 8                            BRN2 ASCL1 MYT1L NEUROD1    Both
# 9         ASCL1 ISL1 NEUROD1 BRN2 HB9 LHX3 MYT1L NGN2   Human
# 10                                 SOX2 GATA3 NEUROD1   Human
# 11                                          SOX2 PAX6   Human
# 12                                              Ptf1a    Both
# 13  SOX2; SOX2 and PAX6; SOX2 and LMX1A; SOX2, LMX...   Human
# 14                           SOX2, ASCL1, and NEUROG2   Human
# 15                                     ASCL1 and SOX2   Human
# 16                 FOXM1, SOX2, MYC, SALL4, and STAT6   Human
# 17  AR, SOX2, SMAD3, MYC, JUN, WT1, TAL1, SPI1, an...   Human
# 18           POU3F2, SOX2, BACH1, AR, PBX1, and NANOG   Human
# 19  ASCL1, PHOX2B, AP-2A, GATA3, HAND2, NURR1, and...    Both
# 20                               MSI1, NGN2, and MBD2   Human
# 21                   GATA4, MEF2C, TBX5, MESP1, MYOCD   Human
# 22     GATA4, MEF2C, TBX5, ESRRG, MESP1, ZFPM2, MYOCD   Human
# 23  HNF1A, HNF4A, HNF6, ATF5, PROX1, CEBPA, and MY...   Human
# 24     FOXA3, HNF1A, and HNF4A + SV40 Large T Antigen   Human
# 25  HNF1A, and Any Two of the Three Factors: FOXA1...   Human
# 26               ATF5, PROX1, FOXA2, FOXA3, and HNF4A   Human
# 27                      OCT4, FOXA2, HNF1A, and GATA3   Human
# 28                               PDX1, PAX4, and MAFA   Human
# 29                               NFE2, MAFG, and MAFK    Both
# 30                              PU.1, IRF8, and BATF3    Both
# 31                              c-MYC, KLF4, and SOX9   Human
# 32   OCT3/4 and OCT6 or OCT9 + L-MYC, c-MYC, or N-MYC   Human
# 33                    RUNX2, OCT4, OSTERIX, and L-MYC   Human
# 34                           OCT4, OSTERIX, and L-MYC   Human
# 35                                     MYOD1 and MYCL   Human
# 36                                   PRDM16 and CEBPB    Both
# 37                               CRX, RAX, and NEUROD   Human
# 38                              MITF, SOX10, and PAX3    Both
# 39                                              SOX18   Human
# 40                         CRX, RAX, OTX2, and NEUROD   Human
# 41                                    NF-κB and LEF-1   Human
# 42                                               OCT4   Human
# 43                       EMX2, HNF1B, HNF4A, and PAX8    Both
# 44                                              MYOCD   Human
# 45                          ER71/ETV2 (ETS Variant 2)   Human
# 46                                             PPARG2   Human
# 47                      HNF4A, FOXA3, GATA6, and CDX2    Both
# 48                            MYOCD, GATA6, and MEF2C    Both
# 49                              SNAI2, EYA1, and SIX1   Human
#
#    Cell Transplantation  Published Year          PMID
# 0                   Yes            2011    2172534_27
# 1                   NaN            2011   21617644_28
# 2                   NaN            2011   21646515_29
# 3                   Yes            2012   22683203_31
# 4                   Yes            2014  25129808_214
# 5                   NaN            2016   26725112_46
# 6                   NaN            2017   28844127_33
# 7                   NaN            2017  28697461_217
# 8                   NaN            2017  28327614_218
# 9                   NaN            2017  28099929_219
# 10                  NaN            2017   28587331_62
# 11                  NaN            2018   30450440_34
# 12                  Yes            2018   30030434_35
# 13                  NaN            2018   30018471_36
# 14                  NaN            2018  29937717_221
# 15                  NaN            2018  29915193_181
# 16                  NaN            2018   29653196_38
# 17                  NaN            2018   29653196_38
# 18                  NaN            2018   29653196_38
# 19                  Yes            2019  31315047_222
# 20                  Yes            2019   31196173_37
# 21                  NaN            2013   23861494_52
# 22                  Yes            2013   24319660_53
# 23                  Yes            2014   24582926_57
# 24                  Yes            2014   24582927_58
# 25                  NaN            2014   24963715_59
# 26                  NaN            2017   29192290_61
# 27                  NaN            2017   28587331_62
# 28                  NaN            2014   24504462_66
# 29                  Yes            2012   22855609_75
# 30                  NaN            2018   30530727_78
# 31                  Yes            2013  24146984_224
# 32                  NaN            2015   26499074_79
# 33                  Yes            2015   25918395_80
# 34                  Yes            2016   26990860_81
# 35                  Yes            2017   28501623_83
# 36                  Yes            2009   19641492_95
# 37                  NaN            2012   22558175_85
# 38                  Yes            2014   25510211_97
# 39                  NaN            2014   25290189_93
# 40                  NaN            2014   24456169_86
# 41                  Yes            2015   26566868_91
# 42                  NaN            2016  27019637_225
# 43                  Yes            2016   27820600_99
# 44                  NaN            2016   26874281_89
# 45                  Yes            2017   28003219_94
# 46                  NaN            2017   28982679_88
# 47                  Yes            2017  28943029_100
# 48                  NaN            2018   30026272_90
# 49                  NaN            2019  30827514_103

# %% [markdown]
# # Day 0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load known reprogramming regiems
df = pd.read_csv('data/known-regiems-T1.csv')

# %%
# get list of unique transcription factors
TFs = []
for regime in df['TFs'].unique():
    TFs += regime.replace(',', '').split()
TFs = list(set(TFs))
print(f"{len(TFs)=}")
TFs
# Out:
# len(TFs)=126
# ['PROX1',
#  'P53',
#  'N-MYC',
#  'LEF-1',
#  'PRDM16',
#  'NFE2',
#  'RUNX1',
#  'A',
#  'Ptf1a',
#  'SALL4',
#  'MESP1',
#  'PAX6',
#  'MYT1L',
#  'GATA3',
#  'SNAI2',
#  'ER71/ETV2',
#  'MAFA',
#  'CEBPB',
#  'Antigen',
#  'LXMLA',
#  'Two',
#  'SOX2;',
#  'FOXA3',
#  'HAND2',
#  'MBD2',
#  'NEUROD1',
#  'BACH1',
#  'AR',
#  'ZFPM2',
#  'RUNX2',
#  'CRX',
#  'GATA4',
#  'CEBPA',
#  'OCT4',
#  'FOXM1',
#  'MYC',
#  'PAX4',
#  'MITF',
#  'CDX2',
#  'LMX1A',
#  'OTX2',
#  'Variant',
#  'BRN2',
#  'MAFG',
#  'HB9',
#  'EYA1',
#  'PBX1',
#  'and',
#  'Factors:',
#  'SV40',
#  'NANOG',
#  'HNF1B',
#  'TP53',
#  'HNF6',
#  'LXH3',
#  'SOX10',
#  'OSTERIX',
#  'Large',
#  'TAL1',
#  'ESRRG',
#  'NEUROD',
#  'MASH1',
#  'SOX9',
#  'PHOX2A',
#  'FOXA1',
#  'STAT6',
#  'Any',
#  'SOX18',
#  'PHOX2B',
#  'the',
#  '(ETS',
#  'WT1',
#  'MEF2C',
#  'IRF8',
#  'NEUROG2',
#  'Dominant-Negative',
#  'PU.1',
#  'SOX11',
#  'LHX3',
#  'RAX',
#  'NGN2',
#  'ASCL1',
#  'BATF3',
#  'NURR1',
#  'SOX2',
#  'AP-2A',
#  'MAFK',
#  'or',
#  'PAX6;',
#  'JUN',
#  'ISL1',
#  'Knockdown',
#  'EMX2',
#  'GATA6',
#  '+',
#  'LMX1A;',
#  'POU3F2',
#  'c-MYC',
#  'HMGA2',
#  'HNF1A',
#  'SMAD3',
#  'OCT3/4',
#  'OCT9',
#  'MYOCD',
#  'L-MYC',
#  'T',
#  'SPI1',
#  'PPARG2',
#  'TBX5',
#  'PDX1',
#  'NF-κB',
#  'PITX3',
#  'MYOD1',
#  'PAX3',
#  'FOXA2',
#  'PAX8',
#  'of',
#  '2)',
#  'HNF4A',
#  'SIX1',
#  'Three',
#  'OCT6',
#  'MSI1',
#  'MYCL',
#  'KLF4',
#  'ATF5']
