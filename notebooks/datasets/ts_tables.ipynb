# %% [markdown]
# # Tables to Describe Tabula Sapiens

# %%
import os
import sys
import scanpy as sc
import anndata as ad
import numpy as np
import pandas as pd
import numpy
import pickle
from scipy.sparse import issparse, csr_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

def getFiles(category=None, model=None):
    h5ad_files = [] # list of all files
    targets    = [] # list of target
    for root, dirs, files in os.walk(DATAPATH):
        for file in files:
            if file.endswith('.h5ad'):
                h5ad_files.append(os.path.join(root, file))
    for root, dirs, files in os.walk(EMBPATH):
        for file in files:
            if file.endswith('.h5ad'):
                h5ad_files.append(os.path.join(root, file))
    for file in h5ad_files:
        if category is None and model in file:
            targets.append(file)
        elif model is None and category in file:
            targets.append(file)
        elif model == 'raw' and category in file:
            if 'geneformer' not in file and 'scgpt' not in file and 'Tgpt' not in file:
                targets.append(file)
        elif model is not None and category is not None and model in file and category in file:
            targets.append(file)
    return targets

def format_number(x):
    if isinstance(x, (float, np.float64)):
        return f"{x:.2g}"
    return x

# %% [markdown]
# ## Assemble Data

# %%
data_summary_file = '/nfs/turbo/umms-indikar/shared/projects/foundation_models/experiments/tabulaSapiens/data_summary.pkl'
with open(data_summary_file, 'rb') as file:
    data = pickle.load(file)

print("Data has been loaded from: " + data_summary_file)
print("You should not need to run the cells below")
# Out:
# Data has been loaded from: /nfs/turbo/umms-indikar/shared/projects/foundation_models/experiments/tabulaSapiens/data_summary.pkl
# You should not need to run the cells below

# %%
DATAPATH = "/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/"
EMBPATH  = "/nfs/turbo/umms-indikar/shared/projects/foundation_models/experiments/tabulaSapiens"

# %%
h5ad_files = []
for root, dirs, files in os.walk(DATAPATH):
    for file in files:
        if file.endswith('.h5ad'):
            h5ad_files.append(os.path.join(root, file))

tsCategories = []
for file in h5ad_files:
    tsCategories.append(file.split('.')[0].split('/')[-1])
tsCategories.remove('TabulaSapiens')
print(tsCategories)
models = ['raw', 'geneformer', 'Tgpt', 'scgpt']
print(models)
# Out:
# ['TS_germ line', 'TS_stromal', 'TS_Large_Intestine', 'TS_Lymph_Node', 'TS_Skin', 'TS_epithelial', 'TS_Spleen', 'TS_Vasculature', 'TS_Kidney', 'TS_Salivary_Gland', 'TS_Thymus', 'TS_Pancreas', 'TS_Fat', 'TS_Bladder', 'TS_endothelial', 'TS_Blood', 'TS_Trachea', 'TS_Bone_Marrow', 'TS_Tongue', 'TS_Lung', 'TS_Liver', 'TS_Small_Intestine', 'TS_immune', 'TS_Uterus', 'TS_Eye', 'TS_Mammary', 'TS_Prostate', 'TS_Heart', 'TS_Muscle']
# ['raw', 'geneformer', 'Tgpt', 'scgpt']

# %% [markdown]
# ### Rank and Effective Ranks of the Data

# %%
## Comput the SVD of each of dataset in each embedding space
import subprocess

# Define the number of jobs (assuming one job per file)
num_jobs = len(tsCategories) * len(models)

# SLURM parameters
job_name       = "TS-SVDs"
partition      = "standard"  # Specify your SLURM partition
nodes          = 1
tasks_per_node = 1
cpus_per_task  = 1
memory         = "100G"      # Adjust as per your memory requirements
account        = 'indikar0'
time           = "0:30:00"

# Loop over each category and model to submit jobs
job_id = 1
for category in tsCategories:
    for model in ['raw']: # models:
        file = getFiles(category=category, model=model)
        if len(file) == 0:
            continue
        file = file[0]
        if model == 'raw':
            time = "5:00:00"
        else:
            time = "1:00:00"

        # Construct command to run the Python script with arguments
        command = f"python svd_job.py {file} {category} {model}"

        # SLURM job submission command
        sbatch_cmd = f"sbatch --job-name {job_name} " \
                     f"--partition {partition} " \
                     f"--nodes={nodes} " \
                     f"--time={time} "\
                     f"--account={account} " \
                     f"--ntasks-per-node={tasks_per_node} " \
                     f"--cpus-per-task={cpus_per_task} " \
                     f"--mem={memory} " \
                     f"--output=/home/jpic/scFoundationProject/scFoundationModels/notebooks/datasets/logs/%x-%j.log " \
                     f"--wrap=\"{command}\""
        # print(sbatch_cmd)
        # Submit the job using subprocess
        subprocess.run(sbatch_cmd, shell=True)
        print(f"Submitted job {job_id}/{num_jobs}")
        job_id += 1
# Out:
# Submitted batch job 10888843
# Submitted job 1/116
# Submitted batch job 10888844
# Submitted job 2/116
# Submitted batch job 10888845
# Submitted job 3/116
# Submitted batch job 10888846
# Submitted job 4/116
# Submitted batch job 10888847
# Submitted job 5/116
# Submitted batch job 10888848
# Submitted job 6/116
# Submitted batch job 10888849
# Submitted job 7/116
# Submitted batch job 10888850
# Submitted job 8/116
# Submitted batch job 10888851
# Submitted job 9/116
# Submitted batch job 10888852
# Submitted job 10/116
# Submitted batch job 10888853
# Submitted job 11/116
# Submitted batch job 10888854
# Submitted job 12/116
# Submitted batch job 10888855
# Submitted job 13/116
# Submitted batch job 10888856
# Submitted job 14/116
# Submitted batch job 10888857
# Submitted job 15/116
# Submitted batch job 10888858
# Submitted job 16/116
# Submitted batch job 10888859
# Submitted job 17/116
# Submitted batch job 10888860
# Submitted job 18/116
# Submitted batch job 10888861
# Submitted job 19/116
# Submitted batch job 10888862
# Submitted job 20/116
# Submitted batch job 10888863
# Submitted job 21/116
# Submitted batch job 10888864
# Submitted job 22/116
# Submitted batch job 10888865
# Submitted job 23/116
# Submitted batch job 10888866
# Submitted job 24/116
# Submitted batch job 10888867
# Submitted job 25/116
# Submitted batch job 10888868
# Submitted job 26/116
# Submitted batch job 10888869
# Submitted job 27/116
# Submitted batch job 10888870
# Submitted job 28/116
# Submitted batch job 10888871
# Submitted job 29/116

# %%
result = {
    'file': [],
    'data': [],
    'model': [],
    'numCells': [],
    'dimension': [],
    'sigmas': []
}
for category in tsCategories:
    for model in models:
        output_file = f'/nfs/turbo/umms-indikar/shared/projects/foundation_models/experiments/tabulaSapiens/results/result_{category}_{model}.pkl'        
        if os.path.exists(output_file):
            with open(output_file, 'rb') as file:
                single_results = pickle.load(file)
                result['file'].append(output_file)
                result['data'].append(single_results['data'])
                result['model'].append(single_results['model'])
                result['numCells'].append(single_results['numCells'])
                result['dimension'].append(single_results['dimension'])
                result['sigmas'].append(single_results['sigmas'])
        else:
            # File does not exist, append None values
            result['file'].append(None)
            result['data'].append(category)
            result['model'].append(model)
            result['numCells'].append(None)
            result['dimension'].append(None)
            result['sigmas'].append(None)

df = pd.DataFrame(result)
df
# Out:
#                                                   file          data  \
# 0                                                 None  TS_germ line
# 1                                                 None  TS_germ line
# 2                                                 None  TS_germ line
# 3                                                 None  TS_germ line
# 4    /nfs/turbo/umms-indikar/shared/projects/founda...    TS_stromal
# ..                                                 ...           ...
# 111  /nfs/turbo/umms-indikar/shared/projects/founda...      TS_Heart
# 112  /nfs/turbo/umms-indikar/shared/projects/founda...     TS_Muscle
# 113  /nfs/turbo/umms-indikar/shared/projects/founda...     TS_Muscle
# 114  /nfs/turbo/umms-indikar/shared/projects/founda...     TS_Muscle
# 115  /nfs/turbo/umms-indikar/shared/projects/founda...     TS_Muscle
#
#           model  numCells  dimension  \
# 0           raw       NaN        NaN
# 1    geneformer       NaN        NaN
# 2          Tgpt       NaN        NaN
# 3         scgpt       NaN        NaN
# 4           raw   82478.0    58870.0
# ..          ...       ...        ...
# 111       scgpt   11505.0      512.0
# 112         raw   30746.0    58870.0
# 113  geneformer   30746.0      512.0
# 114        Tgpt   30746.0     1024.0
# 115       scgpt   30746.0      512.0
#
#                                                 sigmas
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4    [527.04584, 527.44977, 527.73, 527.86005, 528....
# ..                                                 ...
# 111  [102.1326, 24.3429, 10.272291, 9.001001, 6.298...
# 112  [334.51364, 334.55432, 334.70996, 334.8416, 33...
# 113  [2352.0562, 660.7629, 193.3488, 154.38156, 150...
# 114  [874.7479394410863, 2.6449773579307213e-05, 1....
# 115  [168.26132, 26.562035, 19.433113, 14.5399885, ...
#
# [116 rows x 6 columns]

# %%
def determine_rank_fixed_threshold(singular_values, epsilon=1e-10):
    return np.sum(singular_values > epsilon)

def determine_rank_energy_threshold(singular_values, energy_threshold=0.99):
    total_energy = np.sum(singular_values**2)
    cumulative_energy = np.cumsum(singular_values**2)
    rank = np.searchsorted(cumulative_energy, energy_threshold * total_energy) + 1
    return rank

def determine_rank_relative_threshold(singular_values, relative_threshold=1e-3):
    max_singular_value = np.max(singular_values)
    threshold = relative_threshold * max_singular_value
    return np.sum(singular_values > threshold)

# %%
v1 = 10
v2 = 0.90
v3 = 0.05
maxSv = []
eng90p = []
relS1 = []
fixed = []
for i in range(df.shape[0]):
    sigmas = df['sigmas'].iloc[i]
    if sigmas is None:
        maxSv.append(None)
        eng90p.append(None)
        relS1.append(None)
        fixed.append(None)
    else:
        maxSv.append(max(sigmas))
        fixed.append(determine_rank_fixed_threshold(sigmas, epsilon=v1))
        eng90p.append(determine_rank_energy_threshold(sigmas, energy_threshold=v2))
        relS1.append(determine_rank_relative_threshold(sigmas, relative_threshold=v3))

df['maxSv'] = maxSv
df['fixed'] = fixed
df['eng90p'] = eng90p
df['relS1'] = relS1

pivoted_df = df.pivot(index='data', columns='model', values=['maxSv', 'fixed', 'eng90p', 'relS1'])

# Flatten the multi-index columns
# pivoted_df.columns = [f'{col[1]} {col[0]}' for col in pivoted_df.columns]

# Reset the index to turn the 'data' index back into a column
pivoted_df.reset_index(inplace=True)

latex_table = pivoted_df.to_latex(index=False, escape=False, float_format="%.f")
latex_table = latex_table.replace(
    'TS_', ''
).replace(
    '\midrule', '\hline\hline'
).replace(
    'NaN', ''
).replace(
    r'\begin{tabular}{lrrrrrrrrrrrrrrrr}', r'\begin{tabular}{l|rrrrrrrrrrrrrrrr}'
).replace(
    '{4}{r}', '{4}{c}'
).replace(
    r'\toprule', ''
).replace(
    'data', '\multicolumn{1}{c}{}'
).replace('_', ' ').replace(
    'maxSv', 'Largest Singular Value $\sigma_1$'
).replace(
    'fixed', (r'$\sigma_r> \varepsilon$ ' + f'(\\varepsilon={v1})')
).replace(
    'eng90p', (r'$\sum_i^r\sigma_i\approx\varepsilon\sum\sigma_i$ ' + f'(\\varepsilon={v2})')
).replace(
    'relS1', (r'$\sigma_r\leq \varepsilon\sigma_1$ ' + f'(\\varepsilon={v3})')
).replace(
    r' & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt',
    r'\cmidrule(lr){2-5} \cmidrule(lr){6-9}\cmidrule(lr){10-13}\cmidrule(lr){14-17} & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt'
)
print(latex_table)
# Out:
# \begin{tabular}{l|rrrrrrrrrrrrrrrr}
#
# \multicolumn{1}{c}{} & \multicolumn{4}{c}{Largest Singular Value $\sigma_1$} & \multicolumn{4}{c}{$\sigma_r> \varepsilon$ (\varepsilon=10)} & \multicolumn{4}{c}{$\sum_i^r\sigma_i\approx\varepsilon\sum\sigma_i$ (\varepsilon=0.9)} & \multicolumn{4}{c}{$\sigma_r\leq \varepsilon\sigma_1$ (\varepsilon=0.05)} \\
# \cmidrule(lr){2-5} \cmidrule(lr){6-9}\cmidrule(lr){10-13}\cmidrule(lr){14-17} & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt \\
# \hline\hline
# Bladder & 647 & 2123 & 10113 & 149 & 127 & 189 & 250 & 6 & 12 & 2 & 250 & 2 & 21 & 6 & 36 & 10 \\
# Blood & 932 & 2893 & 13721 & 211 & 242 & 279 & 250 & 8 & 13 & 2 & 250 & 2 & 20 & 7 & 23 & 8 \\
# Bone Marrow & 477 & 1462 & 7180 & 105 & 69 & 150 & 250 & 4 & 11 & 2 & 250 & 2 & 18 & 7 & 45 & 11 \\
# Eye & 418 & 1412 & 7877 & 97 & 59 & 126 & 250 & 4 & 11 & 2 & 250 & 2 & 22 & 6 & 51 & 9 \\
# Fat & 575 & 1979 & 10502 & 137 & 98 & 170 & 250 & 5 & 11 & 2 & 250 & 1 & 21 & 5 & 28 & 10 \\
# Heart & 535 & 1504 & 10480 & 102 & 1 & 120 & 250 & 3 & 1 & 2 & 250 & 1 & 1 & 5 & 19 & 7 \\
# Kidney & 419 & 1364 & 9466 & 95 & 46 & 108 & 250 & 2 & 7 & 2 & 250 & 1 & 16 & 5 & 18 & 5 \\
  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# immune & 2196 & 6744 & 31711 & 491 & 653 & 440 & 250 & 26 & 12 & 2 & 250 & 1 & 19 & 6 & 32 & 10 \\
# stromal & 1154 & 3981 & 21517 & 275 & 275 & 301 & 250 & 14 & 10 & 2 & 250 & 1 & 20 & 5 & 34 & 9 \\
# \bottomrule
# \end{tabular}

# %%
v1 = 50
v2 = 0.99
v3 = 0.001
maxSv = []
eng90p = []
relS1 = []
fixed = []
for i in range(df.shape[0]):
    sigmas = df['sigmas'].iloc[i]
    if sigmas is None:
        maxSv.append(None)
        eng90p.append(None)
        relS1.append(None)
        fixed.append(None)
    else:
        maxSv.append(max(sigmas))
        fixed.append(determine_rank_fixed_threshold(sigmas, epsilon=v1))
        eng90p.append(determine_rank_energy_threshold(sigmas, energy_threshold=v2))
        relS1.append(determine_rank_relative_threshold(sigmas, relative_threshold=v3))

df['maxSv'] = maxSv
df['fixed'] = fixed
df['eng90p'] = eng90p
df['relS1'] = relS1

pivoted_df = df.pivot(index='data', columns='model', values=['maxSv', 'fixed', 'eng90p', 'relS1'])

# Flatten the multi-index columns
# pivoted_df.columns = [f'{col[1]} {col[0]}' for col in pivoted_df.columns]

# Reset the index to turn the 'data' index back into a column
pivoted_df.reset_index(inplace=True)

latex_table = pivoted_df.to_latex(index=False, escape=False, float_format="%.f")
latex_table = latex_table.replace(
    'TS_', ''
).replace(
    '\midrule', '\hline\hline'
).replace(
    'NaN', ''
).replace(
    r'\begin{tabular}{lrrrrrrrrrrrrrrrr}', r'\begin{tabular}{l|rrrrrrrrrrrrrrrr}'
).replace(
    '{4}{r}', '{4}{c}'
).replace(
    r'\toprule', ''
).replace(
    'data', '\multicolumn{1}{c}{}'
).replace('_', ' ').replace(
    'maxSv', 'Largest Singular Value $\sigma_1$'
).replace(
    'fixed', (r'$\sigma_r> \varepsilon$ ' + f'(\\varepsilon={v1})')
).replace(
    'eng90p', (r'$\sum_i^r\sigma_i\approx\varepsilon\sum\sigma_i$ ' + f'(\\varepsilon={v2})')
).replace(
    'relS1', (r'$\sigma_r\leq \varepsilon\sigma_1$ ' + f'(\\varepsilon={v3})')
).replace(
    r' & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt',
    r'\cmidrule(lr){2-5} \cmidrule(lr){6-9}\cmidrule(lr){10-13}\cmidrule(lr){14-17} & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt'
)
print(latex_table)
# Out:
# \begin{tabular}{l|rrrrrrrrrrrrrrrr}
#
# \multicolumn{1}{c}{} & \multicolumn{4}{c}{Largest Singular Value $\sigma_1$} & \multicolumn{4}{c}{$\sigma_r> \varepsilon$ (\varepsilon=50)} & \multicolumn{4}{c}{$\sum_i^r\sigma_i\approx\varepsilon\sum\sigma_i$ (\varepsilon=0.99)} & \multicolumn{4}{c}{$\sigma_r\leq \varepsilon\sigma_1$ (\varepsilon=0.001)} \\
# \cmidrule(lr){2-5} \cmidrule(lr){6-9}\cmidrule(lr){10-13}\cmidrule(lr){14-17} & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt \\
# Tongue & 510 & 1673 & 8927 & 115 & 8 & 13 & 250 & 1 & 378 & 48 & 250 & 18 & 1022 & 460 & 250 & 353 \\
# Trachea & 383 & 1321 & 6915 & 93 & 7 & 9 & 250 & 1 & 360 & 50 & 250 & 23 & 1022 & 458 & 250 & 353 \\
# Uterus & 341 & 1154 & 6309 & 80 & 4 & 7 & 250 & 1 & 339 & 44 & 250 & 22 & 1022 & 455 & 250 & 354 \\
# Vasculature & 510 & 1796 & 9856 & 120 & 8 & 14 & 250 & 1 & 346 & 42 & 250 & 20 & 1022 & 452 & 250 & 356 \\
# endothelial & 690 & 2397 & 14168 & 171 & 13 & 19 & 250 & 1 & 338 & 45 & 250 & 14 & 1022 & 460 & 250 & 332 \\
# epithelial & 1315 & 4432 & 21387 & 302 & 31 & 70 & 250 & 2 & 387 & 53 & 250 & 35 & 1022 & 465 & 250 & 415 \\
# germ line &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# immune & 2196 & 6744 & 31711 & 491 & 63 & 132 & 250 & 3 & 382 & 61 & 250 & 24 & 1022 & 468 & 250 & 375 \\
# stromal & 1154 & 3981 & 21517 & 275 & 23 & 50 & 250 & 1 & 339 & 45 & 250 & 19 & 1022 & 458 & 250 & 362 \\
# \bottomrule
# \end{tabular}

# %%
v1 = 50
v2 = 0.8
v3 = 0.5
maxSv = []
eng90p = []
relS1 = []
fixed = []
for i in range(df.shape[0]):
    sigmas = df['sigmas'].iloc[i]
    if sigmas is None:
        maxSv.append(None)
        eng90p.append(None)
        relS1.append(None)
        fixed.append(None)
    else:
        maxSv.append(max(sigmas))
        fixed.append(determine_rank_fixed_threshold(sigmas, epsilon=v1))
        eng90p.append(determine_rank_energy_threshold(sigmas, energy_threshold=v2))
        relS1.append(determine_rank_relative_threshold(sigmas, relative_threshold=v3))

df['maxSv'] = maxSv
df['fixed'] = fixed
df['eng90p'] = eng90p
df['relS1'] = relS1

pivoted_df = df.pivot(index='data', columns='model', values=['maxSv', 'fixed', 'eng90p', 'relS1'])

# Flatten the multi-index columns
# pivoted_df.columns = [f'{col[1]} {col[0]}' for col in pivoted_df.columns]

# Reset the index to turn the 'data' index back into a column
pivoted_df.reset_index(inplace=True)

latex_table = pivoted_df.to_latex(index=False, escape=False, float_format="%.f")
latex_table = latex_table.replace(
    'TS_', ''
).replace(
    '\midrule', '\hline\hline'
).replace(
    'NaN', ''
).replace(
    r'\begin{tabular}{lrrrrrrrrrrrrrrrr}', r'\begin{tabular}{l|rrrrrrrrrrrrrrrr}'
).replace(
    '{4}{r}', '{4}{c}'
).replace(
    r'\toprule', ''
).replace(
    'data', '\multicolumn{1}{c}{}'
).replace('_', ' ').replace(
    'maxSv', 'Largest Singular Value $\sigma_1$'
).replace(
    'fixed', (r'$\sigma_r> \varepsilon$ ' + f'(\\varepsilon={v1})')
).replace(
    'eng90p', (r'$\sum_i^r\sigma_i\approx\varepsilon\sum\sigma_i$ ' + f'(\\varepsilon={v2})')
).replace(
    'relS1', (r'$\sigma_r\leq \varepsilon\sigma_1$ ' + f'(\\varepsilon={v3})')
).replace(
    r' & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt',
    r'\cmidrule(lr){2-5} \cmidrule(lr){6-9}\cmidrule(lr){10-13}\cmidrule(lr){14-17} & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt'
)
print(latex_table)
# Out:
# \begin{tabular}{l|rrrrrrrrrrrrrrrr}
#
# \multicolumn{1}{c}{} & \multicolumn{4}{c}{Largest Singular Value $\sigma_1$} & \multicolumn{4}{c}{$\sigma_r> \varepsilon$ (\varepsilon=50)} & \multicolumn{4}{c}{$\sum_i^r\sigma_i\approx\varepsilon\sum\sigma_i$ (\varepsilon=0.8)} & \multicolumn{4}{c}{$\sigma_r\leq \varepsilon\sigma_1$ (\varepsilon=0.5)} \\
# \cmidrule(lr){2-5} \cmidrule(lr){6-9}\cmidrule(lr){10-13}\cmidrule(lr){14-17} & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt & Tgpt & geneformer & raw & scgpt \\
# \hline\hline
# Bladder & 647 & 2123 & 10113 & 149 & 10 & 20 & 250 & 1 & 3 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Blood & 932 & 2893 & 13721 & 211 & 18 & 35 & 250 & 2 & 4 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Bone Marrow & 477 & 1462 & 7180 & 105 & 8 & 12 & 250 & 1 & 3 & 1 & 250 & 1 & 1 & 1 & 2 & 1 \\
# Eye & 418 & 1412 & 7877 & 97 & 6 & 10 & 250 & 1 & 3 & 1 & 250 & 1 & 1 & 1 & 2 & 1 \\
# Fat & 575 & 1979 & 10502 & 137 & 9 & 14 & 250 & 1 & 3 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Heart & 535 & 1504 & 10480 & 102 & 1 & 9 & 250 & 1 & 1 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Kidney & 419 & 1364 & 9466 & 95 & 5 & 7 & 250 & 1 & 2 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Large Intestine & 472 & 1557 & 6713 & 112 & 8 & 8 & 250 & 1 & 3 & 1 & 250 & 1 & 1 & 1 & 2 & 1 \\
# Liver & 282 & 945 & 5450 & 68 & 3 & 6 & 250 & 1 & 2 & 1 & 250 & 1 & 1 & 1 & 2 & 1 \\
# Lung & 778 & 2661 & 13596 & 179 & 13 & 25 & 250 & 1 & 3 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Lymph Node & 1019 & 3033 & 14709 & 224 & 17 & 28 & 250 & 1 & 2 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Mammary & 439 & 1439 & 7325 & 102 & 6 & 9 & 250 & 1 & 3 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Muscle & 875 & 2352 & 12043 & 168 & 1 & 21 & 250 & 1 & 1 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Pancreas & 471 & 1573 & 7682 & 110 & 9 & 13 & 250 & 1 & 4 & 1 & 250 & 1 & 1 & 1 & 2 & 1 \\
# Prostate & 505 & 1716 & 8769 & 123 & 8 & 13 & 250 & 1 & 3 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Salivary Gland & 667 & 2180 & 9947 & 158 & 12 & 19 & 250 & 1 & 4 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Skin & 392 & 1292 & 6373 & 93 & 6 & 7 & 250 & 1 & 3 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Small Intestine & 471 & 1485 & 6774 & 108 & 7 & 8 & 250 & 1 & 3 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Spleen & 794 & 2443 & 11999 & 176 & 14 & 23 & 250 & 1 & 3 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Thymus & 762 & 2427 & 12131 & 177 & 13 & 21 & 250 & 1 & 3 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Tongue & 510 & 1673 & 8927 & 115 & 8 & 13 & 250 & 1 & 4 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Trachea & 383 & 1321 & 6915 & 93 & 7 & 9 & 250 & 1 & 4 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Uterus & 341 & 1154 & 6309 & 80 & 4 & 7 & 250 & 1 & 3 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# Vasculature & 510 & 1796 & 9856 & 120 & 8 & 14 & 250 & 1 & 3 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# endothelial & 690 & 2397 & 14168 & 171 & 13 & 19 & 250 & 1 & 2 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# epithelial & 1315 & 4432 & 21387 & 302 & 31 & 70 & 250 & 2 & 3 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# germ line &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# immune & 2196 & 6744 & 31711 & 491 & 63 & 132 & 250 & 3 & 3 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# stromal & 1154 & 3981 & 21517 & 275 & 23 & 50 & 250 & 1 & 2 & 1 & 250 & 1 & 1 & 1 & 1 & 1 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Summary Stats

# %%
dfData = pd.DataFrame(index = tsCategories)
dfData.index = dfData.index.map(lambda x: x[3:])
dfRep = pd.DataFrame(index = models)

# %%
data = []

for d in dfData.index:
    f = getFiles(category = 'TS_' + d, model='raw') #, model='geneformer') #_geneformer.h5ad
    print(f)
    adata = sc.read_h5ad(f[0])

    # Number of cells
    num_cells  = adata.shape[0]

    # female to mail ratio
    gender_distribution = adata.obs['gender'].value_counts()
    genders = list(gender_distribution.keys())
    if len(genders) == 2:
        fmr = gender_distribution.female / gender_distribution.male
    elif 'male' in genders:
        fmr = 'M'
    else:
        fmr = 'F'
    
    # unique molecular identifiers
    umi_mean = adata.obs['n_counts_UMIs'].mean()
    umi_median = adata.obs['n_counts_UMIs'].median()
    umi_std = adata.obs['n_counts_UMIs'].std()

    # Number of genes
    n_genes_mean = adata.obs['n_genes'].mean()
    n_genes_median = adata.obs['n_genes'].median()
    n_genes_std = adata.obs['n_genes'].std()
    
    # Anatomical information
    anatomy = ', '.join(adata.obs['anatomical_information'].unique())

    # Compartment
    compartment = ', '.join(adata.obs['compartment'].unique())

    # Methods
    methods = ', '.join(adata.obs['method'].unique())

    # Dataset
    ds = ', '.join(adata.obs['donor'].unique())

    # Append the collected data to the list
    data.append({
        'dataset': d,
        'num_cells': num_cells,
        'female_to_male_ratio': fmr,
        'umi_mean': umi_mean,
        'umi_median': umi_median,
        'umi_std': umi_std,
        'n_genes_mean': n_genes_mean,
        'n_genes_median': n_genes_median,
        'n_genes_std': n_genes_std,
        'anatomy': anatomy,
        'compartment': compartment,
        'methods': methods,
        'donor': ds
    })
    print(data[-1])

# Create a DataFrame from the collected data
df_results = pd.DataFrame(data)
# Out:
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_germ line.h5ad']
# {'dataset': 'germ line', 'num_cells': 11, 'female_to_male_ratio': 'M', 'umi_mean': 13773.818, 'umi_median': 11515.0, 'umi_std': 7367.68798828125, 'n_genes_mean': 2836.3636363636365, 'n_genes_median': 2775.0, 'n_genes_std': 1062.8599411707332, 'anatomy': 'nan', 'compartment': 'germ line', 'methods': '10X', 'donor': 'TSP14'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_stromal.h5ad']
# {'dataset': 'stromal', 'num_cells': 82478, 'female_to_male_ratio': 0.8408213369043633, 'umi_mean': 69257.82, 'umi_median': 10464.0, 'umi_std': 351686.34375, 'n_genes_mean': 3095.35902907442, 'n_genes_median': 2803.0, 'n_genes_std': 1462.1518160320982, 'anatomy': 'nan, Supradiaphagmatic, Parotid, Posterior, Endometrium, Myometrium, MAT, SCAT, Atria, Ventricle, exocrine, abdomen, chest, atria, ventricle, noCornea, lacrimalgland, diaphragm, rectusabdominus, whole, anterior, posterior, Sublingual, Cornea-etc, Neuroretina-etc, Sclera-etc, Distal, Proximal, Abdomen, Chest, Anterior, Diaphragm, AortaVeneCava, CoronaryArteries, distal, proximal, MedialDistal , proxmedialdistal, Neuron, Endocrine, Exocrine, Aorta, aorta', 'compartment': 'stromal', 'methods': '10X, smartseq2', 'donor': 'TSP6, TSP7, TSP4, TSP5, TSP3, TSP10, TSP12, TSP9, TSP8, TSP14, TSP15, TSP1, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Large_Intestine.h5ad']
# {'dataset': 'Large_Intestine', 'num_cells': 13680, 'female_to_male_ratio': 0.1959087332808812, 'umi_mean': 23675.748, 'umi_median': 6036.5, 'umi_std': 112187.65625, 'n_genes_mean': 1832.6504385964913, 'n_genes_median': 1525.5, 'n_genes_std': 980.5872224616902, 'anatomy': 'Distal, Proximal, distal, proximal, nan', 'compartment': 'immune, epithelial, stromal, endothelial', 'methods': '10X, smartseq2', 'donor': 'TSP14, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Lymph_Node.h5ad']
# {'dataset': 'Lymph_Node', 'num_cells': 53275, 'female_to_male_ratio': 0.7509120189305551, 'umi_mean': 25103.4, 'umi_median': 5949.0, 'umi_std': 119044.3203125, 'n_genes_mean': 2004.631290473956, 'n_genes_median': 1810.0, 'n_genes_std': 807.0289588636018, 'anatomy': 'Inguinal, Supradiaphagmatic, inguinal, supradiaphragmatic, nan', 'compartment': 'immune, endothelial, stromal', 'methods': '10X, smartseq2', 'donor': 'TSP7, TSP14, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Skin.h5ad']
# {'dataset': 'Skin', 'num_cells': 9424, 'female_to_male_ratio': 'M', 'umi_mean': 115167.19, 'umi_median': 7401.5, 'umi_std': 531242.8125, 'n_genes_mean': 2161.478034804754, 'n_genes_median': 1960.0, 'n_genes_std': 974.9489827632551, 'anatomy': 'nan, abdomen, chest, Abdomen, Chest', 'compartment': 'immune, stromal, endothelial, epithelial', 'methods': '10X, smartseq2', 'donor': 'TSP10, TSP14'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_epithelial.h5ad']
# {'dataset': 'epithelial', 'num_cells': 104148, 'female_to_male_ratio': 1.1368952357503386, 'umi_mean': 70796.49, 'umi_median': 11906.5, 'umi_std': 414406.875, 'n_genes_mean': 3028.2610899873257, 'n_genes_median': 2675.0, 'n_genes_std': 1752.915742969831, 'anatomy': 'nan, Parotid, Anterior, Posterior, Endometrium, Myometrium, Conjunctiva, Atria, Ventricle, exocrine, abdomen, chest, atria, ventricle, noCornea, lacrimalgland, whole, anterior, posterior, Sublingual, Cornea-etc, Neuroretina-etc, Sclera-etc, Distal, Proximal, Abdomen, Chest, distal, proximal, MedialDistal , proxmedialdistal, Neuron, Endocrine, Exocrine, Aorta', 'compartment': 'epithelial', 'methods': '10X, smartseq2', 'donor': 'TSP6, TSP7, TSP4, TSP5, TSP3, TSP10, TSP12, TSP9, TSP8, TSP14, TSP15, TSP1, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Spleen.h5ad']
# {'dataset': 'Spleen', 'num_cells': 34004, 'female_to_male_ratio': 0.7930816283484496, 'umi_mean': 33204.973, 'umi_median': 6628.0, 'umi_std': 146508.28125, 'n_genes_mean': 2349.5154099517704, 'n_genes_median': 2110.0, 'n_genes_std': 1167.4199364284573, 'anatomy': 'nan', 'compartment': 'immune, endothelial', 'methods': '10X, smartseq2', 'donor': 'TSP7, TSP14, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Vasculature.h5ad']
# {'dataset': 'Vasculature', 'num_cells': 16037, 'female_to_male_ratio': 1.1703884152118014, 'umi_mean': 24278.81, 'umi_median': 13304.0, 'umi_std': 52047.7578125, 'n_genes_mean': 3616.7917939764293, 'n_genes_median': 3426.0, 'n_genes_std': 1715.1142509251742, 'anatomy': 'AortaVeneCava, CoronaryArteries, Aorta, nan, aorta', 'compartment': 'stromal, immune, endothelial, epithelial', 'methods': '10X, smartseq2', 'donor': 'TSP14, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Kidney.h5ad']
# {'dataset': 'Kidney', 'num_cells': 9641, 'female_to_male_ratio': 'F', 'umi_mean': 24345.217, 'umi_median': 8520.0, 'umi_std': 98628.0546875, 'n_genes_mean': 2683.97323929053, 'n_genes_median': 2481.0, 'n_genes_std': 1069.4323423017286, 'anatomy': 'nan', 'compartment': 'epithelial, immune, endothelial', 'methods': '10X, smartseq2', 'donor': 'TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Salivary_Gland.h5ad']
# {'dataset': 'Salivary_Gland', 'num_cells': 27199, 'female_to_male_ratio': 0.5313027812183313, 'umi_mean': 39793.414, 'umi_median': 7092.0, 'umi_std': 214614.59375, 'n_genes_mean': 2446.1270267289237, 'n_genes_median': 2083.0, 'n_genes_std': 1698.5102734630711, 'anatomy': 'Parotid, Sublingual', 'compartment': 'epithelial, immune, stromal, endothelial', 'methods': '10X, smartseq2', 'donor': 'TSP7, TSP14'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Thymus.h5ad']
# {'dataset': 'Thymus', 'num_cells': 33664, 'female_to_male_ratio': 0.5601075169153767, 'umi_mean': 15215.986, 'umi_median': 6423.5, 'umi_std': 69065.6171875, 'n_genes_mean': 2401.8281547053234, 'n_genes_median': 2084.0, 'n_genes_std': 1066.8157077193953, 'anatomy': 'nan', 'compartment': 'immune, epithelial, stromal, endothelial', 'methods': '10X, smartseq2', 'donor': 'TSP14, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Pancreas.h5ad']
# {'dataset': 'Pancreas', 'num_cells': 13497, 'female_to_male_ratio': 1.0147783251231528, 'umi_mean': 107647.79, 'umi_median': 12816.0, 'umi_std': 521587.8125, 'n_genes_mean': 2954.093724531377, 'n_genes_median': 2614.0, 'n_genes_std': 1713.781155263306, 'anatomy': 'exocrine, Endocrine, Exocrine', 'compartment': 'epithelial, immune, endothelial, stromal', 'methods': '10X, smartseq2', 'donor': 'TSP9, TSP1'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Fat.h5ad']
# {'dataset': 'Fat', 'num_cells': 20263, 'female_to_male_ratio': 'M', 'umi_mean': 56812.285, 'umi_median': 11511.0, 'umi_std': 410517.34375, 'n_genes_mean': 3197.3036569116125, 'n_genes_median': 3132.0, 'n_genes_std': 1367.3564784455853, 'anatomy': 'MAT, SCAT', 'compartment': 'stromal, endothelial, immune', 'methods': '10X, smartseq2', 'donor': 'TSP10, TSP14'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Bladder.h5ad']
# {'dataset': 'Bladder', 'num_cells': 24583, 'female_to_male_ratio': 7.017938682322244, 'umi_mean': 43915.56, 'umi_median': 9327.0, 'umi_std': 236138.6875, 'n_genes_mean': 2720.9129886506935, 'n_genes_median': 2399.0, 'n_genes_std': 1380.5378991879945, 'anatomy': 'nan', 'compartment': 'immune, stromal, epithelial, endothelial', 'methods': '10X, smartseq2', 'donor': 'TSP14, TSP1, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_endothelial.h5ad']
# {'dataset': 'endothelial', 'num_cells': 31691, 'female_to_male_ratio': 0.9756249610373419, 'umi_mean': 77655.41, 'umi_median': 7436.0, 'umi_std': 388806.40625, 'n_genes_mean': 2702.6087217191002, 'n_genes_median': 2421.0, 'n_genes_std': 1262.8111113961622, 'anatomy': 'nan, Inguinal, Supradiaphagmatic, Parotid, Posterior, Endometrium, Myometrium, Orbital, MAT, SCAT, Atria, Ventricle, exocrine, abdomen, chest, atria, ventricle, lacrimalgland, noCornea, diaphragm, rectusabdominus, inguinal, supradiaphragmatic, anterior, posterior, Sublingual, Cornea-etc, Sclera-etc, Distal, Proximal, Abdomen, Chest, Anterior, Diaphragm, AortaVeneCava, CoronaryArteries, distal, proximal, MedialDistal , proxmedialdistal, Endocrine, Exocrine, Aorta, aorta', 'compartment': 'endothelial', 'methods': '10X, smartseq2', 'donor': 'TSP6, TSP7, TSP4, TSP5, TSP3, TSP10, TSP12, TSP9, TSP8, TSP14, TSP15, TSP1, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Blood.h5ad']
# {'dataset': 'Blood', 'num_cells': 50115, 'female_to_male_ratio': 1.9578587027090835, 'umi_mean': 25557.389, 'umi_median': 7814.0, 'umi_std': 162959.703125, 'n_genes_mean': 1847.9537264292128, 'n_genes_median': 1708.0, 'n_genes_std': 1199.3767996508157, 'anatomy': 'nan', 'compartment': 'immune', 'methods': '10X, smartseq2', 'donor': 'TSP7, TSP10, TSP8, TSP14, TSP1, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Trachea.h5ad']
# {'dataset': 'Trachea', 'num_cells': 9522, 'female_to_male_ratio': 0.8604923798358733, 'umi_mean': 57639.977, 'umi_median': 7810.0, 'umi_std': 277252.28125, 'n_genes_mean': 2834.2302037387103, 'n_genes_median': 2469.0, 'n_genes_std': 1494.6364652163534, 'anatomy': 'nan', 'compartment': 'immune, epithelial, stromal, endothelial', 'methods': '10X, smartseq2', 'donor': 'TSP6, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Bone_Marrow.h5ad']
# {'dataset': 'Bone_Marrow', 'num_cells': 12297, 'female_to_male_ratio': 0.3849532605023088, 'umi_mean': 109504.63, 'umi_median': 7741.0, 'umi_std': 405771.40625, 'n_genes_mean': 2400.6517036675614, 'n_genes_median': 2001.0, 'n_genes_std': 1548.5289985362385, 'anatomy': 'nan, vertebralbody', 'compartment': 'immune', 'methods': '10X, smartseq2', 'donor': 'TSP11, TSP13, TSP14, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Tongue.h5ad']
# {'dataset': 'Tongue', 'num_cells': 15020, 'female_to_male_ratio': 1.7727524460033228, 'umi_mean': 80515.84, 'umi_median': 10800.0, 'umi_std': 391156.59375, 'n_genes_mean': 2695.688548601864, 'n_genes_median': 2363.0, 'n_genes_std': 1512.0205688904314, 'anatomy': 'Anterior, Posterior, nan, anterior, posterior', 'compartment': 'epithelial, immune, stromal, endothelial', 'methods': '10X, smartseq2', 'donor': 'TSP7, TSP4, TSP14'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Lung.h5ad']
# {'dataset': 'Lung', 'num_cells': 35682, 'female_to_male_ratio': 7.2027586206896554, 'umi_mean': 68051.26, 'umi_median': 13465.5, 'umi_std': 318570.21875, 'n_genes_mean': 3275.1932066588197, 'n_genes_median': 3191.0, 'n_genes_std': 1481.6763930491543, 'anatomy': 'Distal, Proximal, nan, MedialDistal , proxmedialdistal, Neuron', 'compartment': 'epithelial, immune, endothelial, stromal', 'methods': '10X, smartseq2', 'donor': 'TSP14, TSP1, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Liver.h5ad']
# {'dataset': 'Liver', 'num_cells': 5007, 'female_to_male_ratio': 'M', 'umi_mean': 28392.615, 'umi_median': 6329.0, 'umi_std': 217181.59375, 'n_genes_mean': 2289.529458757739, 'n_genes_median': 2072.0, 'n_genes_std': 946.8976698906137, 'anatomy': 'nan', 'compartment': 'immune, endothelial, stromal, epithelial', 'methods': '10X, smartseq2', 'donor': 'TSP6, TSP14'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Small_Intestine.h5ad']
# {'dataset': 'Small_Intestine', 'num_cells': 12467, 'female_to_male_ratio': 0.19210174029451138, 'umi_mean': 32625.623, 'umi_median': 6369.0, 'umi_std': 175116.296875, 'n_genes_mean': 1967.3262212240315, 'n_genes_median': 1741.0, 'n_genes_std': 889.9268264741113, 'anatomy': 'Distal, Proximal, distal, proximal, nan', 'compartment': 'immune, epithelial, stromal, endothelial', 'methods': '10X, smartseq2', 'donor': 'TSP14, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_immune.h5ad']
# {'dataset': 'immune', 'num_cells': 264824, 'female_to_male_ratio': 0.9548101835790157, 'umi_mean': 36243.04, 'umi_median': 6467.0, 'umi_std': 211887.203125, 'n_genes_mean': 2130.1319026976407, 'n_genes_median': 1880.0, 'n_genes_std': 1107.4070386050994, 'anatomy': 'nan, Inguinal, Supradiaphagmatic, Parotid, Posterior, Endometrium, Myometrium, Orbital, MAT, SCAT, Atria, Ventricle, exocrine, abdomen, chest, atria, ventricle, vertebralbody, noCornea, lacrimalgland, diaphragm, rectusabdominus, whole, inguinal, supradiaphragmatic, anterior, posterior, Sublingual, Cornea-etc, Neuroretina-etc, Sclera-etc, Distal, Proximal, Abdomen, Chest, Anterior, Diaphragm, AortaVeneCava, CoronaryArteries, distal, proximal, MedialDistal , proxmedialdistal, Neuron, Endocrine, Exocrine, Aorta, aorta', 'compartment': 'immune', 'methods': '10X, smartseq2', 'donor': 'TSP6, TSP7, TSP4, TSP5, TSP10, TSP8, TSP3, TSP11, TSP12, TSP9, TSP13, TSP14, TSP15, TSP1, TSP2'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Uterus.h5ad']
# {'dataset': 'Uterus', 'num_cells': 7124, 'female_to_male_ratio': 'F', 'umi_mean': 93465.16, 'umi_median': 10123.0, 'umi_std': 593572.0625, 'n_genes_mean': 3062.347838293094, 'n_genes_median': 2722.0, 'n_genes_std': 1520.6161696220765, 'anatomy': 'Endometrium, Myometrium, nan', 'compartment': 'immune, stromal, epithelial, endothelial', 'methods': '10X, smartseq2', 'donor': 'TSP4'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Eye.h5ad']
# {'dataset': 'Eye', 'num_cells': 10650, 'female_to_male_ratio': 0.8980573872749955, 'umi_mean': 47718.64, 'umi_median': 10517.0, 'umi_std': 433921.4375, 'n_genes_mean': 3268.511549295775, 'n_genes_median': 2792.0, 'n_genes_std': 2096.543272530692, 'anatomy': 'nan, Conjunctiva, Orbital, noCornea, lacrimalgland, whole, Cornea-etc, Neuroretina-etc, Sclera-etc', 'compartment': 'epithelial, immune, stromal, endothelial', 'methods': '10X, smartseq2', 'donor': 'TSP5, TSP3, TSP15'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Mammary.h5ad']
# {'dataset': 'Mammary', 'num_cells': 11375, 'female_to_male_ratio': 'F', 'umi_mean': 86726.71, 'umi_median': 8506.0, 'umi_std': 603710.4375, 'n_genes_mean': 2504.7185934065933, 'n_genes_median': 2318.0, 'n_genes_std': 1152.741654483558, 'anatomy': 'nan', 'compartment': 'stromal, immune, epithelial, endothelial', 'methods': '10X, smartseq2', 'donor': 'TSP4'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Prostate.h5ad']
# {'dataset': 'Prostate', 'num_cells': 16375, 'female_to_male_ratio': 'M', 'umi_mean': 91032.62, 'umi_median': 7488.0, 'umi_std': 537543.625, 'n_genes_mean': 2474.9666564885497, 'n_genes_median': 2126.0, 'n_genes_std': 1373.4602589976716, 'anatomy': 'nan', 'compartment': 'epithelial, stromal, immune, endothelial, germ line', 'methods': '10X, smartseq2', 'donor': 'TSP8, TSP14'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Heart.h5ad']
# {'dataset': 'Heart', 'num_cells': 11505, 'female_to_male_ratio': 'M', 'umi_mean': 47384.58, 'umi_median': 11373.0, 'umi_std': 271071.21875, 'n_genes_mean': 3716.8061712299, 'n_genes_median': 3208.0, 'n_genes_std': 2092.2421811017066, 'anatomy': 'Atria, Ventricle, atria, ventricle', 'compartment': 'endothelial, stromal, epithelial, immune', 'methods': '10X, smartseq2', 'donor': 'TSP12'}
# ['/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/extract/TS_Muscle.h5ad']
# {'dataset': 'Muscle', 'num_cells': 30746, 'female_to_male_ratio': 2.6628544198236836, 'umi_mean': 123840.6, 'umi_median': 9269.0, 'umi_std': 410966.4375, 'n_genes_mean': 2428.3909776881546, 'n_genes_median': 2394.0, 'n_genes_std': 917.4659647224217, 'anatomy': 'diaphragm, rectusabdominus, Abdomen, Diaphragm, nan', 'compartment': 'endothelial, stromal, immune', 'methods': 'smartseq2, 10X', 'donor': 'TSP4, TSP14, TSP1, TSP2'}

# %% [raw]
# # You should not run this cell again so it has been set to raw
# data_summary_file = '/nfs/turbo/umms-indikar/shared/projects/foundation_models/experiments/tabulaSapiens/data_summary.pkl'
# with open(data_summary_file, 'wb') as file:
#     pickle.dump(data, file)

# %% [markdown]
# ## Dataset summary table

# %%
df_results = pd.DataFrame(data)
df_results['anatomy list'] = df_results['anatomy'].apply(lambda x: x.split(','))
df_results['num. anatomy'] = df_results['anatomy list'].apply(lambda x: 0 if x[0] == 'nan' else len(x))
df_results = df_results.drop(['anatomy list', 'anatomy'], axis=1)
df_results['donor list'] = df_results['donor'].apply(lambda x: x.split(','))
df_results['num. donor'] = df_results['donor list'].apply(lambda x: 0 if x[0] == 'nan' else len(x))
df_results = df_results.drop(['donor list', 'donor'], axis=1)
df_results['compartment list'] = df_results['compartment'].apply(lambda x: x.split(','))
df_results['num. compartment'] = df_results['compartment list'].apply(lambda x: 0 if x[0] == 'nan' else len(x))
df_results = df_results.drop(['compartment list', 'compartment'], axis=1)
df_results['10X'] = df_results['methods'].apply(lambda x: '\checkmark' if '10X' in x else '')
df_results['smartseq2'] = df_results['methods'].apply(lambda x: '\checkmark' if 'smartseq2' in x else '')
df_results = df_results.drop(['methods'], axis=1)
df_results.columns = ['Dataset', '\# Cells', 'F/M', 'avg. UMI', 'med. UMI', 'std. UMI', 'avg. \# genes', 'med. \# genes', 'std. \# genes', '\# anatomy', '\# donors', '\# compartments', '10X', 'smartseq2']
df_results = df_results.applymap(format_number)


latex_table = df_results.to_latex(index=False, escape=False, float_format="%.3f")

custom_table = latex_table.replace(
    r'\begin{tabular}{lrlllllllllll}',
    r'\begin{tabular}{l|rrrrrrrrrrrr}'
).replace(
    r'\toprule',
    r'\hline'
).replace(
    r'\midrule',
    r'\hline\hline'
).replace(
    '_', ' '
).replace(
    r"""\begin{tabular}{lrlllllllrrrll}
\hline
Dataset & \# Cells & F/M & avg. UMI & med. UMI & std. UMI & avg. \# genes & med. \# genes & std. \# genes & \# anatomy & \# donors & \# compartments & 10X & smartseq2 \\
""",
    r"""\begin{tabular}{l|rrrrrrrrrrrrrr}
\multicolumn{2}{c}{}& & \multicolumn{3}{c}{UMI} & \multicolumn{3}{c}{Num. Genes} &\multicolumn{3}{c}{Categories}&\multicolumn{2}{c}{Assays} \\
\cmidrule(lr){4-6} \cmidrule(lr){7-9}\cmidrule(lr){10-12}\cmidrule(lr){13-14}
Dataset & \# Cells & F/M &avg.&med.&std.&avg.&med.&std.&\# Anatomy &\# Donors&\# Compartments&10X&smartseq2\\
    """
)

# Print the LaTeX table
print(custom_table)
# Out:
# \begin{tabular}{l|rrrrrrrrrrrrrr}
# \multicolumn{2}{c}{}& & \multicolumn{3}{c}{UMI} & \multicolumn{3}{c}{Num. Genes} &\multicolumn{3}{c}{Categories}&\multicolumn{2}{c}{Assays} \\
# \cmidrule(lr){4-6} \cmidrule(lr){7-9}\cmidrule(lr){10-12}\cmidrule(lr){13-14}
# Dataset & \# Cells & F/M &avg.&med.&std.&avg.&med.&std.&\# Anatomy &\# Donors&\# Compartments&10X&smartseq2\\
#     \hline\hline
# germ line & 11 & M & 1.4e+04 & 1.2e+04 & 7.4e+03 & 2.8e+03 & 2.8e+03 & 1.1e+03 & 0 & 1 & 1 & \checkmark &  \\
# stromal & 82478 & 0.84 & 6.9e+04 & 1e+04 & 3.5e+05 & 3.1e+03 & 2.8e+03 & 1.5e+03 & 0 & 13 & 1 & \checkmark & \checkmark \\
# Large Intestine & 13680 & 0.2 & 2.4e+04 & 6e+03 & 1.1e+05 & 1.8e+03 & 1.5e+03 & 9.8e+02 & 5 & 2 & 4 & \checkmark & \checkmark \\
# Lymph Node & 53275 & 0.75 & 2.5e+04 & 5.9e+03 & 1.2e+05 & 2e+03 & 1.8e+03 & 8.1e+02 & 5 & 3 & 3 & \checkmark & \checkmark \\
# Skin & 9424 & M & 1.2e+05 & 7.4e+03 & 5.3e+05 & 2.2e+03 & 2e+03 & 9.7e+02 & 0 & 2 & 4 & \checkmark & \checkmark \\
# epithelial & 104148 & 1.1 & 7.1e+04 & 1.2e+04 & 4.1e+05 & 3e+03 & 2.7e+03 & 1.8e+03 & 0 & 13 & 1 & \checkmark & \checkmark \\
# Spleen & 34004 & 0.79 & 3.3e+04 & 6.6e+03 & 1.5e+05 & 2.3e+03 & 2.1e+03 & 1.2e+03 & 0 & 3 & 2 & \checkmark & \checkmark \\
# Vasculature & 16037 & 1.2 & 2.4e+04 & 1.3e+04 & 5.2e+04 & 3.6e+03 & 3.4e+03 & 1.7e+03 & 5 & 2 & 4 & \checkmark & \checkmark \\
# Kidney & 9641 & F & 2.4e+04 & 8.5e+03 & 9.9e+04 & 2.7e+03 & 2.5e+03 & 1.1e+03 & 0 & 1 & 3 & \checkmark & \checkmark \\
# Salivary Gland & 27199 & 0.53 & 4e+04 & 7.1e+03 & 2.1e+05 & 2.4e+03 & 2.1e+03 & 1.7e+03 & 2 & 2 & 4 & \checkmark & \checkmark \\
# Thymus & 33664 & 0.56 & 1.5e+04 & 6.4e+03 & 6.9e+04 & 2.4e+03 & 2.1e+03 & 1.1e+03 & 0 & 2 & 4 & \checkmark & \checkmark \\
# Heart & 11505 & M & 4.7e+04 & 1.1e+04 & 2.7e+05 & 3.7e+03 & 3.2e+03 & 2.1e+03 & 4 & 1 & 4 & \checkmark & \checkmark \\
# Muscle & 30746 & 2.7 & 1.2e+05 & 9.3e+03 & 4.1e+05 & 2.4e+03 & 2.4e+03 & 9.2e+02 & 5 & 4 & 3 & \checkmark & \checkmark \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_3074957/2707408305.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_results = df_results.applymap(format_number)

# %% [markdown]
# ## Categories Tables

# %%
# Anatomy table
df_results = pd.DataFrame(data)
df_results = df_results.drop(['num_cells', 'female_to_male_ratio', 'num_cells', 'female_to_male_ratio', 'umi_mean',
       'umi_median', 'umi_std', 'n_genes_mean', 'n_genes_median',
       'n_genes_std', 'compartment', 'methods', 'donor'], axis=1)
df_results.columns = ['Dataset', 'Anatomy']
df_results['anatomy list'] = df_results['Anatomy'].apply(lambda x: x.split(','))
df_results['Anatomy'] = df_results['anatomy list'].apply(lambda x: ', '.join(x))
df_results = df_results.drop(['anatomy list'], axis=1)
latex = df_results.to_latex(index=False)
latex = latex.replace('nan, ', '').replace('nan,', '').replace('nan', '').replace('_', ' ').replace('\midrule', '\hline\hline').replace(r'\begin{tabular}{ll}', r'\begin{tabular}{l|p{0.8\linewidth}}')

print(latex)
# Out:
# \begin{tabular}{l|p{0.8\linewidth}}
# \toprule
# Dataset & Anatomy \\
# \hline\hline
# germ line &  \\
# stromal &  Supradiaphagmatic,  Parotid,  Posterior,  Endometrium,  Myometrium,  MAT,  SCAT,  Atria,  Ventricle,  exocrine,  abdomen,  chest,  atria,  ventricle,  noCornea,  lacrimalgland,  diaphragm,  rectusabdominus,  whole,  anterior,  posterior,  Sublingual,  Cornea-etc,  Neuroretina-etc,  Sclera-etc,  Distal,  Proximal,  Abdomen,  Chest,  Anterior,  Diaphragm,  AortaVeneCava,  CoronaryArteries,  distal,  proximal,  MedialDistal ,  proxmedialdistal,  Neuron,  Endocrine,  Exocrine,  Aorta,  aorta \\
# Large Intestine & Distal,  Proximal,  distal,  proximal,   \\
# Lymph Node & Inguinal,  Supradiaphagmatic,  inguinal,  supradiaphragmatic,   \\
# Skin &  abdomen,  chest,  Abdomen,  Chest \\
# epithelial &  Parotid,  Anterior,  Posterior,  Endometrium,  Myometrium,  Conjunctiva,  Atria,  Ventricle,  exocrine,  abdomen,  chest,  atria,  ventricle,  noCornea,  lacrimalgland,  whole,  anterior,  posterior,  Sublingual,  Cornea-etc,  Neuroretina-etc,  Sclera-etc,  Distal,  Proximal,  Abdomen,  Chest,  distal,  proximal,  MedialDistal ,  proxmedialdistal,  Neuron,  Endocrine,  Exocrine,  Aorta \\
# Spleen &  \\
# Vasculature & AortaVeneCava,  CoronaryArteries,  Aorta,   aorta \\
# Kidney &  \\
# Salivary Gland & Parotid,  Sublingual \\
# Thymus &  \\
# Pancreas & exocrine,  Endocrine,  Exocrine \\
# Fat & MAT,  SCAT \\
# Bladder &  \\
# endothelial &  Inguinal,  Supradiaphagmatic,  Parotid,  Posterior,  Endometrium,  Myometrium,  Orbital,  MAT,  SCAT,  Atria,  Ventricle,  exocrine,  abdomen,  chest,  atria,  ventricle,  lacrimalgland,  noCornea,  diaphragm,  rectusabdominus,  inguinal,  supradiaphragmatic,  anterior,  posterior,  Sublingual,  Cornea-etc,  Sclera-etc,  Distal,  Proximal,  Abdomen,  Chest,  Anterior,  Diaphragm,  AortaVeneCava,  CoronaryArteries,  distal,  proximal,  MedialDistal ,  proxmedialdistal,  Endocrine,  Exocrine,  Aorta,  aorta \\
# Blood &  \\
# Trachea &  \\
# Bone Marrow &  vertebralbody \\
# Tongue & Anterior,  Posterior,   anterior,  posterior \\
# Lung & Distal,  Proximal,   MedialDistal ,  proxmedialdistal,  Neuron \\
# Liver &  \\
# Small Intestine & Distal,  Proximal,  distal,  proximal,   \\
# immune &  Inguinal,  Supradiaphagmatic,  Parotid,  Posterior,  Endometrium,  Myometrium,  Orbital,  MAT,  SCAT,  Atria,  Ventricle,  exocrine,  abdomen,  chest,  atria,  ventricle,  vertebralbody,  noCornea,  lacrimalgland,  diaphragm,  rectusabdominus,  whole,  inguinal,  supradiaphragmatic,  anterior,  posterior,  Sublingual,  Cornea-etc,  Neuroretina-etc,  Sclera-etc,  Distal,  Proximal,  Abdomen,  Chest,  Anterior,  Diaphragm,  AortaVeneCava,  CoronaryArteries,  distal,  proximal,  MedialDistal ,  proxmedialdistal,  Neuron,  Endocrine,  Exocrine,  Aorta,  aorta \\
# Uterus & Endometrium,  Myometrium,   \\
# Eye &  Conjunctiva,  Orbital,  noCornea,  lacrimalgland,  whole,  Cornea-etc,  Neuroretina-etc,  Sclera-etc \\
# Mammary &  \\
# Prostate &  \\
# Heart & Atria,  Ventricle,  atria,  ventricle \\
# Muscle & diaphragm,  rectusabdominus,  Abdomen,  Diaphragm,   \\
# \bottomrule
# \end{tabular}

# %%
# Compartment table
df_results = pd.DataFrame(data)
df_results = df_results.drop(['num_cells', 'female_to_male_ratio', 'num_cells', 'female_to_male_ratio', 'umi_mean',
       'umi_median', 'umi_std', 'n_genes_mean', 'n_genes_median',
       'n_genes_std', 'anatomy', 'methods', 'donor'], axis=1)
df_results.columns = ['Dataset', 'Compartment']
df_results['Compartment list'] = df_results['Compartment'].apply(lambda x: x.split(','))
df_results['Compartment'] = df_results['Compartment list'].apply(lambda x: ', '.join(x))
df_results = df_results.drop(['Compartment list'], axis=1)
latex = df_results.to_latex(index=False)
latex = latex.replace('nan, ', '').replace('nan,', '').replace('nan', '').replace('_', ' ').replace('\midrule', '\hline\hline').replace(r'\begin{tabular}{ll}', r'\begin{tabular}{l|l}')

print(latex)
# Out:
# \begin{tabular}{l|l}
# \toprule
# Dataset & Compartment \\
# \hline\hline
# germ line & germ line \\
# stromal & stromal \\
# Large Intestine & immune,  epithelial,  stromal,  endothelial \\
# Lymph Node & immune,  endothelial,  stromal \\
# Skin & immune,  stromal,  endothelial,  epithelial \\
# epithelial & epithelial \\
# Spleen & immune,  endothelial \\
# Vasculature & stromal,  immune,  endothelial,  epithelial \\
# Kidney & epithelial,  immune,  endothelial \\
# Salivary Gland & epithelial,  immune,  stromal,  endothelial \\
# Thymus & immune,  epithelial,  stromal,  endothelial \\
# Pancreas & epithelial,  immune,  endothelial,  stromal \\
# Fat & stromal,  endothelial,  immune \\
# Bladder & immune,  stromal,  epithelial,  endothelial \\
# endothelial & endothelial \\
# Blood & immune \\
# Trachea & immune,  epithelial,  stromal,  endothelial \\
# Bone Marrow & immune \\
# Tongue & epithelial,  immune,  stromal,  endothelial \\
# Lung & epithelial,  immune,  endothelial,  stromal \\
# Liver & immune,  endothelial,  stromal,  epithelial \\
# Small Intestine & immune,  epithelial,  stromal,  endothelial \\
# immune & immune \\
# Uterus & immune,  stromal,  epithelial,  endothelial \\
# Eye & epithelial,  immune,  stromal,  endothelial \\
# Mammary & stromal,  immune,  epithelial,  endothelial \\
# Prostate & epithelial,  stromal,  immune,  endothelial,  germ line \\
# Heart & endothelial,  stromal,  epithelial,  immune \\
# Muscle & endothelial,  stromal,  immune \\
# \bottomrule
# \end{tabular}

# %%
# Donor table
df_results = pd.DataFrame(data)
df_results = df_results.drop(['num_cells', 'female_to_male_ratio', 'num_cells', 'female_to_male_ratio', 'umi_mean',
       'umi_median', 'umi_std', 'n_genes_mean', 'n_genes_median',
       'n_genes_std', 'anatomy', 'methods', 'compartment'], axis=1)
df_results.columns = ['Dataset', 'Donor']
df_results['Donor list'] = df_results['Donor'].apply(lambda x: x.split(','))
df_results['Donor'] = df_results['Donor list'].apply(lambda x: ', '.join(x))
df_results = df_results.drop(['Donor list'], axis=1)
latex = df_results.to_latex(index=False)
latex = latex.replace('nan, ', '').replace('nan,', '').replace('nan', '').replace('_', ' ').replace('\midrule', '\hline\hline').replace(r'\begin{tabular}{ll}', r'\begin{tabular}{l|l}')

print(latex)
# Out:
# \begin{tabular}{l|l}
# \toprule
# Dataset & Donor \\
# \hline\hline
# germ line & TSP14 \\
# stromal & TSP6,  TSP7,  TSP4,  TSP5,  TSP3,  TSP10,  TSP12,  TSP9,  TSP8,  TSP14,  TSP15,  TSP1,  TSP2 \\
# Large Intestine & TSP14,  TSP2 \\
# Lymph Node & TSP7,  TSP14,  TSP2 \\
# Skin & TSP10,  TSP14 \\
# epithelial & TSP6,  TSP7,  TSP4,  TSP5,  TSP3,  TSP10,  TSP12,  TSP9,  TSP8,  TSP14,  TSP15,  TSP1,  TSP2 \\
# Spleen & TSP7,  TSP14,  TSP2 \\
# Vasculature & TSP14,  TSP2 \\
# Kidney & TSP2 \\
# Salivary Gland & TSP7,  TSP14 \\
# Thymus & TSP14,  TSP2 \\
# Pancreas & TSP9,  TSP1 \\
# Fat & TSP10,  TSP14 \\
# Bladder & TSP14,  TSP1,  TSP2 \\
# endothelial & TSP6,  TSP7,  TSP4,  TSP5,  TSP3,  TSP10,  TSP12,  TSP9,  TSP8,  TSP14,  TSP15,  TSP1,  TSP2 \\
# Blood & TSP7,  TSP10,  TSP8,  TSP14,  TSP1,  TSP2 \\
# Trachea & TSP6,  TSP2 \\
# Bone Marrow & TSP11,  TSP13,  TSP14,  TSP2 \\
# Tongue & TSP7,  TSP4,  TSP14 \\
# Lung & TSP14,  TSP1,  TSP2 \\
# Liver & TSP6,  TSP14 \\
# Small Intestine & TSP14,  TSP2 \\
# immune & TSP6,  TSP7,  TSP4,  TSP5,  TSP10,  TSP8,  TSP3,  TSP11,  TSP12,  TSP9,  TSP13,  TSP14,  TSP15,  TSP1,  TSP2 \\
# Uterus & TSP4 \\
# Eye & TSP5,  TSP3,  TSP15 \\
# Mammary & TSP4 \\
# Prostate & TSP8,  TSP14 \\
# Heart & TSP12 \\
# Muscle & TSP4,  TSP14,  TSP1,  TSP2 \\
# \bottomrule
# \end{tabular}

# %%
df_results = pd.DataFrame(data)
df_results['anatomy list'] = df_results['anatomy'].apply(lambda x: x.split(','))
df_results['num. anatomy'] = df_results['anatomy list'].apply(lambda x: 0 if x[0] == 'nan' else len(x))
df_results = df_results.drop(['anatomy list', 'anatomy'], axis=1)
df_results['donor list'] = df_results['donor'].apply(lambda x: x.split(','))
df_results['num. donor'] = df_results['donor list'].apply(lambda x: 0 if x[0] == 'nan' else len(x))
df_results = df_results.drop(['donor list', 'donor'], axis=1)
df_results['compartment list'] = df_results['compartment'].apply(lambda x: x.split(','))
df_results['num. compartment'] = df_results['compartment list'].apply(lambda x: 0 if x[0] == 'nan' else len(x))
df_results = df_results.drop(['compartment list', 'compartment'], axis=1)
df_results['10X'] = df_results['methods'].apply(lambda x: '\checkmark' if '10X' in x else '')
df_results['smartseq2'] = df_results['methods'].apply(lambda x: '\checkmark' if 'smartseq2' in x else '')
df_results = df_results.drop(['methods'], axis=1)
df_results.columns = ['Dataset', '\# Cells', 'F/M', 'avg. UMI', 'med. UMI', 'std. UMI', 'avg. \# genes', 'med. \# genes', 'std. \# genes', '\# anatomy', '\# donors', '\# compartments', '10X', 'smartseq2']
df_results = df_results.applymap(format_number)

# %%
def format_number(x):
    if isinstance(x, (float, np.float64)):
        return f"{x:.2g}"
    return x

df_results = pd.DataFrame(data)
df_results.columns = ['Dataset', 'Number of Cells', 'F/M', 'avg. UMI', 'med. UMI', 'std. UMI', 'avg. num. genes', 'med. num. genes', 'std. num. genes', 'anatomy', 'compartment', 'assay', 'donor']
# df_results.columns = df_results.columns.str.replace('_', ' ')

# Apply number formatting
df_results = df_results.applymap(format_number)

# Convert DataFrame to LaTeX
latex_table = df_results.to_latex(index=False, escape=False, float_format="%.3f")

custom_table = latex_table.replace(
    r'\begin{tabular}{lrlllllllllll}',
    r'\begin{tabular}{l|rrrrrrrrrrrr}'
).replace(
    r'\toprule',
    r'\hline'
).replace(
    r'\midrule',
    r'\hline\hline'
).replace(
    '_', ' '
)

# Print the LaTeX table
print(custom_table)
# Out:
# \begin{tabular}{l|rrrrrrrrrrrr}
# \hline
# Dataset & Number of Cells & F/M & avg. UMI & med. UMI & std. UMI & avg. num. genes & med. num. genes & std. num. genes & anatomy & compartment & assay & donor \\
# \hline\hline
FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_results = df_results.applymap(format_number)

# %%
help(df_results.to_latex)
# Out:
# Help on method to_latex in module pandas.core.generic:
#
# to_latex(buf: 'FilePath | WriteBuffer[str] | None' = None, columns: 'Sequence[Hashable] | None' = None, header: 'bool_t | list[str]' = True, index: 'bool_t' = True, na_rep: 'str' = 'NaN', formatters: 'FormattersType | None' = None, float_format: 'FloatFormatType | None' = None, sparsify: 'bool_t | None' = None, index_names: 'bool_t' = True, bold_rows: 'bool_t' = False, column_format: 'str | None' = None, longtable: 'bool_t | None' = None, escape: 'bool_t | None' = None, encoding: 'str | None' = None, decimal: 'str' = '.', multicolumn: 'bool_t | None' = None, multicolumn_format: 'str | None' = None, multirow: 'bool_t | None' = None, caption: 'str | tuple[str, str] | None' = None, label: 'str | None' = None, position: 'str | None' = None) -> 'str | None' method of pandas.core.frame.DataFrame instance
#     Render object to a LaTeX tabular, longtable, or nested table.
#
#     Requires ``\usepackage{{booktabs}}``.  The output can be copy/pasted
#     into a main LaTeX document or read from an external file
#     with ``\input{{table.tex}}``.
#
#     .. versionchanged:: 1.2.0
#        Added position argument, changed meaning of caption argument.
#
#     .. versionchanged:: 2.0.0
#        Refactored to use the Styler implementation via jinja2 templating.
#
#     Parameters
#     ----------
#     buf : str, Path or StringIO-like, optional, default None
#         Buffer to write to. If None, the output is returned as a string.
#     columns : list of label, optional
#         The subset of columns to write. Writes all columns by default.
#     header : bool or list of str, default True
#         Write out the column names. If a list of strings is given,
#         it is assumed to be aliases for the column names.
#     index : bool, default True
#         Write row names (index).
#     na_rep : str, default 'NaN'
#         Missing data representation.
#     formatters : list of functions or dict of {{str: function}}, optional
#         Formatter functions to apply to columns' elements by position or
#         name. The result of each function must be a unicode string.
#         List must be of length equal to the number of columns.
#     float_format : one-parameter function or str, optional, default None
#         Formatter for floating point numbers. For example
#         ``float_format="%.2f"`` and ``float_format="{{:0.2f}}".format`` will
#         both result in 0.1234 being formatted as 0.12.
#     sparsify : bool, optional
#         Set to False for a DataFrame with a hierarchical index to print
#         every multiindex key at each row. By default, the value will be
#         read from the config module.
#     index_names : bool, default True
#         Prints the names of the indexes.
#     bold_rows : bool, default False
#         Make the row labels bold in the output.
#     column_format : str, optional
#         The columns format as specified in `LaTeX table format
#         <https://en.wikibooks.org/wiki/LaTeX/Tables>`__ e.g. 'rcl' for 3
#         columns. By default, 'l' will be used for all columns except
#         columns of numbers, which default to 'r'.
#     longtable : bool, optional
#         Use a longtable environment instead of tabular. Requires
#         adding a \usepackage{{longtable}} to your LaTeX preamble.
#         By default, the value will be read from the pandas config
#         module, and set to `True` if the option ``styler.latex.environment`` is
#         `"longtable"`.
#
#         .. versionchanged:: 2.0.0
#            The pandas option affecting this argument has changed.
#     escape : bool, optional
#         By default, the value will be read from the pandas config
#         module and set to `True` if the option ``styler.format.escape`` is
#         `"latex"`. When set to False prevents from escaping latex special
#         characters in column names.
#
#         .. versionchanged:: 2.0.0
#            The pandas option affecting this argument has changed, as has the
#            default value to `False`.
#     encoding : str, optional
#         A string representing the encoding to use in the output file,
#         defaults to 'utf-8'.
#     decimal : str, default '.'
#         Character recognized as decimal separator, e.g. ',' in Europe.
#     multicolumn : bool, default True
#         Use \multicolumn to enhance MultiIndex columns.
#         The default will be read from the config module, and is set
#         as the option ``styler.sparse.columns``.
#
#         .. versionchanged:: 2.0.0
#            The pandas option affecting this argument has changed.
#     multicolumn_format : str, default 'r'
#         The alignment for multicolumns, similar to `column_format`
#         The default will be read from the config module, and is set as the option
#         ``styler.latex.multicol_align``.
#
#         .. versionchanged:: 2.0.0
#            The pandas option affecting this argument has changed, as has the
#            default value to "r".
#     multirow : bool, default True
#         Use \multirow to enhance MultiIndex rows. Requires adding a
#         \usepackage{{multirow}} to your LaTeX preamble. Will print
#         centered labels (instead of top-aligned) across the contained
#         rows, separating groups via clines. The default will be read
#         from the pandas config module, and is set as the option
#         ``styler.sparse.index``.
#
#         .. versionchanged:: 2.0.0
#            The pandas option affecting this argument has changed, as has the
#            default value to `True`.
#     caption : str or tuple, optional
#         Tuple (full_caption, short_caption),
#         which results in ``\caption[short_caption]{{full_caption}}``;
#         if a single string is passed, no short caption will be set.
#
#         .. versionchanged:: 1.2.0
#            Optionally allow caption to be a tuple ``(full_caption, short_caption)``.
#
#     label : str, optional
#         The LaTeX label to be placed inside ``\label{{}}`` in the output.
#         This is used with ``\ref{{}}`` in the main ``.tex`` file.
#
#     position : str, optional
#         The LaTeX positional argument for tables, to be placed after
#         ``\begin{{}}`` in the output.
#
#         .. versionadded:: 1.2.0
#
#     Returns
#     -------
#     str or None
#         If buf is None, returns the result as a string. Otherwise returns None.
#
#     See Also
#     --------
#     io.formats.style.Styler.to_latex : Render a DataFrame to LaTeX
#         with conditional formatting.
#     DataFrame.to_string : Render a DataFrame to a console-friendly
#         tabular output.
#     DataFrame.to_html : Render a DataFrame as an HTML table.
#
#     Notes
#     -----
#     As of v2.0.0 this method has changed to use the Styler implementation as
#     part of :meth:`.Styler.to_latex` via ``jinja2`` templating. This means
#     that ``jinja2`` is a requirement, and needs to be installed, for this method
#     to function. It is advised that users switch to using Styler, since that
#     implementation is more frequently updated and contains much more
#     flexibility with the output.
#
#     Examples
#     --------
#     Convert a general DataFrame to LaTeX with formatting:
#
#     >>> df = pd.DataFrame(dict(name=['Raphael', 'Donatello'],
#     ...                        age=[26, 45],
#     ...                        height=[181.23, 177.65]))
#     >>> print(df.to_latex(index=False,
#     ...                   formatters={"name": str.upper},
#     ...                   float_format="{:.1f}".format,
#     ... ))  # doctest: +SKIP
#     \begin{tabular}{lrr}
#     \toprule
#     name & age & height \\
#     \midrule
#     RAPHAEL & 26 & 181.2 \\
#     DONATELLO & 45 & 177.7 \\
#     \bottomrule
#     \end{tabular}

# %%
list(gender_distribution.keys())
# Out:
# ['male']

# %%
adata.obs
# Out:
#                                            organ_tissue method  donor  \
# cell_id
# cell_id
# ACTATTCAGGTCATCT_TSP14_Prostate_NA_10X_1_1               sperm
# AGGTTGTCAACCCTAA_TSP14_Prostate_NA_10X_1_1               sperm
# ATCCGTCGTGCTATTG_TSP14_Prostate_NA_10X_1_1               sperm
# GAGCCTGAGCATGCAG_TSP14_Prostate_NA_10X_1_1               sperm
# GGGACTCCAATGAGCG_TSP14_Prostate_NA_10X_1_1               sperm
# TGACCCTTCATCGCCT_TSP14_Prostate_NA_10X_1_1               sperm
# AACACACAGCGAACTG_TSP14_Prostate_NA_10X_1_2               sperm
# AAGGAATGTATTCTCT_TSP14_Prostate_NA_10X_1_2               sperm
# ACTATCTCATCCGAAT_TSP14_Prostate_NA_10X_1_2               sperm
# CGGGTCAAGTATTAGG_TSP14_Prostate_NA_10X_1_2               sperm
# TCGGGCAAGGTAGACC_TSP14_Prostate_NA_10X_1_2               sperm
#
#                                            free_annotation  \
# cell_id
# ACTATTCAGGTCATCT_TSP14_Prostate_NA_10X_1_1      Sperm Cell
# AGGTTGTCAACCCTAA_TSP14_Prostate_NA_10X_1_1      Sperm Cell
# ATCCGTCGTGCTATTG_TSP14_Prostate_NA_10X_1_1      Sperm Cell
# GAGCCTGAGCATGCAG_TSP14_Prostate_NA_10X_1_1      Sperm Cell
# GGGACTCCAATGAGCG_TSP14_Prostate_NA_10X_1_1      Sperm Cell
# TGACCCTTCATCGCCT_TSP14_Prostate_NA_10X_1_1      Sperm Cell
# AACACACAGCGAACTG_TSP14_Prostate_NA_10X_1_2      Sperm Cell
# AAGGAATGTATTCTCT_TSP14_Prostate_NA_10X_1_2      Sperm Cell
# ACTATCTCATCCGAAT_TSP14_Prostate_NA_10X_1_2      Sperm Cell
# CGGGTCAAGTATTAGG_TSP14_Prostate_NA_10X_1_2      Sperm Cell
# TCGGGCAAGGTAGACC_TSP14_Prostate_NA_10X_1_2      Sperm Cell
#
#                                             manually_annotated compartment  \
# cell_id
# ACTATTCAGGTCATCT_TSP14_Prostate_NA_10X_1_1                True   germ line
# AGGTTGTCAACCCTAA_TSP14_Prostate_NA_10X_1_1                True   germ line
# ATCCGTCGTGCTATTG_TSP14_Prostate_NA_10X_1_1                True   germ line
# GAGCCTGAGCATGCAG_TSP14_Prostate_NA_10X_1_1                True   germ line
# GGGACTCCAATGAGCG_TSP14_Prostate_NA_10X_1_1                True   germ line
# TGACCCTTCATCGCCT_TSP14_Prostate_NA_10X_1_1                True   germ line
# AACACACAGCGAACTG_TSP14_Prostate_NA_10X_1_2                True   germ line
# AAGGAATGTATTCTCT_TSP14_Prostate_NA_10X_1_2                True   germ line
# ACTATCTCATCCGAAT_TSP14_Prostate_NA_10X_1_2                True   germ line
# CGGGTCAAGTATTAGG_TSP14_Prostate_NA_10X_1_2                True   germ line
# TCGGGCAAGGTAGACC_TSP14_Prostate_NA_10X_1_2                True   germ line
#
#                                            gender
# cell_id
# ACTATTCAGGTCATCT_TSP14_Prostate_NA_10X_1_1   male
# AGGTTGTCAACCCTAA_TSP14_Prostate_NA_10X_1_1   male
# ATCCGTCGTGCTATTG_TSP14_Prostate_NA_10X_1_1   male
# GAGCCTGAGCATGCAG_TSP14_Prostate_NA_10X_1_1   male
# GGGACTCCAATGAGCG_TSP14_Prostate_NA_10X_1_1   male
# TGACCCTTCATCGCCT_TSP14_Prostate_NA_10X_1_1   male
# AACACACAGCGAACTG_TSP14_Prostate_NA_10X_1_2   male
# AAGGAATGTATTCTCT_TSP14_Prostate_NA_10X_1_2   male
# ACTATCTCATCCGAAT_TSP14_Prostate_NA_10X_1_2   male
# CGGGTCAAGTATTAGG_TSP14_Prostate_NA_10X_1_2   male
# TCGGGCAAGGTAGACC_TSP14_Prostate_NA_10X_1_2   male

# %%
dfData['Number of Cells'] = numCells
dfData
# Out:
#                  Number of Cells
# germ line                     11
# stromal                    82478
# Large_Intestine            13680
# Lymph_Node                 53275
# Skin                        9424
# epithelial                104148
# Spleen                     34004
# Vasculature                16037
# Kidney                      9641
# Salivary_Gland             27199
# Thymus                     33664
# Pancreas                   13497
# Fat                        20263
# Bladder                    24583
# endothelial                31691
# Blood                      50115
# Trachea                     9522
# Bone_Marrow                12297
# Tongue                     15020
# Lung                       35682
# Liver                       5007
# Small_Intestine            12467
# immune                    264824
# Uterus                      7124
# Eye                        10650
# Mammary                    11375
# Prostate                   16375
# Heart                      11505
# Muscle                     30746

# %%
# female to mail ratio
gender_distribution = adata.obs['gender'].value_counts()
fmr = gender_distribution.female / gender_distribution.male

# unique molecular identifiers
umiMean = adata.obs['n_counts_UMIs'].mean()
umiMedian = adata.obs['n_counts_UMIs'].median()
umiStd = adata.obs['n_counts_UMIs'].std()

# number of genes
nGenesMean = adata.obs['n_genes'].mean()
nGenesMedian = adata.obs['n_genes'].median()
nGenesStd = adata.obs['n_genes'].std()

# anatomical information
anatomy = adata.obs['anatomical_information'].unique()

# compartment
compartment = adata.obs['compartment'].unique()

# methods
methods = adata.obs['method'].unique()

# dataset
ds = adata.obs['donor'].unique()

# %%
adata.obs['compartment'].unique()
# Out:
# ['endothelial', 'stromal', 'immune']
# Categories (3, object): ['endothelial', 'immune', 'stromal']

# %%
adata.obs
# Out:
#                                                    organ_tissue     method  \
# cell_id
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Empty...       Muscle  smartseq2
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...       Muscle  smartseq2
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...       Muscle  smartseq2
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...       Muscle  smartseq2
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...       Muscle  smartseq2
# ...                                                         ...        ...
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...       Muscle  smartseq2
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...       Muscle  smartseq2
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...       Muscle  smartseq2
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...       Muscle  smartseq2
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...       Muscle  smartseq2
#
#                                                    donor  \
# cell_id
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Empty...  TSP4
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...  TSP4
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...  TSP4
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...  TSP4
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...  TSP4
# ...                                                  ...
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...  TSP2
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...  TSP2
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...  TSP2
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...  TSP2
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...  TSP2
#
#                                                    anatomical_information  \
# cell_id
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Empty...              diaphragm
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...              diaphragm
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...              diaphragm
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...              diaphragm
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...              diaphragm
# ...                                                                   ...
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...        rectusabdominus
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...        rectusabdominus
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...        rectusabdominus
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...        rectusabdominus
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...        rectusabdominus
#
#                                                     n_counts_UMIs  n_genes  \
# cell_id
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Empty...        82831.0     2253
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...      3531175.0     3896
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...      1332680.0     1487
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...        37120.0      502
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...      2391365.0     3262
# ...                                                           ...      ...
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...       410010.0     1669
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...      1547776.0     2212
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...        99507.0      899
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...       200210.0      726
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...        57224.0      390
#
#                                                                      cell_ontology_class  \
# cell_id
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Empty...     endothelial cell of vascular tree
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...     endothelial cell of vascular tree
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...            capillary endothelial cell
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...  endothelial cell of lymphatic vessel
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...  endothelial cell of lymphatic vessel
# ...                                                                                  ...
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...                 mesenchymal stem cell
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...                 mesenchymal stem cell
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...   skeletal muscle satellite stem cell
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...   skeletal muscle satellite stem cell
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...   skeletal muscle satellite stem cell
#
#                                                                          free_annotation  \
# cell_id
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Empty...     endothelial cell of vascular tree
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...     endothelial cell of vascular tree
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...            capillary endothelial cell
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...  endothelial cell of lymphatic vessel
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...  endothelial cell of lymphatic vessel
# ...                                                                                  ...
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...                 mesenchymal stem cell
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...                 mesenchymal stem cell
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...   skeletal muscle satellite stem cell
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...   skeletal muscle satellite stem cell
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...   skeletal muscle satellite stem cell
#
#                                                     manually_annotated  \
# cell_id
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Empty...                True
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...                True
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...                True
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...                True
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...                True
# ...                                                                ...
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...                True
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...                True
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...                True
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...                True
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...                True
#
#                                                     compartment  gender
# cell_id
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Empty...  endothelial  female
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...  endothelial  female
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...  endothelial  female
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...  endothelial  female
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endot...  endothelial  female
# ...                                                         ...     ...
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...      stromal  female
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...      stromal  female
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...      stromal  female
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...      stromal  female
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087...      stromal  female
#
# [30746 rows x 11 columns]

# %%
adata.var
# Out:
#              gene_symbol     feature_type          ensemblid  highly_variable  \
# DDX11L1          DDX11L1  Gene Expression  ENSG00000223972.5            False
# WASH7P            WASH7P  Gene Expression  ENSG00000227232.5            False
# MIR6859-1      MIR6859-1  Gene Expression  ENSG00000278267.1            False
# MIR1302-2HG  MIR1302-2HG  Gene Expression  ENSG00000243485.5            False
# MIR1302-2      MIR1302-2  Gene Expression  ENSG00000284332.1            False
# ...                  ...              ...                ...              ...
# MT-ND6            MT-ND6  Gene Expression  ENSG00000198695.2            False
# MT-TE              MT-TE  Gene Expression  ENSG00000210194.1            False
# MT-CYB            MT-CYB  Gene Expression  ENSG00000198727.2            False
# MT-TT              MT-TT  Gene Expression  ENSG00000210195.2            False
# MT-TP              MT-TP  Gene Expression  ENSG00000210196.2             True
#
#                     means  dispersions  dispersions_norm      mean       std
# DDX11L1      6.398244e-05     0.835044         -0.573947  0.000039  0.005574
# WASH7P       2.274395e-03     2.442280          0.533203  0.001080  0.031731
# MIR6859-1    6.175251e-05     1.295335         -0.256874  0.000033  0.005634
# MIR1302-2HG  1.372886e-04     2.656352          0.680668  0.000048  0.008041
# MIR1302-2    1.000000e-12          NaN          0.000000  0.000000  1.000000
# ...                   ...          ...               ...       ...       ...
# MT-ND6       9.634841e-01     2.466404          0.154140  0.590065  0.741395
# MT-TE        1.600667e-01     1.603787         -0.044396  0.083929  0.301820
# MT-CYB       4.367693e+00     4.765751         -0.499747  3.874830  1.104192
# MT-TT        6.573967e-02     0.624316         -0.719108  0.040580  0.186848
# MT-TP        4.385102e-01     2.705558          1.115482  0.204806  0.501265
#
# [58870 rows x 9 columns]

# %%
adata.obs['gender']  # ['compartment']
# Out:
# cell_id
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Empty_J24_L003                   female
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endothelial_B12_L003             female
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endothelial_B13_L003             female
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endothelial_B14_L003             female
# TSP4_Muscle_diaphragm_SS2_B112813_B134043_Endothelial_B15_L003             female
#                                                                             ...
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087_MuscleStemCell_O6_S342     female
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087_MuscleStemCell_P18_S378    female
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087_MuscleStemCell_P21_S381    female
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087_MuscleStemCell_P7_S367     female
# TSP2_Muscle_rectusabdominus_SS2_B114661_B133087_MuscleStemCell_P8_S368     female
# Name: gender, Length: 30746, dtype: category
# Categories (2, object): ['female', 'male']

# %%
dfRep['Reference'] = ['','','','']
dfRep['Dimension'] = ['', 512, '', '']
dfRep['Input']     = ['NA', 'Rank Order', 'Rank Order', 'Real Value']
dfRep
