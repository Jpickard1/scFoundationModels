# %% [markdown]
# # Population Fibroblast Proliferation
#
# **Summary** This dataset contains population RNAseq collected in 8 hour intervals from a culture of synchronized Fibroblasts.
#
# **Reference**: [Functional organization of the human 4D Nucleome](https://drive.google.com/file/d/1bur_yPNbBN41SDklDMbYgBiTHi7Ce329/view)

# %%
import os
import sys
import numpy as np
import scipy as sp
import pandas as pd
import anndata as ad
import seaborn as sns

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

DATASET = "Fibroblast Proliferation"

# %%
DATAPATH = "/nfs/turbo/umms-indikar/shared/projects/foundation_models/experiments/fibroblastProliferation/"
MODELS   = [
    "tGPT",
    "geneformer",
    "scgpt",
    "raw"
]
ads = {}
for model in MODELS:
    ads[model] = ad.read_h5ad(os.path.join(DATAPATH, model + '.h5ad'))

# %% [markdown]
# ## Scree Plots

# %%
svs = []
for key, adata in ads.items():
    print(key)
    X = np.nan_to_num(adata.X, nan=0.0)
    _, sigma, _ = np.linalg.svd(X)
    svs.append(sigma)
# Out:
# tGPT
# geneformer
# scgpt
# raw

# %%
plt.figure(figsize=(3,2), dpi=300)
for i in range(4):
    # n = svs[i] / sum(svs[i])
    n = svs[i]
    plt.plot(n[:25], label=list(ads.keys())[i])
plt.legend(loc='lower right', fontsize='small', fancybox=False, framealpha=1, edgecolor='black')
sns.despine()
plt.xlabel('Component')
plt.ylabel('Magnitude')
plt.yscale('log')
plt.title('Fibroblast Proliferation Data', fontsize=10)
plt.show()

# %%
plt.figure(figsize=(3,2), dpi=300)
for i in range(4):
    n = svs[i] / sum(svs[i])
    # n = svs[i]
    plt.plot(n[:25], label=list(ads.keys())[i])
plt.legend(loc='lower right', fontsize='small', fancybox=False, framealpha=1, edgecolor='black')
sns.despine()
plt.xlabel('Component')
plt.ylabel('Contribution')
plt.yscale('log')
plt.title('Fibroblast Proliferation Data', fontsize=10)
plt.show()

# %% [markdown]
# ## Building DMD Models

# %%
from pydmd import DMD

def anndata2timeseries(adata):
    """converts an ann data object to a tensor that we can perform DMD on"""
    replicates = adata.obs['replicate'].nunique()
    maxTimePts = adata.obs['order'].nunique()
    offsetRep, offsetTime = 0, 0
    if adata.obs['replicate'].min() == 1:
        offsetRep = 1
    if adata.obs['order'].min() == 1:
        offsetTime = 1
    stateDims  = adata.X.shape[1]
    X = np.zeros((stateDims, maxTimePts, replicates))
    for observation in range(adata.X.shape[0]):
        rep  = adata.obs['replicate'].iloc[observation] - offsetRep
        time = adata.obs['order'].iloc[observation] - offsetTime
        X[:, time, rep] = adata.X[observation, :]
    return X

def tensor2matrices(data):
    """
    Utility function to reshape the data for Dynamic Mode Decomposition (DMD).

    Params:
    --------------
    data (np.array):
        An array of shape (genes, timepoints, replicates).

    Returns:
    --------------
    Xp (np.array):
        The first m-1 timepoints for all replicates.

    Xf (np.array):
        The last m-1 timepoints for all replicates.
    """
    if data.ndim == 2:
        data = data[:, :, np.newaxis]

    n, m, r = data.shape

    Xp = data[:,:-1].reshape(n, (m-1)*r, order='F')
    Xf = data[:,1:].reshape(n, (m-1)*r, order='F')

    return Xp, Xf

# %%
dmdR, dmdG, dmdT, dmdS = DMD(), DMD(), DMD(), DMD()
Xm, Xp = tensor2matrices(anndata2timeseries(ads['raw']))
dmdR.fit(Xm, Xp)
Xm, Xp = tensor2matrices(anndata2timeseries(ads['geneformer']))
dmdG.fit(Xm, Xp)
Xm, Xp = tensor2matrices(anndata2timeseries(ads['tGPT']))
dmdT.fit(Xm, Xp)
Xm, Xp = tensor2matrices(anndata2timeseries(ads['scgpt']))
dmdS.fit(Xm, Xp)

# %%
dmd_models = [dmdR, dmdG, dmdT, dmdS]
labels = ['Raw Data', 'Geneformer', 'tGPT', 'scGPT']

plt.figure(figsize=(12, 6), dpi=300)

for i, (dmd, label) in enumerate(zip(dmd_models, labels)):
    plt.subplot(2, 2, i+1)
    for mode in dmd.modes.T:
        plt.plot(mode.real)
    plt.title(f'{label}')
    plt.xlabel('Feature Index')
    plt.ylabel('Mode Amplitude')
    plt.xlim([0, len(mode)])
    sns.despine()
    
plt.tight_layout()
plt.show()

# %%
dmd_models = [dmdR, dmdG, dmdT, dmdS]
labels = ['Raw Data', 'Geneformer', 'tGPT', 'scGPT']

# Create a figure
plt.figure(figsize=(6, 6), dpi=300)

for i, (dmd, label) in enumerate(zip(dmd_models, labels)):
    plt.subplot(2, 2, i + 1)
    eigenvalues = dmd.eigs
    
    # Plot the unit circle
    unit_circle = plt.Circle((0, 0), 1, color='gray', fill=False, linestyle='-')
    plt.gca().add_artist(unit_circle)
    
    # Plot the eigenvalues
    plt.scatter(eigenvalues.real, eigenvalues.imag, marker='o', label='Eigenvalues')
    
    plt.title(label)
    plt.xlabel('Real')
    plt.ylabel('Imaginary')
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.gca().set_aspect('equal', adjustable='box')
    sns.despine()
    plt.xlim([-1.05, 1.05])
    plt.ylim([-1.05, 1.05])

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
for mode in dmdR.modes.T:
    plt.plot(mode.real)
plt.title('DMD Modes')
plt.xlabel('Feature Index')
plt.ylabel('Mode Amplitude')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(Xp, aspect='auto', origin='lower')
plt.title('Original Data')
plt.xlabel('Time')
plt.ylabel('Feature Index')

plt.subplot(1, 2, 2)
plt.imshow(Xm, aspect='auto', origin='lower')
plt.title('Reconstructed Data')
plt.xlabel('Time')
plt.ylabel('Feature Index')
plt.show()

# %%
# !pip install pydmd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydmd in /home/jpic/.local/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: numpy<2 in /home/jpic/.local/lib/python3.11/site-packages (from pydmd) (1.25.2)
# Requirement already satisfied: scipy in /home/jpic/.local/lib/python3.11/site-packages (from pydmd) (1.11.1)
# Requirement already satisfied: matplotlib in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from pydmd) (3.8.0)
# Requirement already satisfied: scikit-learn in /home/jpic/.local/lib/python3.11/site-packages (from pydmd) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jpic/.local/lib/python3.11/site-packages (from matplotlib->pydmd) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/jpic/.local/lib/python3.11/site-packages (from matplotlib->pydmd) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jpic/.local/lib/python3.11/site-packages (from matplotlib->pydmd) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jpic/.local/lib/python3.11/site-packages (from matplotlib->pydmd) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/jpic/.local/lib/python3.11/site-packages (from matplotlib->pydmd) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/jpic/.local/lib/python3.11/site-packages (from matplotlib->pydmd) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jpic/.local/lib/python3.11/site-packages (from matplotlib->pydmd) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from matplotlib->pydmd) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /home/jpic/.local/lib/python3.11/site-packages (from scikit-learn->pydmd) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/jpic/.local/lib/python3.11/site-packages (from scikit-learn->pydmd) (3.2.0)
# Requirement already satisfied: six>=1.5 in /sw/pkgs/arc/python3.11-anaconda/2024.02-1/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->pydmd) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
